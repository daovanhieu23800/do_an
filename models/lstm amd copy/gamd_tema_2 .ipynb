# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import random
random.seed(0)
import torch
torch.manual_seed(0)
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
data = pd.read_csv('/Users/hieudao/Desktop/ai/do_an/clean_data/clean_amd.csv')

# %%
data['Date'] = pd.to_datetime(data['Date'])
data = data[ data['Date'] < pd.to_datetime('2023-01-01 00:00:00-04:00')]
data = data[ data['Date'] >= pd.to_datetime('2013-01-01 00:00:00-04:00')]
data['Close+1'] = data['Close'].shift(-1)
data = data.dropna()
data.tail(3)
# Out:
#                             Date       Open       High        Low  Close  \
# 10669  2022-12-27 00:00:00-05:00  63.869999  64.279999  62.970001  63.27
# 10670  2022-12-28 00:00:00-05:00  62.540001  63.540001  61.959999  62.57
# 10671  2022-12-29 00:00:00-05:00  63.639999  65.180000  63.060001  64.82
#
#          Volume    NATR_3      RSI_3      ADX_3  CCI_3_0.015  ...  BBU_3_2.0  \
# 10669  36086000  3.580215  28.581375  40.744299       -100.0  ...  64.904483
# 10670  39526500  3.072722  23.469149  48.356896       -100.0  ...  65.066470
# 10671  41428500  3.496299  58.907116  36.887101        100.0  ...  65.433640
#
#        BBB_3_2.0  BBP_3_2.0  min_price_3  max_price_3  mid_price     tema_2  \
# 10669   3.196924   0.199686    62.259998    66.309998  63.625000  63.296061
# 10670   5.084485   0.226207    61.959999    64.660004  62.750000  62.554867
# 10671   5.917257   0.836824    61.959999    65.180000  64.120001  64.702822
#
#         tema_100     tema_8    Close+1
# 10669  64.069522  63.354633  62.570000
# 10670  63.816341  62.618721  64.820000
# 10671  63.707736  63.450099  64.769997
#
# [3 rows x 28 columns]

# %%
data = data.drop(columns=['tema_8', 'tema_100'])
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'NATR_3', 'RSI_3',
#        'ADX_3', 'CCI_3_0.015', 'ROC_3', 'STOCHk_14_3_3', 'STOCHd_14_3_3',
#        'WILLR_3', 'OBV', 'MACD_12_26_9', 'BBL_3_2.0', 'BBM_3_2.0', 'BBU_3_2.0',
#        'BBB_3_2.0', 'BBP_3_2.0', 'min_price_3', 'max_price_3', 'mid_price',
#        'tema_2', 'Close+1'],
#       dtype='object')

# %%
train = data[data['Date'] < pd.to_datetime('2022-01-01 00:00:00-04:00')]

val = data[data['Date'] < pd.to_datetime('2023-01-01 00:00:00-04:00')]
val = data[data['Date'] >= pd.to_datetime('2022-01-01 00:00:00-04:00')]

train = train.drop(columns=['Date'])
val = val.drop(columns=['Date'])


X_train = train.copy().drop(columns=['Close+1'])
y_train = pd.DataFrame()
y_train['Close+1'] = train[['Close+1']]

X_val = val.copy().drop(columns=['Close+1'])
y_val = pd.DataFrame()
y_val['Close+1'] = val[['Close+1']]
X_train.shape,X_val.shape,y_train.shape,y_val.shape
# Out:
# ((2266, 24), (250, 24), (2266, 1), (250, 1))

# %%
X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
X_val = X_val.to_numpy()
y_val = y_val.to_numpy()
X_train.shape, X_val.shape
# Out:
# ((2266, 24), (250, 24))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_train_scaled.shape, X_val_scaled.shape
# Out:
# ((2266, 24), (250, 24))

# %%
from torch.utils.data import DataLoader,Dataset
sequence_length= 5
class TimeSeriesDataset(Dataset):
    def __init__(self, X, y,sequence_length=5):
        self.X =  torch.tensor(X).float()
        self.y = torch.tensor(y).float()
        self.sequence_length = sequence_length
    def __len__(self):
        return len(self.X)

    def __getitem__(self, i): 
       
        if i >= self.sequence_length - 1:
            i_start = i - self.sequence_length + 1
            x = self.X[i_start:(i + 1), :]
        elif self.sequence_length==1:
            return self.X[i],self.y[i]
        else:
            padding = self.X[0].repeat(self.sequence_length - i - 1, 1)
            x = self.X[0:(i + 1), :]
            #print(padding.shape, x.shape)
            x = torch.cat((padding, x), 0)
            # x = self.X[0:i, :]
            #print(x.shape,padding.shape)

        return x, self.y[i]
       
train_dataset = TimeSeriesDataset(X_train_scaled, y_train, sequence_length=sequence_length)
val_dataset = TimeSeriesDataset(X_val_scaled, y_val, sequence_length=sequence_length)

# %%
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers,batch_first=True)

        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

model = LSTM(24, 64, 2)
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(24, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
losses = []
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    # Set the model to training mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.train()
    train_loss = 0
    num_batches = len(dataloader)

    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)
        train_loss += loss.item()
        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            #print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    print(f"train Error: Avg loss: {train_loss/num_batches:>8f}")
    losses.append((train_loss/num_batches))

# %%
val = []
def test_loop(dataloader, model, loss_fn):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    
    val.append(test_loss)
    
    scheduler.step()
    #curr_lr = optimizer.param_groups[0]['lr']

    print(f"Test Error: Avg loss: {test_loss:>8f}  \n")

# %%
from torch.optim.lr_scheduler import StepLR

learning_rate = 0.01
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = StepLR(optimizer, step_size=200, gamma=0.1)

epochs = 2000
for t in range(epochs):
    if epochs %100==0:
        
        print(f"Epoch {t+1}\n-------------------------------")
    
    train_loop(train_loader, model, loss_fn, optimizer)
    test_loop(val_loader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# train Error: Avg loss: 1782.175712
# Test Error: Avg loss: 6562.710571
#
# Epoch 2
# -------------------------------
# train Error: Avg loss: 1412.661160
# Test Error: Avg loss: 5157.603241
#
# Epoch 3
# -------------------------------
# train Error: Avg loss: 1194.667504
# Test Error: Avg loss: 4145.410980
#
# Epoch 4
# -------------------------------
# train Error: Avg loss: 948.835464
# Test Error: Avg loss: 3314.016891
#
# Epoch 5
# -------------------------------
# train Error: Avg loss: 763.422987
# Test Error: Avg loss: 2614.707031
#
# Epoch 6
# -------------------------------
# train Error: Avg loss: 647.856555
# Test Error: Avg loss: 2081.737396
#
# Epoch 7
# -------------------------------
# train Error: Avg loss: 518.759479
# Test Error: Avg loss: 1637.722492
#
# Epoch 8
# -------------------------------
# train Error: Avg loss: 442.356981
# Test Error: Avg loss: 1381.735207
#
# Epoch 9
# -------------------------------
# train Error: Avg loss: 422.789854
# Test Error: Avg loss: 1031.558188
#
# Epoch 10
# -------------------------------
# train Error: Avg loss: 467.828490
# Test Error: Avg loss: 930.058536
#
# Epoch 11
# -------------------------------
# train Error: Avg loss: 345.489176
# Test Error: Avg loss: 777.523228
#
# Epoch 12
# -------------------------------
# train Error: Avg loss: 280.375817
# Test Error: Avg loss: 663.059952
#
# Epoch 13
# -------------------------------
# train Error: Avg loss: 229.325068
# Test Error: Avg loss: 557.772503
#
# Epoch 14
# -------------------------------
# train Error: Avg loss: 184.258264
# Test Error: Avg loss: 446.452625
#
# Epoch 15
# -------------------------------
# train Error: Avg loss: 161.632642
# Test Error: Avg loss: 378.050079
#
# Epoch 16
# -------------------------------
# train Error: Avg loss: 154.395201
# Test Error: Avg loss: 354.227242
#
# Epoch 17
# -------------------------------
# train Error: Avg loss: 161.907325
# Test Error: Avg loss: 358.087297
#
# Epoch 18
# -------------------------------
# train Error: Avg loss: 152.034365
# Test Error: Avg loss: 289.774693
#
# Epoch 19
# -------------------------------
# train Error: Avg loss: 152.919946
# Test Error: Avg loss: 303.193356
#
# Epoch 20
# -------------------------------
# train Error: Avg loss: 137.382792
# Test Error: Avg loss: 274.784730
#
# Epoch 21
# -------------------------------
# train Error: Avg loss: 136.327418
# Test Error: Avg loss: 465.275871
#
# Epoch 22
# -------------------------------
# train Error: Avg loss: 142.500084
# Test Error: Avg loss: 404.950300
#
# Epoch 23
# -------------------------------
# train Error: Avg loss: 289.404156
# Test Error: Avg loss: 289.704559
#
# Epoch 24
# -------------------------------
# train Error: Avg loss: 179.935898
# Test Error: Avg loss: 286.307492
#
# Epoch 25
# -------------------------------
# train Error: Avg loss: 224.218808
# Test Error: Avg loss: 302.404974
#
# Epoch 26
# -------------------------------
# train Error: Avg loss: 168.017914
# Test Error: Avg loss: 228.518836
#
# Epoch 27
# -------------------------------
# train Error: Avg loss: 141.254455
# Test Error: Avg loss: 333.669323
#
# Epoch 28
# -------------------------------
# train Error: Avg loss: 129.866904
# Test Error: Avg loss: 272.968117
#
# Epoch 29
# -------------------------------
# train Error: Avg loss: 118.033751
# Test Error: Avg loss: 245.318172
#
# Epoch 30
# -------------------------------
# train Error: Avg loss: 105.801272
# Test Error: Avg loss: 187.695816
#
# Epoch 31
# -------------------------------
# train Error: Avg loss: 92.808131
# Test Error: Avg loss: 154.695524
#
# Epoch 32
# -------------------------------
# train Error: Avg loss: 96.986787
# Test Error: Avg loss: 148.487964
#
# Epoch 33
# -------------------------------
# train Error: Avg loss: 100.423629
# Test Error: Avg loss: 225.007733
#
# Epoch 34
# -------------------------------
# train Error: Avg loss: 110.921825
# Test Error: Avg loss: 134.787431
#
# Epoch 35
# -------------------------------
# train Error: Avg loss: 90.416653
# Test Error: Avg loss: 214.019117
#
# Epoch 36
# -------------------------------
# train Error: Avg loss: 71.109374
# Test Error: Avg loss: 118.600140
#
# Epoch 37
# -------------------------------
# train Error: Avg loss: 65.166238
# Test Error: Avg loss: 114.249732
#
# Epoch 38
# -------------------------------
# train Error: Avg loss: 90.233120
# Test Error: Avg loss: 110.652629
#
# Epoch 39
# -------------------------------
# train Error: Avg loss: 95.799782
# Test Error: Avg loss: 246.290074
#
# Epoch 40
# -------------------------------
# train Error: Avg loss: 75.240829
# Test Error: Avg loss: 113.552617
#
# Epoch 41
# -------------------------------
# train Error: Avg loss: 59.997897
# Test Error: Avg loss: 209.259665
#
# Epoch 42
# -------------------------------
# train Error: Avg loss: 50.615190
# Test Error: Avg loss: 152.652336
#
# Epoch 43
# -------------------------------
# train Error: Avg loss: 45.489578
# Test Error: Avg loss: 122.396379
#
# Epoch 44
# -------------------------------
# train Error: Avg loss: 39.764269
# Test Error: Avg loss: 106.672490
#
# Epoch 45
# -------------------------------
# train Error: Avg loss: 34.869423
# Test Error: Avg loss: 99.349705
#
# Epoch 46
# -------------------------------
# train Error: Avg loss: 35.543116
# Test Error: Avg loss: 132.978361
#
# Epoch 47
# -------------------------------
# train Error: Avg loss: 40.448563
# Test Error: Avg loss: 160.081028
#
# Epoch 48
# -------------------------------
# train Error: Avg loss: 35.967868
# Test Error: Avg loss: 100.973274
#
# Epoch 49
# -------------------------------
# train Error: Avg loss: 36.394266
# Test Error: Avg loss: 133.538242
#
# Epoch 50
# -------------------------------
# train Error: Avg loss: 34.928258
# Test Error: Avg loss: 125.655920
#
# Epoch 51
# -------------------------------
# train Error: Avg loss: 59.102391
# Test Error: Avg loss: 243.226012
#
# Epoch 52
# -------------------------------
# train Error: Avg loss: 65.332526
# Test Error: Avg loss: 147.444500
#
# Epoch 53
# -------------------------------
# train Error: Avg loss: 114.129874
# Test Error: Avg loss: 226.995682
#
# Epoch 54
# -------------------------------
# train Error: Avg loss: 350.390576
# Test Error: Avg loss: 300.388021
#
# Epoch 55
# -------------------------------
# train Error: Avg loss: 148.052039
# Test Error: Avg loss: 338.369770
#
# Epoch 56
# -------------------------------
# train Error: Avg loss: 120.116434
# Test Error: Avg loss: 299.574968
#
# Epoch 57
# -------------------------------
# train Error: Avg loss: 124.157931
# Test Error: Avg loss: 318.923302
#
# Epoch 58
# -------------------------------
# train Error: Avg loss: 111.429474
# Test Error: Avg loss: 303.663792
#
# Epoch 59
# -------------------------------
# train Error: Avg loss: 102.618818
# Test Error: Avg loss: 294.164665
#
# Epoch 60
# -------------------------------
# train Error: Avg loss: 88.592276
# Test Error: Avg loss: 244.538557
#
# Epoch 61
# -------------------------------
# train Error: Avg loss: 94.216772
# Test Error: Avg loss: 252.645012
#
# Epoch 62
# -------------------------------
# train Error: Avg loss: 86.967993
# Test Error: Avg loss: 197.356865
#
# Epoch 63
# -------------------------------
# train Error: Avg loss: 77.873927
# Test Error: Avg loss: 155.595495
#
# Epoch 64
# -------------------------------
# train Error: Avg loss: 124.869620
# Test Error: Avg loss: 125.382015
#
# Epoch 65
# -------------------------------
# train Error: Avg loss: 81.695778
# Test Error: Avg loss: 168.008319
#
# Epoch 66
# -------------------------------
# train Error: Avg loss: 81.981396
# Test Error: Avg loss: 134.828201
#
# Epoch 67
# -------------------------------
# train Error: Avg loss: 56.955537
# Test Error: Avg loss: 174.555853
#
# Epoch 68
# -------------------------------
# train Error: Avg loss: 54.908683
# Test Error: Avg loss: 126.973488
#
# Epoch 69
# -------------------------------
# train Error: Avg loss: 46.102634
# Test Error: Avg loss: 92.353299
#
# Epoch 70
# -------------------------------
# train Error: Avg loss: 56.171030
# Test Error: Avg loss: 148.009998
#
# Epoch 71
# -------------------------------
# train Error: Avg loss: 71.443440
# Test Error: Avg loss: 211.830139
#
# Epoch 72
# -------------------------------
# train Error: Avg loss: 48.237809
# Test Error: Avg loss: 88.342136
#
# Epoch 73
# -------------------------------
# train Error: Avg loss: 39.627074
# Test Error: Avg loss: 156.672215
#
# Epoch 74
# -------------------------------
# train Error: Avg loss: 33.345946
# Test Error: Avg loss: 76.339226
#
# Epoch 75
# -------------------------------
# train Error: Avg loss: 29.130083
# Test Error: Avg loss: 108.175353
#
# Epoch 76
# -------------------------------
# train Error: Avg loss: 23.947672
# Test Error: Avg loss: 73.571936
#
# Epoch 77
# -------------------------------
# train Error: Avg loss: 21.745067
# Test Error: Avg loss: 73.313225
#
# Epoch 78
# -------------------------------
# train Error: Avg loss: 21.027969
# Test Error: Avg loss: 63.872445
#
# Epoch 79
# -------------------------------
# train Error: Avg loss: 20.096994
# Test Error: Avg loss: 73.034532
#
# Epoch 80
# -------------------------------
# train Error: Avg loss: 17.634774
# Test Error: Avg loss: 60.572968
#
# Epoch 81
# -------------------------------
# train Error: Avg loss: 18.537514
# Test Error: Avg loss: 67.982650
#
# Epoch 82
# -------------------------------
# train Error: Avg loss: 21.783209
# Test Error: Avg loss: 73.650439
#
# Epoch 83
# -------------------------------
# train Error: Avg loss: 33.349021
# Test Error: Avg loss: 186.852789
#
# Epoch 84
# -------------------------------
# train Error: Avg loss: 23.745478
# Test Error: Avg loss: 85.284515
#
# Epoch 85
# -------------------------------
# train Error: Avg loss: 36.286990
# Test Error: Avg loss: 195.498978
#
# Epoch 86
# -------------------------------
# train Error: Avg loss: 28.683051
# Test Error: Avg loss: 91.714520
#
# Epoch 87
# -------------------------------
# train Error: Avg loss: 25.658978
# Test Error: Avg loss: 184.432745
#
# Epoch 88
# -------------------------------
# train Error: Avg loss: 18.175798
# Test Error: Avg loss: 93.981834
#
# Epoch 89
# -------------------------------
# train Error: Avg loss: 13.068183
# Test Error: Avg loss: 77.614400
#
# Epoch 90
# -------------------------------
# train Error: Avg loss: 9.958296
# Test Error: Avg loss: 64.287586
#
# Epoch 91
# -------------------------------
# train Error: Avg loss: 8.331366
# Test Error: Avg loss: 56.338954
#
# Epoch 92
# -------------------------------
# train Error: Avg loss: 10.202904
# Test Error: Avg loss: 66.004727
#
# Epoch 93
# -------------------------------
# train Error: Avg loss: 18.320007
# Test Error: Avg loss: 112.958401
#
# Epoch 94
# -------------------------------
# train Error: Avg loss: 18.982813
# Test Error: Avg loss: 95.195929
#
# Epoch 95
# -------------------------------
# train Error: Avg loss: 24.416751
# Test Error: Avg loss: 190.626978
#
# Epoch 96
# -------------------------------
# train Error: Avg loss: 11.945997
# Test Error: Avg loss: 82.105832
#
# Epoch 97
# -------------------------------
# train Error: Avg loss: 8.150552
# Test Error: Avg loss: 60.477201
#
# Epoch 98
# -------------------------------
# train Error: Avg loss: 8.312794
# Test Error: Avg loss: 59.391301
#
# Epoch 99
# -------------------------------
# train Error: Avg loss: 10.740077
# Test Error: Avg loss: 71.421930
#
# Epoch 100
# -------------------------------
# train Error: Avg loss: 14.594222
# Test Error: Avg loss: 63.717043
#
# Epoch 101
# -------------------------------
# train Error: Avg loss: 25.023858
# Test Error: Avg loss: 195.007401
#
# Epoch 102
# -------------------------------
# train Error: Avg loss: 11.950594
# Test Error: Avg loss: 99.174704
#
# Epoch 103
# -------------------------------
# train Error: Avg loss: 8.539868
# Test Error: Avg loss: 81.141964
#
# Epoch 104
# -------------------------------
# train Error: Avg loss: 7.200213
# Test Error: Avg loss: 66.228257
#
# Epoch 105
# -------------------------------
# train Error: Avg loss: 6.809768
# Test Error: Avg loss: 75.859129
#
# Epoch 106
# -------------------------------
# train Error: Avg loss: 5.811148
# Test Error: Avg loss: 64.574357
#
# Epoch 107
# -------------------------------
# train Error: Avg loss: 5.388044
# Test Error: Avg loss: 65.540452
#
# Epoch 108
# -------------------------------
# train Error: Avg loss: 5.456182
# Test Error: Avg loss: 61.139271
#
# Epoch 109
# -------------------------------
# train Error: Avg loss: 5.827620
# Test Error: Avg loss: 65.883574
#
# Epoch 110
# -------------------------------
# train Error: Avg loss: 5.605712
# Test Error: Avg loss: 59.581063
#
# Epoch 111
# -------------------------------
# train Error: Avg loss: 6.354081
# Test Error: Avg loss: 66.746066
#
# Epoch 112
# -------------------------------
# train Error: Avg loss: 7.371847
# Test Error: Avg loss: 60.526480
#
# Epoch 113
# -------------------------------
# train Error: Avg loss: 12.488157
# Test Error: Avg loss: 88.306416
#
# Epoch 114
# -------------------------------
# train Error: Avg loss: 16.103981
# Test Error: Avg loss: 81.168907
#
# Epoch 115
# -------------------------------
# train Error: Avg loss: 58.094644
# Test Error: Avg loss: 234.337172
#
# Epoch 116
# -------------------------------
# train Error: Avg loss: 120.020693
# Test Error: Avg loss: 223.613850
#
# Epoch 117
# -------------------------------
# train Error: Avg loss: 198.353534
# Test Error: Avg loss: 456.446648
#
# Epoch 118
# -------------------------------
# train Error: Avg loss: 91.086080
# Test Error: Avg loss: 216.264336
#
# Epoch 119
# -------------------------------
# train Error: Avg loss: 33.531403
# Test Error: Avg loss: 68.120348
#
# Epoch 120
# -------------------------------
# train Error: Avg loss: 21.581876
# Test Error: Avg loss: 81.155705
#
# Epoch 121
# -------------------------------
# train Error: Avg loss: 17.457784
# Test Error: Avg loss: 80.112002
#
# Epoch 122
# -------------------------------
# train Error: Avg loss: 11.925168
# Test Error: Avg loss: 65.026281
#
# Epoch 123
# -------------------------------
# train Error: Avg loss: 7.723489
# Test Error: Avg loss: 69.819244
#
# Epoch 124
# -------------------------------
# train Error: Avg loss: 10.285490
# Test Error: Avg loss: 62.305271
#
# Epoch 125
# -------------------------------
# train Error: Avg loss: 10.590035
# Test Error: Avg loss: 63.928308
#
# Epoch 126
# -------------------------------
# train Error: Avg loss: 12.451637
# Test Error: Avg loss: 87.446772
#
# Epoch 127
# -------------------------------
# train Error: Avg loss: 9.645626
# Test Error: Avg loss: 68.707767
#
# Epoch 128
# -------------------------------
# train Error: Avg loss: 12.699936
# Test Error: Avg loss: 89.099447
#
# Epoch 129
# -------------------------------
# train Error: Avg loss: 8.311236
# Test Error: Avg loss: 85.041354
#
# Epoch 130
# -------------------------------
# train Error: Avg loss: 7.403109
# Test Error: Avg loss: 81.457754
#
# Epoch 131
# -------------------------------
# train Error: Avg loss: 5.009760
# Test Error: Avg loss: 70.237144
#
# Epoch 132
# -------------------------------
# train Error: Avg loss: 4.630464
# Test Error: Avg loss: 64.769639
#
# Epoch 133
# -------------------------------
# train Error: Avg loss: 4.570613
# Test Error: Avg loss: 64.142910
#
# Epoch 134
# -------------------------------
# train Error: Avg loss: 4.643548
# Test Error: Avg loss: 62.087495
#
# Epoch 135
# -------------------------------
# train Error: Avg loss: 4.301514
# Test Error: Avg loss: 61.799987
#
# Epoch 136
# -------------------------------
# train Error: Avg loss: 4.712981
# Test Error: Avg loss: 58.731543
#
# Epoch 137
# -------------------------------
# train Error: Avg loss: 4.636828
# Test Error: Avg loss: 63.391533
#
# Epoch 138
# -------------------------------
# train Error: Avg loss: 5.466831
# Test Error: Avg loss: 57.207895
#
# Epoch 139
# -------------------------------
# train Error: Avg loss: 4.946598
# Test Error: Avg loss: 65.886567
#
# Epoch 140
# -------------------------------
# train Error: Avg loss: 4.321559
# Test Error: Avg loss: 56.531413
#
# Epoch 141
# -------------------------------
# train Error: Avg loss: 3.799302
# Test Error: Avg loss: 56.861579
#
# Epoch 142
# -------------------------------
# train Error: Avg loss: 3.509938
# Test Error: Avg loss: 54.637374
#
# Epoch 143
# -------------------------------
# train Error: Avg loss: 3.280898
# Test Error: Avg loss: 55.036407
#
# Epoch 144
# -------------------------------
# train Error: Avg loss: 3.122741
# Test Error: Avg loss: 53.767342
#
# Epoch 145
# -------------------------------
# train Error: Avg loss: 3.103792
# Test Error: Avg loss: 54.097463
#
# Epoch 146
# -------------------------------
# train Error: Avg loss: 3.030055
# Test Error: Avg loss: 51.846348
#
# Epoch 147
# -------------------------------
# train Error: Avg loss: 3.007509
# Test Error: Avg loss: 51.712520
#
# Epoch 148
# -------------------------------
# train Error: Avg loss: 3.129052
# Test Error: Avg loss: 50.724548
#
# Epoch 149
# -------------------------------
# train Error: Avg loss: 3.516211
# Test Error: Avg loss: 52.137839
#
# Epoch 150
# -------------------------------
# train Error: Avg loss: 4.788788
# Test Error: Avg loss: 52.031455
#
# Epoch 151
# -------------------------------
# train Error: Avg loss: 6.190825
# Test Error: Avg loss: 60.190220
#
# Epoch 152
# -------------------------------
# train Error: Avg loss: 13.561824
# Test Error: Avg loss: 70.182806
#
# Epoch 153
# -------------------------------
# train Error: Avg loss: 21.576699
# Test Error: Avg loss: 90.915709
#
# Epoch 154
# -------------------------------
# train Error: Avg loss: 42.973038
# Test Error: Avg loss: 267.884930
#
# Epoch 155
# -------------------------------
# train Error: Avg loss: 43.810939
# Test Error: Avg loss: 141.871477
#
# Epoch 156
# -------------------------------
# train Error: Avg loss: 92.263700
# Test Error: Avg loss: 125.739351
#
# Epoch 157
# -------------------------------
# train Error: Avg loss: 98.546894
# Test Error: Avg loss: 109.551824
#
# Epoch 158
# -------------------------------
# train Error: Avg loss: 52.274995
# Test Error: Avg loss: 166.022390
#
# Epoch 159
# -------------------------------
# train Error: Avg loss: 44.315976
# Test Error: Avg loss: 158.895987
#
# Epoch 160
# -------------------------------
# train Error: Avg loss: 137.871506
# Test Error: Avg loss: 300.819773
#
# Epoch 161
# -------------------------------
# train Error: Avg loss: 91.864563
# Test Error: Avg loss: 189.297063
#
# Epoch 162
# -------------------------------
# train Error: Avg loss: 27.680833
# Test Error: Avg loss: 79.130503
#
# Epoch 163
# -------------------------------
# train Error: Avg loss: 10.794982
# Test Error: Avg loss: 91.539791
#
# Epoch 164
# -------------------------------
# train Error: Avg loss: 10.473947
# Test Error: Avg loss: 75.698365
#
# Epoch 165
# -------------------------------
# train Error: Avg loss: 13.040428
# Test Error: Avg loss: 95.593008
#
# Epoch 166
# -------------------------------
# train Error: Avg loss: 11.972874
# Test Error: Avg loss: 55.970473
#
# Epoch 167
# -------------------------------
# train Error: Avg loss: 13.295602
# Test Error: Avg loss: 111.847950
#
# Epoch 168
# -------------------------------
# train Error: Avg loss: 7.749577
# Test Error: Avg loss: 67.665134
#
# Epoch 169
# -------------------------------
# train Error: Avg loss: 6.556052
# Test Error: Avg loss: 73.120220
#
# Epoch 170
# -------------------------------
# train Error: Avg loss: 5.930604
# Test Error: Avg loss: 58.345355
#
# Epoch 171
# -------------------------------
# train Error: Avg loss: 5.166350
# Test Error: Avg loss: 67.387068
#
# Epoch 172
# -------------------------------
# train Error: Avg loss: 5.516682
# Test Error: Avg loss: 57.686022
#
# Epoch 173
# -------------------------------
# train Error: Avg loss: 5.539515
# Test Error: Avg loss: 61.815908
#
# Epoch 174
# -------------------------------
# train Error: Avg loss: 4.854940
# Test Error: Avg loss: 52.918132
#
# Epoch 175
# -------------------------------
# train Error: Avg loss: 4.595526
# Test Error: Avg loss: 62.504232
#
# Epoch 176
# -------------------------------
# train Error: Avg loss: 5.077515
# Test Error: Avg loss: 54.069198
#
# Epoch 177
# -------------------------------
# train Error: Avg loss: 5.620035
# Test Error: Avg loss: 65.433852
#
# Epoch 178
# -------------------------------
# train Error: Avg loss: 6.220607
# Test Error: Avg loss: 54.077954
#
# Epoch 179
# -------------------------------
# train Error: Avg loss: 8.912140
# Test Error: Avg loss: 83.836868
#
# Epoch 180
# -------------------------------
# train Error: Avg loss: 8.420401
# Test Error: Avg loss: 55.573065
#
# Epoch 181
# -------------------------------
# train Error: Avg loss: 11.205077
# Test Error: Avg loss: 87.297186
#
# Epoch 182
# -------------------------------
# train Error: Avg loss: 9.295636
# Test Error: Avg loss: 61.982379
#
# Epoch 183
# -------------------------------
# train Error: Avg loss: 8.103540
# Test Error: Avg loss: 77.165475
#
# Epoch 184
# -------------------------------
# train Error: Avg loss: 5.512923
# Test Error: Avg loss: 54.382114
#
# Epoch 185
# -------------------------------
# train Error: Avg loss: 4.270005
# Test Error: Avg loss: 61.681163
#
# Epoch 186
# -------------------------------
# train Error: Avg loss: 3.657993
# Test Error: Avg loss: 54.959144
#
# Epoch 187
# -------------------------------
# train Error: Avg loss: 3.376732
# Test Error: Avg loss: 56.058998
#
# Epoch 188
# -------------------------------
# train Error: Avg loss: 3.115352
# Test Error: Avg loss: 54.417384
#
# Epoch 189
# -------------------------------
# train Error: Avg loss: 2.964673
# Test Error: Avg loss: 55.658852
#
# Epoch 190
# -------------------------------
# train Error: Avg loss: 2.844881
# Test Error: Avg loss: 55.264981
#
# Epoch 191
# -------------------------------
# train Error: Avg loss: 2.878639
# Test Error: Avg loss: 55.659134
#
# Epoch 192
# -------------------------------
# train Error: Avg loss: 2.870857
# Test Error: Avg loss: 54.754115
#
# Epoch 193
# -------------------------------
# train Error: Avg loss: 3.093833
# Test Error: Avg loss: 56.529923
#
# Epoch 194
# -------------------------------
# train Error: Avg loss: 3.100460
# Test Error: Avg loss: 53.683212
#
# Epoch 195
# -------------------------------
# train Error: Avg loss: 3.713643
# Test Error: Avg loss: 59.877881
#
# Epoch 196
# -------------------------------
# train Error: Avg loss: 3.530840
# Test Error: Avg loss: 52.549283
#
# Epoch 197
# -------------------------------
# train Error: Avg loss: 3.662910
# Test Error: Avg loss: 58.003446
#
# Epoch 198
# -------------------------------
# train Error: Avg loss: 3.557234
# Test Error: Avg loss: 51.976140
#
# Epoch 199
# -------------------------------
# train Error: Avg loss: 3.709087
# Test Error: Avg loss: 56.397654
#
# Epoch 200
# -------------------------------
# train Error: Avg loss: 4.095067
# Test Error: Avg loss: 59.153377
#
# Epoch 201
# -------------------------------
# train Error: Avg loss: 2.639415
# Test Error: Avg loss: 56.242690
#
# Epoch 202
# -------------------------------
# train Error: Avg loss: 2.488606
# Test Error: Avg loss: 55.639323
#
# Epoch 203
# -------------------------------
# train Error: Avg loss: 2.386437
# Test Error: Avg loss: 55.288498
#
# Epoch 204
# -------------------------------
# train Error: Avg loss: 2.309963
# Test Error: Avg loss: 55.047697
#
# Epoch 205
# -------------------------------
# train Error: Avg loss: 2.251593
# Test Error: Avg loss: 54.862545
#
# Epoch 206
# -------------------------------
# train Error: Avg loss: 2.206873
# Test Error: Avg loss: 54.706647
#
# Epoch 207
# -------------------------------
# train Error: Avg loss: 2.171784
# Test Error: Avg loss: 54.571139
#
# Epoch 208
# -------------------------------
# train Error: Avg loss: 2.143291
# Test Error: Avg loss: 54.449488
#
# Epoch 209
# -------------------------------
# train Error: Avg loss: 2.119855
# Test Error: Avg loss: 54.333341
#
# Epoch 210
# -------------------------------
# train Error: Avg loss: 2.100268
# Test Error: Avg loss: 54.219756
#
# Epoch 211
# -------------------------------
# train Error: Avg loss: 2.083164
# Test Error: Avg loss: 54.110987
#
# Epoch 212
# -------------------------------
# train Error: Avg loss: 2.067542
# Test Error: Avg loss: 54.008866
#
# Epoch 213
# -------------------------------
# train Error: Avg loss: 2.052750
# Test Error: Avg loss: 53.914052
#
# Epoch 214
# -------------------------------
# train Error: Avg loss: 2.038343
# Test Error: Avg loss: 53.827094
#
# Epoch 215
# -------------------------------
# train Error: Avg loss: 2.023966
# Test Error: Avg loss: 53.748760
#
# Epoch 216
# -------------------------------
# train Error: Avg loss: 2.009366
# Test Error: Avg loss: 53.679084
#
# Epoch 217
# -------------------------------
# train Error: Avg loss: 1.994836
# Test Error: Avg loss: 53.616904
#
# Epoch 218
# -------------------------------
# train Error: Avg loss: 1.981522
# Test Error: Avg loss: 53.560413
#
# Epoch 219
# -------------------------------
# train Error: Avg loss: 1.969780
# Test Error: Avg loss: 53.507282
#
# Epoch 220
# -------------------------------
# train Error: Avg loss: 1.958784
# Test Error: Avg loss: 53.455214
#
# Epoch 221
# -------------------------------
# train Error: Avg loss: 1.947666
# Test Error: Avg loss: 53.402415
#
# Epoch 222
# -------------------------------
# train Error: Avg loss: 1.935312
# Test Error: Avg loss: 53.347486
#
# Epoch 223
# -------------------------------
# train Error: Avg loss: 1.921024
# Test Error: Avg loss: 53.291689
#
# Epoch 224
# -------------------------------
# train Error: Avg loss: 1.905890
# Test Error: Avg loss: 53.243472
#
# Epoch 225
# -------------------------------
# train Error: Avg loss: 1.886461
# Test Error: Avg loss: 53.210560
#
# Epoch 226
# -------------------------------
# train Error: Avg loss: 1.876118
# Test Error: Avg loss: 53.185485
#
# Epoch 227
# -------------------------------
# train Error: Avg loss: 1.867899
# Test Error: Avg loss: 53.160141
#
# Epoch 228
# -------------------------------
# train Error: Avg loss: 1.859988
# Test Error: Avg loss: 53.139163
#
# Epoch 229
# -------------------------------
# train Error: Avg loss: 1.852229
# Test Error: Avg loss: 53.119977
#
# Epoch 230
# -------------------------------
# train Error: Avg loss: 1.844559
# Test Error: Avg loss: 53.101174
#
# Epoch 231
# -------------------------------
# train Error: Avg loss: 1.836948
# Test Error: Avg loss: 53.082085
#
# Epoch 232
# -------------------------------
# train Error: Avg loss: 1.829374
# Test Error: Avg loss: 53.062193
#
# Epoch 233
# -------------------------------
# train Error: Avg loss: 1.821817
# Test Error: Avg loss: 53.041120
#
# Epoch 234
# -------------------------------
# train Error: Avg loss: 1.814255
# Test Error: Avg loss: 53.018737
#
# Epoch 235
# -------------------------------
# train Error: Avg loss: 1.806657
# Test Error: Avg loss: 52.994940
#
# Epoch 236
# -------------------------------
# train Error: Avg loss: 1.798976
# Test Error: Avg loss: 52.969715
#
# Epoch 237
# -------------------------------
# train Error: Avg loss: 1.791130
# Test Error: Avg loss: 52.943052
#
# Epoch 238
# -------------------------------
# train Error: Avg loss: 1.783001
# Test Error: Avg loss: 52.915074
#
# Epoch 239
# -------------------------------
# train Error: Avg loss: 1.774546
# Test Error: Avg loss: 52.886498
#
# Epoch 240
# -------------------------------
# train Error: Avg loss: 1.765874
# Test Error: Avg loss: 52.858337
#
# Epoch 241
# -------------------------------
# train Error: Avg loss: 1.757075
# Test Error: Avg loss: 52.829531
#
# Epoch 242
# -------------------------------
# train Error: Avg loss: 1.748227
# Test Error: Avg loss: 52.799843
#
# Epoch 243
# -------------------------------
# train Error: Avg loss: 1.739401
# Test Error: Avg loss: 52.769168
#
# Epoch 244
# -------------------------------
# train Error: Avg loss: 1.730656
# Test Error: Avg loss: 52.737680
#
# Epoch 245
# -------------------------------
# train Error: Avg loss: 1.722040
# Test Error: Avg loss: 52.705641
#
# Epoch 246
# -------------------------------
# train Error: Avg loss: 1.713585
# Test Error: Avg loss: 52.673280
#
# Epoch 247
# -------------------------------
# train Error: Avg loss: 1.705288
# Test Error: Avg loss: 52.640683
#
# Epoch 248
# -------------------------------
# train Error: Avg loss: 1.697124
# Test Error: Avg loss: 52.607822
#
# Epoch 249
# -------------------------------
# train Error: Avg loss: 1.689053
# Test Error: Avg loss: 52.574574
#
# Epoch 250
# -------------------------------
# train Error: Avg loss: 1.681025
# Test Error: Avg loss: 52.540816
#
# Epoch 251
# -------------------------------
# train Error: Avg loss: 1.672987
# Test Error: Avg loss: 52.506450
#
# Epoch 252
# -------------------------------
# train Error: Avg loss: 1.664889
# Test Error: Avg loss: 52.471423
#
# Epoch 253
# -------------------------------
# train Error: Avg loss: 1.656677
# Test Error: Avg loss: 52.435740
#
# Epoch 254
# -------------------------------
# train Error: Avg loss: 1.648300
# Test Error: Avg loss: 52.399468
#
# Epoch 255
# -------------------------------
# train Error: Avg loss: 1.639713
# Test Error: Avg loss: 52.362783
#
# Epoch 256
# -------------------------------
# train Error: Avg loss: 1.630901
# Test Error: Avg loss: 52.325874
#
# Epoch 257
# -------------------------------
# train Error: Avg loss: 1.621883
# Test Error: Avg loss: 52.288988
#
# Epoch 258
# -------------------------------
# train Error: Avg loss: 1.612707
# Test Error: Avg loss: 52.252262
#
# Epoch 259
# -------------------------------
# train Error: Avg loss: 1.603400
# Test Error: Avg loss: 52.216035
#
# Epoch 260
# -------------------------------
# train Error: Avg loss: 1.593919
# Test Error: Avg loss: 52.181408
#
# Epoch 261
# -------------------------------
# train Error: Avg loss: 1.584138
# Test Error: Avg loss: 52.150740
#
# Epoch 262
# -------------------------------
# train Error: Avg loss: 1.573850
# Test Error: Avg loss: 52.128025
#
# Epoch 263
# -------------------------------
# train Error: Avg loss: 1.562808
# Test Error: Avg loss: 52.118355
#
# Epoch 264
# -------------------------------
# train Error: Avg loss: 1.550886
# Test Error: Avg loss: 52.125228
#
# Epoch 265
# -------------------------------
# train Error: Avg loss: 1.538499
# Test Error: Avg loss: 52.142407
#
# Epoch 266
# -------------------------------
# train Error: Avg loss: 1.526507
# Test Error: Avg loss: 52.149107
#
# Epoch 267
# -------------------------------
# train Error: Avg loss: 1.515130
# Test Error: Avg loss: 52.134762
#
# Epoch 268
# -------------------------------
# train Error: Avg loss: 1.504095
# Test Error: Avg loss: 52.112693
#
# Epoch 269
# -------------------------------
# train Error: Avg loss: 1.493167
# Test Error: Avg loss: 52.092399
#
# Epoch 270
# -------------------------------
# train Error: Avg loss: 1.482121
# Test Error: Avg loss: 52.076614
#
# Epoch 271
# -------------------------------
# train Error: Avg loss: 1.470597
# Test Error: Avg loss: 52.064877
#
# Epoch 272
# -------------------------------
# train Error: Avg loss: 1.458101
# Test Error: Avg loss: 52.058036
#
# Epoch 273
# -------------------------------
# train Error: Avg loss: 1.444253
# Test Error: Avg loss: 52.053182
#
# Epoch 274
# -------------------------------
# train Error: Avg loss: 1.428096
# Test Error: Avg loss: 52.020528
#
# Epoch 275
# -------------------------------
# train Error: Avg loss: 1.407914
# Test Error: Avg loss: 51.922750
#
# Epoch 276
# -------------------------------
# train Error: Avg loss: 1.384228
# Test Error: Avg loss: 51.849419
#
# Epoch 277
# -------------------------------
# train Error: Avg loss: 1.358664
# Test Error: Avg loss: 51.789477
#
# Epoch 278
# -------------------------------
# train Error: Avg loss: 1.337061
# Test Error: Avg loss: 51.758780
#
# Epoch 279
# -------------------------------
# train Error: Avg loss: 1.319230
# Test Error: Avg loss: 51.702454
#
# Epoch 280
# -------------------------------
# train Error: Avg loss: 1.304956
# Test Error: Avg loss: 51.716295
#
# Epoch 281
# -------------------------------
# train Error: Avg loss: 1.300908
# Test Error: Avg loss: 51.563427
#
# Epoch 282
# -------------------------------
# train Error: Avg loss: 1.277804
# Test Error: Avg loss: 51.447445
#
# Epoch 283
# -------------------------------
# train Error: Avg loss: 1.252535
# Test Error: Avg loss: 51.465243
#
# Epoch 284
# -------------------------------
# train Error: Avg loss: 1.237569
# Test Error: Avg loss: 51.415934
#
# Epoch 285
# -------------------------------
# train Error: Avg loss: 1.231166
# Test Error: Avg loss: 51.031692
#
# Epoch 286
# -------------------------------
# train Error: Avg loss: 1.219894
# Test Error: Avg loss: 51.310600
#
# Epoch 287
# -------------------------------
# train Error: Avg loss: 1.226438
# Test Error: Avg loss: 51.040391
#
# Epoch 288
# -------------------------------
# train Error: Avg loss: 1.234235
# Test Error: Avg loss: 51.571122
#
# Epoch 289
# -------------------------------
# train Error: Avg loss: 1.248350
# Test Error: Avg loss: 50.608474
#
# Epoch 290
# -------------------------------
# train Error: Avg loss: 1.233160
# Test Error: Avg loss: 51.520025
#
# Epoch 291
# -------------------------------
# train Error: Avg loss: 1.202590
# Test Error: Avg loss: 50.774005
#
# Epoch 292
# -------------------------------
# train Error: Avg loss: 1.203216
# Test Error: Avg loss: 51.558572
#
# Epoch 293
# -------------------------------
# train Error: Avg loss: 1.195666
# Test Error: Avg loss: 50.370048
#
# Epoch 294
# -------------------------------
# train Error: Avg loss: 1.207717
# Test Error: Avg loss: 51.370188
#
# Epoch 295
# -------------------------------
# train Error: Avg loss: 1.182727
# Test Error: Avg loss: 50.596437
#
# Epoch 296
# -------------------------------
# train Error: Avg loss: 1.211825
# Test Error: Avg loss: 51.441048
#
# Epoch 297
# -------------------------------
# train Error: Avg loss: 1.189977
# Test Error: Avg loss: 50.236726
#
# Epoch 298
# -------------------------------
# train Error: Avg loss: 1.204009
# Test Error: Avg loss: 51.097362
#
# Epoch 299
# -------------------------------
# train Error: Avg loss: 1.137849
# Test Error: Avg loss: 50.612331
#
# Epoch 300
# -------------------------------
# train Error: Avg loss: 1.140718
# Test Error: Avg loss: 51.183307
#
# Epoch 301
# -------------------------------
# train Error: Avg loss: 1.091352
# Test Error: Avg loss: 50.287158
#
# Epoch 302
# -------------------------------
# train Error: Avg loss: 1.103986
# Test Error: Avg loss: 50.845117
#
# Epoch 303
# -------------------------------
# train Error: Avg loss: 1.086455
# Test Error: Avg loss: 50.185360
#
# Epoch 304
# -------------------------------
# train Error: Avg loss: 1.115806
# Test Error: Avg loss: 50.862411
#
# Epoch 305
# -------------------------------
# train Error: Avg loss: 1.097501
# Test Error: Avg loss: 50.106290
#
# Epoch 306
# -------------------------------
# train Error: Avg loss: 1.133545
# Test Error: Avg loss: 50.998814
#
# Epoch 307
# -------------------------------
# train Error: Avg loss: 1.103684
# Test Error: Avg loss: 49.977129
#
# Epoch 308
# -------------------------------
# train Error: Avg loss: 1.135218
# Test Error: Avg loss: 51.112211
#
# Epoch 309
# -------------------------------
# train Error: Avg loss: 1.095784
# Test Error: Avg loss: 49.949887
#
# Epoch 310
# -------------------------------
# train Error: Avg loss: 1.116010
# Test Error: Avg loss: 51.177269
#
# Epoch 311
# -------------------------------
# train Error: Avg loss: 1.074188
# Test Error: Avg loss: 49.998300
#
# Epoch 312
# -------------------------------
# train Error: Avg loss: 1.088825
# Test Error: Avg loss: 51.209395
#
# Epoch 313
# -------------------------------
# train Error: Avg loss: 1.043123
# Test Error: Avg loss: 50.052171
#
# Epoch 314
# -------------------------------
# train Error: Avg loss: 1.050449
# Test Error: Avg loss: 51.127079
#
# Epoch 315
# -------------------------------
# train Error: Avg loss: 1.008302
# Test Error: Avg loss: 50.100390
#
# Epoch 316
# -------------------------------
# train Error: Avg loss: 1.019617
# Test Error: Avg loss: 50.872539
#
# Epoch 317
# -------------------------------
# train Error: Avg loss: 1.008264
# Test Error: Avg loss: 50.196285
#
# Epoch 318
# -------------------------------
# train Error: Avg loss: 1.075063
# Test Error: Avg loss: 50.882588
#
# Epoch 319
# -------------------------------
# train Error: Avg loss: 1.104806
# Test Error: Avg loss: 50.242395
#
# Epoch 320
# -------------------------------
# train Error: Avg loss: 1.250253
# Test Error: Avg loss: 51.530581
#
# Epoch 321
# -------------------------------
# train Error: Avg loss: 1.207970
# Test Error: Avg loss: 50.574921
#
# Epoch 322
# -------------------------------
# train Error: Avg loss: 1.294218
# Test Error: Avg loss: 52.187258
#
# Epoch 323
# -------------------------------
# train Error: Avg loss: 1.156046
# Test Error: Avg loss: 50.469810
#
# Epoch 324
# -------------------------------
# train Error: Avg loss: 1.169754
# Test Error: Avg loss: 51.626703
#
# Epoch 325
# -------------------------------
# train Error: Avg loss: 1.085711
# Test Error: Avg loss: 50.909455
#
# Epoch 326
# -------------------------------
# train Error: Avg loss: 1.084577
# Test Error: Avg loss: 51.051744
#
# Epoch 327
# -------------------------------
# train Error: Avg loss: 1.106594
# Test Error: Avg loss: 51.887052
#
# Epoch 328
# -------------------------------
# train Error: Avg loss: 1.134249
# Test Error: Avg loss: 50.969965
#
# Epoch 329
# -------------------------------
# train Error: Avg loss: 1.192901
# Test Error: Avg loss: 52.287234
#
# Epoch 330
# -------------------------------
# train Error: Avg loss: 1.169363
# Test Error: Avg loss: 51.261698
#
# Epoch 331
# -------------------------------
# train Error: Avg loss: 1.107340
# Test Error: Avg loss: 51.237020
#
# Epoch 332
# -------------------------------
# train Error: Avg loss: 1.117044
# Test Error: Avg loss: 51.497960
#
# Epoch 333
# -------------------------------
# train Error: Avg loss: 1.025790
# Test Error: Avg loss: 50.851620
#
# Epoch 334
# -------------------------------
# train Error: Avg loss: 1.012201
# Test Error: Avg loss: 51.374267
#
# Epoch 335
# -------------------------------
# train Error: Avg loss: 0.936050
# Test Error: Avg loss: 50.757836
#
# Epoch 336
# -------------------------------
# train Error: Avg loss: 0.913110
# Test Error: Avg loss: 50.850096
#
# Epoch 337
# -------------------------------
# train Error: Avg loss: 0.876680
# Test Error: Avg loss: 50.691272
#
# Epoch 338
# -------------------------------
# train Error: Avg loss: 0.878129
# Test Error: Avg loss: 50.872504
#
# Epoch 339
# -------------------------------
# train Error: Avg loss: 0.855249
# Test Error: Avg loss: 50.652539
#
# Epoch 340
# -------------------------------
# train Error: Avg loss: 0.869627
# Test Error: Avg loss: 50.887412
#
# Epoch 341
# -------------------------------
# train Error: Avg loss: 0.861998
# Test Error: Avg loss: 50.699754
#
# Epoch 342
# -------------------------------
# train Error: Avg loss: 0.896389
# Test Error: Avg loss: 51.063718
#
# Epoch 343
# -------------------------------
# train Error: Avg loss: 0.902075
# Test Error: Avg loss: 50.825155
#
# Epoch 344
# -------------------------------
# train Error: Avg loss: 0.971300
# Test Error: Avg loss: 51.305781
#
# Epoch 345
# -------------------------------
# train Error: Avg loss: 0.999921
# Test Error: Avg loss: 51.046664
#
# Epoch 346
# -------------------------------
# train Error: Avg loss: 1.156470
# Test Error: Avg loss: 51.585081
#
# Epoch 347
# -------------------------------
# train Error: Avg loss: 1.238943
# Test Error: Avg loss: 51.543015
#
# Epoch 348
# -------------------------------
# train Error: Avg loss: 1.607516
# Test Error: Avg loss: 52.907326
#
# Epoch 349
# -------------------------------
# train Error: Avg loss: 1.498277
# Test Error: Avg loss: 52.107215
#
# Epoch 350
# -------------------------------
# train Error: Avg loss: 1.511664
# Test Error: Avg loss: 53.936698
#
# Epoch 351
# -------------------------------
# train Error: Avg loss: 1.301985
# Test Error: Avg loss: 53.288977
#
# Epoch 352
# -------------------------------
# train Error: Avg loss: 1.043027
# Test Error: Avg loss: 52.233943
#
# Epoch 353
# -------------------------------
# train Error: Avg loss: 0.860274
# Test Error: Avg loss: 51.850111
#
# Epoch 354
# -------------------------------
# train Error: Avg loss: 0.800353
# Test Error: Avg loss: 51.538121
#
# Epoch 355
# -------------------------------
# train Error: Avg loss: 0.750797
# Test Error: Avg loss: 51.488969
#
# Epoch 356
# -------------------------------
# train Error: Avg loss: 0.733529
# Test Error: Avg loss: 51.553345
#
# Epoch 357
# -------------------------------
# train Error: Avg loss: 0.710125
# Test Error: Avg loss: 51.490447
#
# Epoch 358
# -------------------------------
# train Error: Avg loss: 0.702027
# Test Error: Avg loss: 51.546579
#
# Epoch 359
# -------------------------------
# train Error: Avg loss: 0.687394
# Test Error: Avg loss: 51.509688
#
# Epoch 360
# -------------------------------
# train Error: Avg loss: 0.681774
# Test Error: Avg loss: 51.566894
#
# Epoch 361
# -------------------------------
# train Error: Avg loss: 0.670776
# Test Error: Avg loss: 51.533017
#
# Epoch 362
# -------------------------------
# train Error: Avg loss: 0.666591
# Test Error: Avg loss: 51.609302
#
# Epoch 363
# -------------------------------
# train Error: Avg loss: 0.659319
# Test Error: Avg loss: 51.600447
#
# Epoch 364
# -------------------------------
# train Error: Avg loss: 0.662919
# Test Error: Avg loss: 51.704484
#
# Epoch 365
# -------------------------------
# train Error: Avg loss: 0.678162
# Test Error: Avg loss: 51.810398
#
# Epoch 366
# -------------------------------
# train Error: Avg loss: 0.712570
# Test Error: Avg loss: 51.839940
#
# Epoch 367
# -------------------------------
# train Error: Avg loss: 0.775328
# Test Error: Avg loss: 51.951128
#
# Epoch 368
# -------------------------------
# train Error: Avg loss: 0.944018
# Test Error: Avg loss: 52.474022
#
# Epoch 369
# -------------------------------
# train Error: Avg loss: 1.114584
# Test Error: Avg loss: 52.623579
#
# Epoch 370
# -------------------------------
# train Error: Avg loss: 1.418701
# Test Error: Avg loss: 53.503207
#
# Epoch 371
# -------------------------------
# train Error: Avg loss: 1.432666
# Test Error: Avg loss: 52.934814
#
# Epoch 372
# -------------------------------
# train Error: Avg loss: 1.670814
# Test Error: Avg loss: 55.194407
#
# Epoch 373
# -------------------------------
# train Error: Avg loss: 1.359010
# Test Error: Avg loss: 53.276207
#
# Epoch 374
# -------------------------------
# train Error: Avg loss: 1.173807
# Test Error: Avg loss: 54.729465
#
# Epoch 375
# -------------------------------
# train Error: Avg loss: 0.870328
# Test Error: Avg loss: 53.132095
#
# Epoch 376
# -------------------------------
# train Error: Avg loss: 0.762943
# Test Error: Avg loss: 52.755470
#
# Epoch 377
# -------------------------------
# train Error: Avg loss: 0.690847
# Test Error: Avg loss: 52.886247
#
# Epoch 378
# -------------------------------
# train Error: Avg loss: 0.663289
# Test Error: Avg loss: 52.853524
#
# Epoch 379
# -------------------------------
# train Error: Avg loss: 0.634347
# Test Error: Avg loss: 52.888193
#
# Epoch 380
# -------------------------------
# train Error: Avg loss: 0.625499
# Test Error: Avg loss: 52.874850
#
# Epoch 381
# -------------------------------
# train Error: Avg loss: 0.609323
# Test Error: Avg loss: 52.919490
#
# Epoch 382
# -------------------------------
# train Error: Avg loss: 0.668887
# Test Error: Avg loss: 52.849907
#
# Epoch 383
# -------------------------------
# train Error: Avg loss: 0.668787
# Test Error: Avg loss: 53.306758
#
# Epoch 384
# -------------------------------
# train Error: Avg loss: 0.671716
# Test Error: Avg loss: 52.869022
#
# Epoch 385
# -------------------------------
# train Error: Avg loss: 0.688902
# Test Error: Avg loss: 53.218982
#
# Epoch 386
# -------------------------------
# train Error: Avg loss: 0.738490
# Test Error: Avg loss: 53.213710
#
# Epoch 387
# -------------------------------
# train Error: Avg loss: 0.769445
# Test Error: Avg loss: 53.040176
#
# Epoch 388
# -------------------------------
# train Error: Avg loss: 0.841039
# Test Error: Avg loss: 53.706863
#
# Epoch 389
# -------------------------------
# train Error: Avg loss: 0.831553
# Test Error: Avg loss: 53.145836
#
# Epoch 390
# -------------------------------
# train Error: Avg loss: 0.880384
# Test Error: Avg loss: 53.924571
#
# Epoch 391
# -------------------------------
# train Error: Avg loss: 0.821521
# Test Error: Avg loss: 53.346433
#
# Epoch 392
# -------------------------------
# train Error: Avg loss: 0.838667
# Test Error: Avg loss: 53.931740
#
# Epoch 393
# -------------------------------
# train Error: Avg loss: 0.785762
# Test Error: Avg loss: 53.572174
#
# Epoch 394
# -------------------------------
# train Error: Avg loss: 0.788952
# Test Error: Avg loss: 53.903815
#
# Epoch 395
# -------------------------------
# train Error: Avg loss: 0.750779
# Test Error: Avg loss: 53.759782
#
# Epoch 396
# -------------------------------
# train Error: Avg loss: 0.754237
# Test Error: Avg loss: 53.953279
#
# Epoch 397
# -------------------------------
# train Error: Avg loss: 0.722968
# Test Error: Avg loss: 53.904015
#
# Epoch 398
# -------------------------------
# train Error: Avg loss: 0.731844
# Test Error: Avg loss: 54.063277
#
# Epoch 399
# -------------------------------
# train Error: Avg loss: 0.705055
# Test Error: Avg loss: 54.018919
#
# Epoch 400
# -------------------------------
# train Error: Avg loss: 0.719082
# Test Error: Avg loss: 54.183743
#
# Epoch 401
# -------------------------------
# train Error: Avg loss: 0.640721
# Test Error: Avg loss: 54.017590
#
# Epoch 402
# -------------------------------
# train Error: Avg loss: 0.578249
# Test Error: Avg loss: 53.969061
#
# Epoch 403
# -------------------------------
# train Error: Avg loss: 0.547117
# Test Error: Avg loss: 53.935829
#
# Epoch 404
# -------------------------------
# train Error: Avg loss: 0.532430
# Test Error: Avg loss: 53.911249
#
# Epoch 405
# -------------------------------
# train Error: Avg loss: 0.525035
# Test Error: Avg loss: 53.892195
#
# Epoch 406
# -------------------------------
# train Error: Avg loss: 0.520941
# Test Error: Avg loss: 53.876752
#
# Epoch 407
# -------------------------------
# train Error: Avg loss: 0.518370
# Test Error: Avg loss: 53.863738
#
# Epoch 408
# -------------------------------
# train Error: Avg loss: 0.516523
# Test Error: Avg loss: 53.852306
#
# Epoch 409
# -------------------------------
# train Error: Avg loss: 0.515033
# Test Error: Avg loss: 53.842058
#
# Epoch 410
# -------------------------------
# train Error: Avg loss: 0.513732
# Test Error: Avg loss: 53.832630
#
# Epoch 411
# -------------------------------
# train Error: Avg loss: 0.512538
# Test Error: Avg loss: 53.823761
#
# Epoch 412
# -------------------------------
# train Error: Avg loss: 0.511410
# Test Error: Avg loss: 53.815375
#
# Epoch 413
# -------------------------------
# train Error: Avg loss: 0.510328
# Test Error: Avg loss: 53.807314
#
# Epoch 414
# -------------------------------
# train Error: Avg loss: 0.509279
# Test Error: Avg loss: 53.799488
#
# Epoch 415
# -------------------------------
# train Error: Avg loss: 0.508256
# Test Error: Avg loss: 53.791892
#
# Epoch 416
# -------------------------------
# train Error: Avg loss: 0.507254
# Test Error: Avg loss: 53.784478
#
# Epoch 417
# -------------------------------
# train Error: Avg loss: 0.506270
# Test Error: Avg loss: 53.777239
#
# Epoch 418
# -------------------------------
# train Error: Avg loss: 0.505302
# Test Error: Avg loss: 53.770180
#
# Epoch 419
# -------------------------------
# train Error: Avg loss: 0.504349
# Test Error: Avg loss: 53.763258
#
# Epoch 420
# -------------------------------
# train Error: Avg loss: 0.503407
# Test Error: Avg loss: 53.756516
#
# Epoch 421
# -------------------------------
# train Error: Avg loss: 0.502477
# Test Error: Avg loss: 53.749919
#
# Epoch 422
# -------------------------------
# train Error: Avg loss: 0.501557
# Test Error: Avg loss: 53.743470
#
# Epoch 423
# -------------------------------
# train Error: Avg loss: 0.500645
# Test Error: Avg loss: 53.737163
#
# Epoch 424
# -------------------------------
# train Error: Avg loss: 0.499742
# Test Error: Avg loss: 53.731025
#
# Epoch 425
# -------------------------------
# train Error: Avg loss: 0.498846
# Test Error: Avg loss: 53.725037
#
# Epoch 426
# -------------------------------
# train Error: Avg loss: 0.497957
# Test Error: Avg loss: 53.719212
#
# Epoch 427
# -------------------------------
# train Error: Avg loss: 0.497073
# Test Error: Avg loss: 53.713562
#
# Epoch 428
# -------------------------------
# train Error: Avg loss: 0.496195
# Test Error: Avg loss: 53.708066
#
# Epoch 429
# -------------------------------
# train Error: Avg loss: 0.495322
# Test Error: Avg loss: 53.702727
#
# Epoch 430
# -------------------------------
# train Error: Avg loss: 0.494453
# Test Error: Avg loss: 53.697568
#
# Epoch 431
# -------------------------------
# train Error: Avg loss: 0.493588
# Test Error: Avg loss: 53.692558
#
# Epoch 432
# -------------------------------
# train Error: Avg loss: 0.492726
# Test Error: Avg loss: 53.687713
#
# Epoch 433
# -------------------------------
# train Error: Avg loss: 0.491867
# Test Error: Avg loss: 53.683028
#
# Epoch 434
# -------------------------------
# train Error: Avg loss: 0.491010
# Test Error: Avg loss: 53.678489
#
# Epoch 435
# -------------------------------
# train Error: Avg loss: 0.490156
# Test Error: Avg loss: 53.674108
#
# Epoch 436
# -------------------------------
# train Error: Avg loss: 0.489304
# Test Error: Avg loss: 53.669899
#
# Epoch 437
# -------------------------------
# train Error: Avg loss: 0.488454
# Test Error: Avg loss: 53.665862
#
# Epoch 438
# -------------------------------
# train Error: Avg loss: 0.487604
# Test Error: Avg loss: 53.661959
#
# Epoch 439
# -------------------------------
# train Error: Avg loss: 0.486757
# ...
# Test Error: Avg loss: 55.293682
#
# Epoch 1856
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1857
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1858
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1859
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1860
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1861
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1862
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1863
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1864
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1865
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1866
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1867
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1868
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1869
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1870
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1871
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1872
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1873
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1874
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1875
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1876
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1877
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1878
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1879
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1880
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1881
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1882
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1883
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1884
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1885
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1886
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1887
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1888
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1889
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1890
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1891
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1892
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1893
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1894
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1895
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1896
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1897
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1898
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1899
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1900
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1901
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1902
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1903
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1904
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1905
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1906
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1907
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1908
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1909
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1910
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1911
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1912
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1913
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1914
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1915
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1916
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1917
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1918
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1919
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1920
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1921
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1922
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1923
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1924
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1925
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1926
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1927
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1928
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1929
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1930
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1931
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1932
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1933
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1934
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1935
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1936
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1937
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1938
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1939
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1940
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1941
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1942
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1943
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1944
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1945
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1946
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1947
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1948
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1949
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1950
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1951
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1952
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1953
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1954
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1955
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1956
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1957
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1958
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1959
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1960
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1961
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1962
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1963
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1964
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1965
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1966
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1967
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1968
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1969
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1970
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1971
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1972
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1973
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1974
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1975
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1976
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1977
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1978
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1979
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1980
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1981
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1982
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1983
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1984
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1985
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1986
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1987
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1988
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1989
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1990
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1991
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1992
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1993
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1994
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1995
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1996
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1997
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1998
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 1999
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Epoch 2000
# -------------------------------
# train Error: Avg loss: 0.324294
# Test Error: Avg loss: 55.293682
#
# Done!

# %%
plt.plot(losses[20:], label='train loss')
plt.plot(val[20:], label='test loss')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
count =0
output = torch.tensor([])
model.eval()
with torch.no_grad():
    for X, y in train_loader:
        y_star = model(X)
        output = torch.cat((output, y_star), 0)
        
        #print(X.shape,y.shape )
        #print(X.shape)
#print(count)
plt.plot(y_train, label='Actual Close')
plt.plot(output, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()
output[2000],y_train[2000]
# Out:
# (tensor([94.4791]), array([94.77999878]))

# %%
output = torch.tensor([])
model.eval()
with torch.no_grad():
    for X, y in val_loader:
        y_star = model(X)
        output = torch.cat((output, y_star), 0)
        print(X.shape,y.shape )
plt.plot(y_val, label='Actual Close')
plt.plot(output, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()
# Out:
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([58, 5, 24]) torch.Size([58, 1])

# %%
for batch, (X, y) in enumerate(train_dataset):
    print( (X.shape, y.shape))
    print( batch,(X, y))
    break
# Out:
# (torch.Size([5, 24]), torch.Size([1]))
# 0 (tensor([[-0.7130, -0.7142, -0.7140, -0.7135, -0.5357,  0.7252,  0.6802,  0.1814,
#           1.1504,  0.8146, -0.3438, -0.6620,  1.1862, -1.1676, -0.2644, -0.7198,
#          -0.7174, -0.7146,  1.5675,  1.1005, -0.7179, -0.7160, -0.7142, -0.7135],
#         [-0.7130, -0.7142, -0.7140, -0.7135, -0.5357,  0.7252,  0.6802,  0.1814,
#           1.1504,  0.8146, -0.3438, -0.6620,  1.1862, -1.1676, -0.2644, -0.7198,
#          -0.7174, -0.7146,  1.5675,  1.1005, -0.7179, -0.7160, -0.7142, -0.7135],
#         [-0.7130, -0.7142, -0.7140, -0.7135, -0.5357,  0.7252,  0.6802,  0.1814,
#           1.1504,  0.8146, -0.3438, -0.6620,  1.1862, -1.1676, -0.2644, -0.7198,
#          -0.7174, -0.7146,  1.5675,  1.1005, -0.7179, -0.7160, -0.7142, -0.7135],
#         [-0.7130, -0.7142, -0.7140, -0.7135, -0.5357,  0.7252,  0.6802,  0.1814,
#           1.1504,  0.8146, -0.3438, -0.6620,  1.1862, -1.1676, -0.2644, -0.7198,
#          -0.7174, -0.7146,  1.5675,  1.1005, -0.7179, -0.7160, -0.7142, -0.7135],
#         [-0.7130, -0.7142, -0.7140, -0.7135, -0.5357,  0.7252,  0.6802,  0.1814,
#           1.1504,  0.8146, -0.3438, -0.6620,  1.1862, -1.1676, -0.2644, -0.7198,
#          -0.7174, -0.7146,  1.5675,  1.1005, -0.7179, -0.7160, -0.7142, -0.7135]]), tensor([2.4900]))

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(output,y_val))
# Out:
# 7.406041730924619

# %%
data = pd.read_csv('/Users/hieudao/Desktop/ai/do_an/clean_data/clean_amd.csv')
data['Date'] = pd.to_datetime(data['Date'])
data['Close+1'] = data['Close'].shift(-1)
data = data.dropna()

test = data[data['Date'] >= pd.to_datetime('2023-01-01 00:00:00-04:00')]
test = test.drop(columns=['Date','tema_8','tema_100'])
test
# Out:
#              Open        High         Low       Close    Volume    NATR_3  \
# 10673   66.000000   66.879997   63.590000   64.019997  46851800  4.110550
# 10674   65.000000   65.790001   63.310001   64.660004  47477100  3.952655
# 10675   64.150002   64.349998   62.299999   62.330002  46159500  3.943359
# 10676   63.150002   64.300003   60.049999   63.959999  70161300  5.243824
# 10677   66.220001   69.320000   65.669998   67.239998  69741300  6.479737
# ...           ...         ...         ...         ...       ...       ...
# 10795  112.070000  112.760002  109.839996  111.239998  58347200  3.230614
# 10796  113.029999  114.690002  112.410004  113.910004  53331900  3.091800
# 10797  115.160004  116.730003  114.510002  115.820000  31860000  2.737813
# 10798  116.099998  117.660004  113.860001  113.949997  49501600  3.058771
# 10799  112.070000  113.790001  110.309998  113.480003  42342000  3.139526
#
#            RSI_3      ADX_3  CCI_3_0.015     ROC_3  ...   BBL_3_2.0  \
# 10673  43.227376  40.566151   100.000000  2.317400  ...   63.804846
# 10674  57.191880  42.429407    10.753448 -0.246831  ...   63.821951
# 10675  24.407318  30.501317  -100.000000 -3.767168  ...   61.704227
# 10676  52.799692  39.568982   -59.824010 -0.093717  ...   61.697703
# 10677  77.878709  41.140061   100.000000  3.990093  ...   60.426246
# ...          ...        ...          ...       ...  ...         ...
# 10795  53.049678  36.721870   100.000000  3.469441  ...  109.677250
# 10796  74.737893  41.386671   100.000000  3.188699  ...  108.627862
# 10797  83.109892  51.287612    94.507029  5.128439  ...  109.899988
# 10798  55.902291  60.012046    27.307241  2.436173  ...  112.777792
# 10799  49.760901  47.188927  -100.000000 -0.377491  ...  112.395293
#
#         BBM_3_2.0   BBU_3_2.0  BBB_3_2.0  BBP_3_2.0  min_price_3  max_price_3  \
# 10673   64.536664   65.268483   2.267915   0.146997    63.060001    66.879997
# 10674   64.483332   65.144714   2.051326   0.633562    63.139999    66.879997
# 10675   63.670001   65.635775   6.174882   0.159168    62.299999    66.879997
# 10676   63.650002   65.602300   6.134481   0.579393    60.049999    65.790001
# 10677   64.510000   68.593753  12.660838   0.834251    60.049999    69.320000
# ...           ...         ...        ...        ...          ...          ...
# 10795  110.599998  111.522747   1.668624   0.846790   107.080002   112.760002
# 10796  111.773333  114.918804   5.628303   0.839642   107.629997   114.690002
# 10797  113.656667  117.413346   6.610574   0.787932   109.839996   116.730003
# 10798  114.560000  116.342208   3.111396   0.328863   112.410004   117.660004
# 10799  114.416667  116.438040   3.533355   0.268310   110.309998   117.660004
#
#         mid_price      tema_2     Close+1
# 10673   65.234999   64.082512   64.660004
# 10674   64.550001   64.613013   62.330002
# 10675   63.324999   62.426739   63.959999
# 10676   62.175001   63.818048   67.239998
# 10677   67.494999   67.149616   68.050003
# ...           ...         ...         ...
# 10795  111.299999  111.254857  113.910004
# 10796  113.550003  113.867390  115.820000
# 10797  115.620003  115.864276  113.949997
# 10798  115.760002  114.120879  113.480003
# 10799  112.049999  113.442697  113.169998
#
# [127 rows x 25 columns]

# %%
X_test = test.copy().drop(columns=['Close+1'])
y_test = pd.DataFrame()
y_test['Close+1'] = test[['Close+1']]

#X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

X_test_scaled = scaler.transform(X_test)

test_dataset = TimeSeriesDataset(X_test_scaled,y_test,sequence_length=sequence_length)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)


output = torch.tensor([])
model.eval()
with torch.no_grad():
    for X, y in test_loader:
        y_star = model(X)
        output = torch.cat((output, y_star), 0)
        
        print(X.shape,y.shape )
#print(count)
plt.plot(y_test, label='Actual Close')
plt.plot(output, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()
np.sqrt(mean_squared_error(output,y_test))
# Out:
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([63, 5, 24]) torch.Size([63, 1])
# /usr/local/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 6.692922706219832

# %%
(np.abs(output-y_test)/y_test).mean()*100
# Out:
# tensor(5.5877, dtype=torch.float64)
