# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import random
random.seed(0)
import torch
torch.manual_seed(0)
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
data = pd.read_csv('/Users/hieudao/Desktop/ai/do_an/clean_data/clean_amd.csv')

# %%
data['Date'] = pd.to_datetime(data['Date'])
data = data[ data['Date'] < pd.to_datetime('2023-01-01 00:00:00-04:00')]
data = data[ data['Date'] >= pd.to_datetime('2013-01-01 00:00:00-04:00')]
data['Close+1'] = data['Close'].shift(-1)
data = data.dropna()
data.tail(3)
# Out:
#                             Date       Open       High        Low  Close  \
# 10669  2022-12-27 00:00:00-05:00  63.869999  64.279999  62.970001  63.27
# 10670  2022-12-28 00:00:00-05:00  62.540001  63.540001  61.959999  62.57
# 10671  2022-12-29 00:00:00-05:00  63.639999  65.180000  63.060001  64.82
#
#          Volume    NATR_3      RSI_3      ADX_3  CCI_3_0.015  ...  BBU_3_2.0  \
# 10669  36086000  3.580215  28.581375  40.744299       -100.0  ...  64.904483
# 10670  39526500  3.072722  23.469149  48.356896       -100.0  ...  65.066470
# 10671  41428500  3.496299  58.907116  36.887101        100.0  ...  65.433640
#
#        BBB_3_2.0  BBP_3_2.0  min_price_3  max_price_3  mid_price     tema_2  \
# 10669   3.196924   0.199686    62.259998    66.309998  63.625000  63.296061
# 10670   5.084485   0.226207    61.959999    64.660004  62.750000  62.554867
# 10671   5.917257   0.836824    61.959999    65.180000  64.120001  64.702822
#
#         tema_100     tema_8    Close+1
# 10669  64.069522  63.354633  62.570000
# 10670  63.816341  62.618721  64.820000
# 10671  63.707736  63.450099  64.769997
#
# [3 rows x 28 columns]

# %%
data = data.drop(columns=['tema_2', 'tema_100'])
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'NATR_3', 'RSI_3',
#        'ADX_3', 'CCI_3_0.015', 'ROC_3', 'STOCHk_14_3_3', 'STOCHd_14_3_3',
#        'WILLR_3', 'OBV', 'MACD_12_26_9', 'BBL_3_2.0', 'BBM_3_2.0', 'BBU_3_2.0',
#        'BBB_3_2.0', 'BBP_3_2.0', 'min_price_3', 'max_price_3', 'mid_price',
#        'tema_8', 'Close+1'],
#       dtype='object')

# %%
train = data[data['Date'] < pd.to_datetime('2022-01-01 00:00:00-04:00')]

val = data[data['Date'] < pd.to_datetime('2023-01-01 00:00:00-04:00')]
val = data[data['Date'] >= pd.to_datetime('2022-01-01 00:00:00-04:00')]

train = train.drop(columns=['Date'])
val = val.drop(columns=['Date'])


X_train = train.copy().drop(columns=['Close+1'])
y_train = pd.DataFrame()
y_train['Close+1'] = train[['Close+1']]

X_val = val.copy().drop(columns=['Close+1'])
y_val = pd.DataFrame()
y_val['Close+1'] = val[['Close+1']]
X_train.shape,X_val.shape,y_train.shape,y_val.shape
# Out:
# ((2266, 24), (250, 24), (2266, 1), (250, 1))

# %%
X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
X_val = X_val.to_numpy()
y_val = y_val.to_numpy()
X_train.shape, X_val.shape
# Out:
# ((2266, 24), (250, 24))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_train_scaled.shape, X_val_scaled.shape
# Out:
# ((2266, 24), (250, 24))

# %%
from torch.utils.data import DataLoader,Dataset
sequence_length= 5
class TimeSeriesDataset(Dataset):
    def __init__(self, X, y,sequence_length=5):
        self.X =  torch.tensor(X).float()
        self.y = torch.tensor(y).float()
        self.sequence_length = sequence_length
    def __len__(self):
        return len(self.X)

    def __getitem__(self, i): 
       
        if i >= self.sequence_length - 1:
            i_start = i - self.sequence_length + 1
            x = self.X[i_start:(i + 1), :]
        elif self.sequence_length==1:
            return self.X[i],self.y[i]
        else:
            padding = self.X[0].repeat(self.sequence_length - i - 1, 1)
            x = self.X[0:(i + 1), :]
            #print(padding.shape, x.shape)
            x = torch.cat((padding, x), 0)
            # x = self.X[0:i, :]
            #print(x.shape,padding.shape)

        return x, self.y[i]
       
train_dataset = TimeSeriesDataset(X_train_scaled, y_train, sequence_length=sequence_length)
val_dataset = TimeSeriesDataset(X_val_scaled, y_val, sequence_length=sequence_length)

# %%
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers,batch_first=True)

        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

model = LSTM(24, 64, 2)
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(24, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
losses = []
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    # Set the model to training mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.train()
    train_loss = 0
    num_batches = len(dataloader)

    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)
        train_loss += loss.item()
        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            #print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    print(f"train Error: Avg loss: {train_loss/num_batches:>8f}")
    losses.append((train_loss/num_batches))

# %%
val = []
def test_loop(dataloader, model, loss_fn):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    
    val.append(test_loss)
    
    scheduler.step()
    #curr_lr = optimizer.param_groups[0]['lr']

    print(f"Test Error: Avg loss: {test_loss:>8f}  \n")

# %%
from torch.optim.lr_scheduler import StepLR

learning_rate = 0.01
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = StepLR(optimizer, step_size=200, gamma=0.1)

epochs = 2000
for t in range(epochs):
    if epochs %100==0:
        
        print(f"Epoch {t+1}\n-------------------------------")
    
    train_loop(train_loader, model, loss_fn, optimizer)
    test_loop(val_loader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# train Error: Avg loss: 1782.213373
# Test Error: Avg loss: 6563.466797
#
# Epoch 2
# -------------------------------
# train Error: Avg loss: 1413.012000
# Test Error: Avg loss: 5158.641449
#
# Epoch 3
# -------------------------------
# train Error: Avg loss: 1196.707386
# Test Error: Avg loss: 4154.882111
#
# Epoch 4
# -------------------------------
# train Error: Avg loss: 935.559313
# Test Error: Avg loss: 3313.110046
#
# Epoch 5
# -------------------------------
# train Error: Avg loss: 777.269849
# Test Error: Avg loss: 2657.465729
#
# Epoch 6
# -------------------------------
# train Error: Avg loss: 674.767321
# Test Error: Avg loss: 2267.684143
#
# Epoch 7
# -------------------------------
# train Error: Avg loss: 553.151616
# Test Error: Avg loss: 1768.372639
#
# Epoch 8
# -------------------------------
# train Error: Avg loss: 490.863775
# Test Error: Avg loss: 1465.229687
#
# Epoch 9
# -------------------------------
# train Error: Avg loss: 420.333926
# Test Error: Avg loss: 1084.645104
#
# Epoch 10
# -------------------------------
# train Error: Avg loss: 341.906819
# Test Error: Avg loss: 896.934896
#
# Epoch 11
# -------------------------------
# train Error: Avg loss: 309.479742
# Test Error: Avg loss: 705.659866
#
# Epoch 12
# -------------------------------
# train Error: Avg loss: 278.825712
# Test Error: Avg loss: 610.900799
#
# Epoch 13
# -------------------------------
# train Error: Avg loss: 213.338884
# Test Error: Avg loss: 516.139603
#
# Epoch 14
# -------------------------------
# train Error: Avg loss: 187.533559
# Test Error: Avg loss: 419.464857
#
# Epoch 15
# -------------------------------
# train Error: Avg loss: 171.148354
# Test Error: Avg loss: 331.083800
#
# Epoch 16
# -------------------------------
# train Error: Avg loss: 158.185869
# Test Error: Avg loss: 294.024343
#
# Epoch 17
# -------------------------------
# train Error: Avg loss: 140.238009
# Test Error: Avg loss: 423.408550
#
# Epoch 18
# -------------------------------
# train Error: Avg loss: 131.587617
# Test Error: Avg loss: 294.700253
#
# Epoch 19
# -------------------------------
# train Error: Avg loss: 121.463977
# Test Error: Avg loss: 280.006028
#
# Epoch 20
# -------------------------------
# train Error: Avg loss: 212.580275
# Test Error: Avg loss: 608.426720
#
# Epoch 21
# -------------------------------
# train Error: Avg loss: 159.682280
# Test Error: Avg loss: 444.885115
#
# Epoch 22
# -------------------------------
# train Error: Avg loss: 425.799105
# Test Error: Avg loss: 655.492413
#
# Epoch 23
# -------------------------------
# train Error: Avg loss: 203.424602
# Test Error: Avg loss: 442.936401
#
# Epoch 24
# -------------------------------
# train Error: Avg loss: 197.660340
# Test Error: Avg loss: 381.854824
#
# Epoch 25
# -------------------------------
# train Error: Avg loss: 146.346080
# Test Error: Avg loss: 280.049590
#
# Epoch 26
# -------------------------------
# train Error: Avg loss: 135.658987
# Test Error: Avg loss: 261.653095
#
# Epoch 27
# -------------------------------
# train Error: Avg loss: 116.043734
# Test Error: Avg loss: 226.857960
#
# Epoch 28
# -------------------------------
# train Error: Avg loss: 119.122130
# Test Error: Avg loss: 253.697763
#
# Epoch 29
# -------------------------------
# train Error: Avg loss: 107.694062
# Test Error: Avg loss: 253.073508
#
# Epoch 30
# -------------------------------
# train Error: Avg loss: 110.486805
# Test Error: Avg loss: 210.502842
#
# Epoch 31
# -------------------------------
# train Error: Avg loss: 104.108304
# Test Error: Avg loss: 230.908989
#
# Epoch 32
# -------------------------------
# train Error: Avg loss: 98.414491
# Test Error: Avg loss: 163.181461
#
# Epoch 33
# -------------------------------
# train Error: Avg loss: 99.080342
# Test Error: Avg loss: 276.064785
#
# Epoch 34
# -------------------------------
# train Error: Avg loss: 109.829576
# Test Error: Avg loss: 175.886306
#
# Epoch 35
# -------------------------------
# train Error: Avg loss: 82.172663
# Test Error: Avg loss: 198.722641
#
# Epoch 36
# -------------------------------
# train Error: Avg loss: 69.534018
# Test Error: Avg loss: 172.118204
#
# Epoch 37
# -------------------------------
# train Error: Avg loss: 60.236543
# Test Error: Avg loss: 134.527740
#
# Epoch 38
# -------------------------------
# train Error: Avg loss: 54.548256
# Test Error: Avg loss: 123.046557
#
# Epoch 39
# -------------------------------
# train Error: Avg loss: 48.864746
# Test Error: Avg loss: 92.848781
#
# Epoch 40
# -------------------------------
# train Error: Avg loss: 55.361727
# Test Error: Avg loss: 161.098130
#
# Epoch 41
# -------------------------------
# train Error: Avg loss: 66.174306
# Test Error: Avg loss: 247.448959
#
# Epoch 42
# -------------------------------
# train Error: Avg loss: 115.630221
# Test Error: Avg loss: 270.571491
#
# Epoch 43
# -------------------------------
# train Error: Avg loss: 218.101237
# Test Error: Avg loss: 254.194118
#
# Epoch 44
# -------------------------------
# train Error: Avg loss: 196.864012
# Test Error: Avg loss: 397.744362
#
# Epoch 45
# -------------------------------
# train Error: Avg loss: 269.175918
# Test Error: Avg loss: 326.762543
#
# Epoch 46
# -------------------------------
# train Error: Avg loss: 213.185627
# Test Error: Avg loss: 325.226013
#
# Epoch 47
# -------------------------------
# train Error: Avg loss: 127.303944
# Test Error: Avg loss: 156.759541
#
# Epoch 48
# -------------------------------
# train Error: Avg loss: 92.624894
# Test Error: Avg loss: 155.799852
#
# Epoch 49
# -------------------------------
# train Error: Avg loss: 68.945624
# Test Error: Avg loss: 160.351229
#
# Epoch 50
# -------------------------------
# train Error: Avg loss: 63.308857
# Test Error: Avg loss: 130.409513
#
# Epoch 51
# -------------------------------
# train Error: Avg loss: 53.719186
# Test Error: Avg loss: 147.756756
#
# Epoch 52
# -------------------------------
# train Error: Avg loss: 46.271241
# Test Error: Avg loss: 103.812881
#
# Epoch 53
# -------------------------------
# train Error: Avg loss: 41.583248
# Test Error: Avg loss: 100.092316
#
# Epoch 54
# -------------------------------
# train Error: Avg loss: 36.982975
# Test Error: Avg loss: 81.703395
#
# Epoch 55
# -------------------------------
# train Error: Avg loss: 33.500221
# Test Error: Avg loss: 76.959888
#
# Epoch 56
# -------------------------------
# train Error: Avg loss: 33.516421
# Test Error: Avg loss: 81.100280
#
# Epoch 57
# -------------------------------
# train Error: Avg loss: 28.147556
# Test Error: Avg loss: 87.754451
#
# Epoch 58
# -------------------------------
# train Error: Avg loss: 27.152026
# Test Error: Avg loss: 71.270316
#
# Epoch 59
# -------------------------------
# train Error: Avg loss: 32.549835
# Test Error: Avg loss: 102.879716
#
# Epoch 60
# -------------------------------
# train Error: Avg loss: 48.895109
# Test Error: Avg loss: 90.385796
#
# Epoch 61
# -------------------------------
# train Error: Avg loss: 90.231658
# Test Error: Avg loss: 271.668434
#
# Epoch 62
# -------------------------------
# train Error: Avg loss: 35.478422
# Test Error: Avg loss: 51.509434
#
# Epoch 63
# -------------------------------
# train Error: Avg loss: 21.597364
# Test Error: Avg loss: 50.038391
#
# Epoch 64
# -------------------------------
# train Error: Avg loss: 24.273226
# Test Error: Avg loss: 66.995255
#
# Epoch 65
# -------------------------------
# train Error: Avg loss: 33.122377
# Test Error: Avg loss: 144.440684
#
# Epoch 66
# -------------------------------
# train Error: Avg loss: 25.912224
# Test Error: Avg loss: 80.358046
#
# Epoch 67
# -------------------------------
# train Error: Avg loss: 27.134812
# Test Error: Avg loss: 161.465630
#
# Epoch 68
# -------------------------------
# train Error: Avg loss: 19.111721
# Test Error: Avg loss: 64.890825
#
# Epoch 69
# -------------------------------
# train Error: Avg loss: 13.339563
# Test Error: Avg loss: 60.704923
#
# Epoch 70
# -------------------------------
# train Error: Avg loss: 12.710053
# Test Error: Avg loss: 76.071359
#
# Epoch 71
# -------------------------------
# train Error: Avg loss: 13.773988
# Test Error: Avg loss: 82.257364
#
# Epoch 72
# -------------------------------
# train Error: Avg loss: 13.132502
# Test Error: Avg loss: 82.409729
#
# Epoch 73
# -------------------------------
# train Error: Avg loss: 22.364154
# Test Error: Avg loss: 128.140064
#
# Epoch 74
# -------------------------------
# train Error: Avg loss: 18.203022
# Test Error: Avg loss: 64.351789
#
# Epoch 75
# -------------------------------
# train Error: Avg loss: 20.170546
# Test Error: Avg loss: 144.080450
#
# Epoch 76
# -------------------------------
# train Error: Avg loss: 14.363735
# Test Error: Avg loss: 53.357968
#
# Epoch 77
# -------------------------------
# train Error: Avg loss: 10.565901
# Test Error: Avg loss: 60.027957
#
# Epoch 78
# -------------------------------
# train Error: Avg loss: 9.219882
# Test Error: Avg loss: 46.422637
#
# Epoch 79
# -------------------------------
# train Error: Avg loss: 9.952807
# Test Error: Avg loss: 69.837157
#
# Epoch 80
# -------------------------------
# train Error: Avg loss: 7.935193
# Test Error: Avg loss: 45.364812
#
# Epoch 81
# -------------------------------
# train Error: Avg loss: 10.171534
# Test Error: Avg loss: 61.746912
#
# Epoch 82
# -------------------------------
# train Error: Avg loss: 10.480433
# Test Error: Avg loss: 52.986156
#
# Epoch 83
# -------------------------------
# train Error: Avg loss: 14.992918
# Test Error: Avg loss: 100.486637
#
# Epoch 84
# -------------------------------
# train Error: Avg loss: 11.042045
# Test Error: Avg loss: 54.047208
#
# Epoch 85
# -------------------------------
# train Error: Avg loss: 20.421665
# Test Error: Avg loss: 127.166185
#
# Epoch 86
# -------------------------------
# train Error: Avg loss: 12.309933
# Test Error: Avg loss: 62.968037
#
# Epoch 87
# -------------------------------
# train Error: Avg loss: 10.646908
# Test Error: Avg loss: 64.844660
#
# Epoch 88
# -------------------------------
# train Error: Avg loss: 8.958074
# Test Error: Avg loss: 75.533635
#
# Epoch 89
# -------------------------------
# train Error: Avg loss: 7.426386
# Test Error: Avg loss: 68.302386
#
# Epoch 90
# -------------------------------
# train Error: Avg loss: 5.919132
# Test Error: Avg loss: 63.132019
#
# Epoch 91
# -------------------------------
# train Error: Avg loss: 6.553803
# Test Error: Avg loss: 66.298141
#
# Epoch 92
# -------------------------------
# train Error: Avg loss: 5.955560
# Test Error: Avg loss: 72.889227
#
# Epoch 93
# -------------------------------
# train Error: Avg loss: 5.771049
# Test Error: Avg loss: 65.347295
#
# Epoch 94
# -------------------------------
# train Error: Avg loss: 7.727772
# Test Error: Avg loss: 73.302499
#
# Epoch 95
# -------------------------------
# train Error: Avg loss: 10.432054
# Test Error: Avg loss: 72.433698
#
# Epoch 96
# -------------------------------
# train Error: Avg loss: 21.790231
# Test Error: Avg loss: 140.914314
#
# Epoch 97
# -------------------------------
# train Error: Avg loss: 11.939648
# Test Error: Avg loss: 66.507164
#
# Epoch 98
# -------------------------------
# train Error: Avg loss: 14.400815
# Test Error: Avg loss: 100.462998
#
# Epoch 99
# -------------------------------
# train Error: Avg loss: 9.062309
# Test Error: Avg loss: 54.341865
#
# Epoch 100
# -------------------------------
# train Error: Avg loss: 8.780570
# Test Error: Avg loss: 60.199848
#
# Epoch 101
# -------------------------------
# train Error: Avg loss: 6.903582
# Test Error: Avg loss: 54.893272
#
# Epoch 102
# -------------------------------
# train Error: Avg loss: 5.885211
# Test Error: Avg loss: 54.211759
#
# Epoch 103
# -------------------------------
# train Error: Avg loss: 5.093068
# Test Error: Avg loss: 51.043717
#
# Epoch 104
# -------------------------------
# train Error: Avg loss: 4.963823
# Test Error: Avg loss: 51.542150
#
# Epoch 105
# -------------------------------
# train Error: Avg loss: 6.110090
# Test Error: Avg loss: 55.582307
#
# Epoch 106
# -------------------------------
# train Error: Avg loss: 7.172034
# Test Error: Avg loss: 73.923932
#
# Epoch 107
# -------------------------------
# train Error: Avg loss: 7.750858
# Test Error: Avg loss: 55.405137
#
# Epoch 108
# -------------------------------
# train Error: Avg loss: 11.756057
# Test Error: Avg loss: 64.402974
#
# Epoch 109
# -------------------------------
# train Error: Avg loss: 27.596110
# Test Error: Avg loss: 72.741323
#
# Epoch 110
# -------------------------------
# train Error: Avg loss: 35.136076
# Test Error: Avg loss: 220.152208
#
# Epoch 111
# -------------------------------
# train Error: Avg loss: 23.694872
# Test Error: Avg loss: 161.997704
#
# Epoch 112
# -------------------------------
# train Error: Avg loss: 69.716415
# Test Error: Avg loss: 120.223344
#
# Epoch 113
# -------------------------------
# train Error: Avg loss: 119.974858
# Test Error: Avg loss: 551.080444
#
# Epoch 114
# -------------------------------
# train Error: Avg loss: 622.337383
# Test Error: Avg loss: 1658.725788
#
# Epoch 115
# -------------------------------
# train Error: Avg loss: 88.704850
# Test Error: Avg loss: 83.790582
#
# Epoch 116
# -------------------------------
# train Error: Avg loss: 131.984118
# Test Error: Avg loss: 83.081371
#
# Epoch 117
# -------------------------------
# train Error: Avg loss: 137.712777
# Test Error: Avg loss: 192.130390
#
# Epoch 118
# -------------------------------
# train Error: Avg loss: 72.003154
# Test Error: Avg loss: 94.442097
#
# Epoch 119
# -------------------------------
# train Error: Avg loss: 16.409468
# Test Error: Avg loss: 71.042510
#
# Epoch 120
# -------------------------------
# train Error: Avg loss: 9.464330
# Test Error: Avg loss: 57.930156
#
# Epoch 121
# -------------------------------
# train Error: Avg loss: 8.695734
# Test Error: Avg loss: 65.486142
#
# Epoch 122
# -------------------------------
# train Error: Avg loss: 7.479107
# Test Error: Avg loss: 56.242582
#
# Epoch 123
# -------------------------------
# train Error: Avg loss: 6.888007
# Test Error: Avg loss: 58.338974
#
# Epoch 124
# -------------------------------
# train Error: Avg loss: 6.352155
# Test Error: Avg loss: 54.032753
#
# Epoch 125
# -------------------------------
# train Error: Avg loss: 6.041700
# Test Error: Avg loss: 58.132464
#
# Epoch 126
# -------------------------------
# train Error: Avg loss: 5.459295
# Test Error: Avg loss: 52.206954
#
# Epoch 127
# -------------------------------
# train Error: Avg loss: 5.018324
# Test Error: Avg loss: 55.551266
#
# Epoch 128
# -------------------------------
# train Error: Avg loss: 4.670178
# Test Error: Avg loss: 52.555005
#
# Epoch 129
# -------------------------------
# train Error: Avg loss: 4.445070
# Test Error: Avg loss: 52.802088
#
# Epoch 130
# -------------------------------
# train Error: Avg loss: 4.170605
# Test Error: Avg loss: 52.760986
#
# Epoch 131
# -------------------------------
# train Error: Avg loss: 4.080849
# Test Error: Avg loss: 52.041630
#
# Epoch 132
# -------------------------------
# train Error: Avg loss: 3.907061
# Test Error: Avg loss: 52.019517
#
# Epoch 133
# -------------------------------
# train Error: Avg loss: 3.867506
# Test Error: Avg loss: 51.100729
#
# Epoch 134
# -------------------------------
# train Error: Avg loss: 3.936549
# Test Error: Avg loss: 51.849821
#
# Epoch 135
# -------------------------------
# train Error: Avg loss: 4.147760
# Test Error: Avg loss: 50.183564
#
# Epoch 136
# -------------------------------
# train Error: Avg loss: 4.756346
# Test Error: Avg loss: 51.264668
#
# Epoch 137
# -------------------------------
# train Error: Avg loss: 5.927483
# Test Error: Avg loss: 53.193774
#
# Epoch 138
# -------------------------------
# train Error: Avg loss: 9.985610
# Test Error: Avg loss: 56.157021
#
# Epoch 139
# -------------------------------
# train Error: Avg loss: 19.232137
# Test Error: Avg loss: 115.645025
#
# Epoch 140
# -------------------------------
# train Error: Avg loss: 11.452599
# Test Error: Avg loss: 58.293389
#
# Epoch 141
# -------------------------------
# train Error: Avg loss: 7.913407
# Test Error: Avg loss: 63.135940
#
# Epoch 142
# -------------------------------
# train Error: Avg loss: 7.180846
# Test Error: Avg loss: 46.609006
#
# Epoch 143
# -------------------------------
# train Error: Avg loss: 6.207474
# Test Error: Avg loss: 65.100912
#
# Epoch 144
# -------------------------------
# train Error: Avg loss: 5.135842
# Test Error: Avg loss: 49.114928
#
# Epoch 145
# -------------------------------
# train Error: Avg loss: 3.927749
# Test Error: Avg loss: 56.755786
#
# Epoch 146
# -------------------------------
# train Error: Avg loss: 3.572687
# Test Error: Avg loss: 51.202388
#
# Epoch 147
# -------------------------------
# train Error: Avg loss: 3.288779
# Test Error: Avg loss: 50.107784
#
# Epoch 148
# -------------------------------
# train Error: Avg loss: 3.014513
# Test Error: Avg loss: 48.325972
#
# Epoch 149
# -------------------------------
# train Error: Avg loss: 3.114031
# Test Error: Avg loss: 48.378549
#
# Epoch 150
# -------------------------------
# train Error: Avg loss: 3.113468
# Test Error: Avg loss: 49.168801
#
# Epoch 151
# -------------------------------
# train Error: Avg loss: 2.975052
# Test Error: Avg loss: 46.770412
#
# Epoch 152
# -------------------------------
# train Error: Avg loss: 3.128314
# Test Error: Avg loss: 45.947636
#
# Epoch 153
# -------------------------------
# train Error: Avg loss: 3.514541
# Test Error: Avg loss: 49.333434
#
# Epoch 154
# -------------------------------
# train Error: Avg loss: 3.624245
# Test Error: Avg loss: 44.948215
#
# Epoch 155
# -------------------------------
# train Error: Avg loss: 3.585891
# Test Error: Avg loss: 47.876766
#
# Epoch 156
# -------------------------------
# train Error: Avg loss: 3.807664
# Test Error: Avg loss: 47.536925
#
# Epoch 157
# -------------------------------
# train Error: Avg loss: 5.199045
# Test Error: Avg loss: 52.835138
#
# Epoch 158
# -------------------------------
# train Error: Avg loss: 5.785596
# Test Error: Avg loss: 50.154989
#
# Epoch 159
# -------------------------------
# train Error: Avg loss: 9.363810
# Test Error: Avg loss: 60.950965
#
# Epoch 160
# -------------------------------
# train Error: Avg loss: 15.998472
# Test Error: Avg loss: 66.850739
#
# Epoch 161
# -------------------------------
# train Error: Avg loss: 31.056773
# Test Error: Avg loss: 174.160287
#
# Epoch 162
# -------------------------------
# train Error: Avg loss: 19.658348
# Test Error: Avg loss: 98.943150
#
# Epoch 163
# -------------------------------
# train Error: Avg loss: 15.863439
# Test Error: Avg loss: 80.590085
#
# Epoch 164
# -------------------------------
# train Error: Avg loss: 19.726984
# Test Error: Avg loss: 64.429437
#
# Epoch 165
# -------------------------------
# train Error: Avg loss: 75.767381
# Test Error: Avg loss: 168.287914
#
# Epoch 166
# -------------------------------
# train Error: Avg loss: 34.248586
# Test Error: Avg loss: 84.508110
#
# Epoch 167
# -------------------------------
# train Error: Avg loss: 26.702315
# Test Error: Avg loss: 170.630474
#
# Epoch 168
# -------------------------------
# train Error: Avg loss: 12.178424
# Test Error: Avg loss: 100.872716
#
# Epoch 169
# -------------------------------
# train Error: Avg loss: 6.446710
# Test Error: Avg loss: 82.719170
#
# Epoch 170
# -------------------------------
# train Error: Avg loss: 5.013795
# Test Error: Avg loss: 91.763009
#
# Epoch 171
# -------------------------------
# train Error: Avg loss: 4.562246
# Test Error: Avg loss: 67.655404
#
# Epoch 172
# -------------------------------
# train Error: Avg loss: 4.346080
# Test Error: Avg loss: 72.060130
#
# Epoch 173
# -------------------------------
# train Error: Avg loss: 4.216015
# Test Error: Avg loss: 62.915242
#
# Epoch 174
# -------------------------------
# train Error: Avg loss: 4.287411
# Test Error: Avg loss: 65.298054
#
# Epoch 175
# -------------------------------
# train Error: Avg loss: 3.306217
# Test Error: Avg loss: 59.862576
#
# Epoch 176
# -------------------------------
# train Error: Avg loss: 4.020829
# Test Error: Avg loss: 72.271999
#
# Epoch 177
# -------------------------------
# train Error: Avg loss: 3.707170
# Test Error: Avg loss: 61.035057
#
# Epoch 178
# -------------------------------
# train Error: Avg loss: 3.374224
# Test Error: Avg loss: 66.321595
#
# Epoch 179
# -------------------------------
# train Error: Avg loss: 3.222608
# Test Error: Avg loss: 60.508423
#
# Epoch 180
# -------------------------------
# train Error: Avg loss: 3.485718
# Test Error: Avg loss: 63.942224
#
# Epoch 181
# -------------------------------
# train Error: Avg loss: 3.610029
# Test Error: Avg loss: 56.138361
#
# Epoch 182
# -------------------------------
# train Error: Avg loss: 4.261687
# Test Error: Avg loss: 67.535694
#
# Epoch 183
# -------------------------------
# train Error: Avg loss: 4.089929
# Test Error: Avg loss: 59.135786
#
# Epoch 184
# -------------------------------
# train Error: Avg loss: 3.702953
# Test Error: Avg loss: 59.336580
#
# Epoch 185
# -------------------------------
# train Error: Avg loss: 3.778078
# Test Error: Avg loss: 53.245680
#
# Epoch 186
# -------------------------------
# train Error: Avg loss: 4.314664
# Test Error: Avg loss: 59.264069
#
# Epoch 187
# -------------------------------
# train Error: Avg loss: 4.313731
# Test Error: Avg loss: 55.643833
#
# Epoch 188
# -------------------------------
# train Error: Avg loss: 4.382396
# Test Error: Avg loss: 65.040216
#
# Epoch 189
# -------------------------------
# train Error: Avg loss: 3.009855
# Test Error: Avg loss: 56.443871
#
# Epoch 190
# -------------------------------
# train Error: Avg loss: 2.682117
# Test Error: Avg loss: 55.851251
#
# Epoch 191
# -------------------------------
# train Error: Avg loss: 2.280969
# Test Error: Avg loss: 53.883475
#
# Epoch 192
# -------------------------------
# train Error: Avg loss: 2.005917
# Test Error: Avg loss: 54.176016
#
# Epoch 193
# -------------------------------
# train Error: Avg loss: 1.960087
# Test Error: Avg loss: 53.437032
#
# Epoch 194
# -------------------------------
# train Error: Avg loss: 2.156953
# Test Error: Avg loss: 57.270766
#
# Epoch 195
# -------------------------------
# train Error: Avg loss: 2.391893
# Test Error: Avg loss: 52.855357
#
# Epoch 196
# -------------------------------
# train Error: Avg loss: 2.604920
# Test Error: Avg loss: 58.767484
#
# Epoch 197
# -------------------------------
# train Error: Avg loss: 3.180014
# Test Error: Avg loss: 50.898472
#
# Epoch 198
# -------------------------------
# train Error: Avg loss: 4.020028
# Test Error: Avg loss: 60.617774
#
# Epoch 199
# -------------------------------
# train Error: Avg loss: 5.254602
# Test Error: Avg loss: 53.019069
#
# Epoch 200
# -------------------------------
# train Error: Avg loss: 9.428677
# Test Error: Avg loss: 60.753399
#
# Epoch 201
# -------------------------------
# train Error: Avg loss: 5.606899
# Test Error: Avg loss: 63.443470
#
# Epoch 202
# -------------------------------
# train Error: Avg loss: 3.753923
# Test Error: Avg loss: 61.001945
#
# Epoch 203
# -------------------------------
# train Error: Avg loss: 3.153383
# Test Error: Avg loss: 59.256042
#
# Epoch 204
# -------------------------------
# train Error: Avg loss: 2.875155
# Test Error: Avg loss: 57.967641
#
# Epoch 205
# -------------------------------
# train Error: Avg loss: 2.707490
# Test Error: Avg loss: 57.048915
#
# Epoch 206
# -------------------------------
# train Error: Avg loss: 2.584490
# Test Error: Avg loss: 56.410587
#
# Epoch 207
# -------------------------------
# train Error: Avg loss: 2.487507
# Test Error: Avg loss: 55.934608
#
# Epoch 208
# -------------------------------
# train Error: Avg loss: 2.401430
# Test Error: Avg loss: 55.515867
#
# Epoch 209
# -------------------------------
# train Error: Avg loss: 2.318202
# Test Error: Avg loss: 55.114485
#
# Epoch 210
# -------------------------------
# train Error: Avg loss: 2.234191
# Test Error: Avg loss: 54.729982
#
# Epoch 211
# -------------------------------
# train Error: Avg loss: 2.163649
# Test Error: Avg loss: 54.484823
#
# Epoch 212
# -------------------------------
# train Error: Avg loss: 2.104378
# Test Error: Avg loss: 54.317019
#
# Epoch 213
# -------------------------------
# train Error: Avg loss: 2.053191
# Test Error: Avg loss: 54.173600
#
# Epoch 214
# -------------------------------
# train Error: Avg loss: 2.007963
# Test Error: Avg loss: 54.036373
#
# Epoch 215
# -------------------------------
# train Error: Avg loss: 1.966418
# Test Error: Avg loss: 53.902317
#
# Epoch 216
# -------------------------------
# train Error: Avg loss: 1.927629
# Test Error: Avg loss: 53.781766
#
# Epoch 217
# -------------------------------
# train Error: Avg loss: 1.891861
# Test Error: Avg loss: 53.684413
#
# Epoch 218
# -------------------------------
# train Error: Avg loss: 1.858294
# Test Error: Avg loss: 53.604015
#
# Epoch 219
# -------------------------------
# train Error: Avg loss: 1.826436
# Test Error: Avg loss: 53.535000
#
# Epoch 220
# -------------------------------
# train Error: Avg loss: 1.796158
# Test Error: Avg loss: 53.476980
#
# Epoch 221
# -------------------------------
# train Error: Avg loss: 1.768413
# Test Error: Avg loss: 53.427872
#
# Epoch 222
# -------------------------------
# train Error: Avg loss: 1.743376
# Test Error: Avg loss: 53.380713
#
# Epoch 223
# -------------------------------
# train Error: Avg loss: 1.719701
# Test Error: Avg loss: 53.331309
#
# Epoch 224
# -------------------------------
# train Error: Avg loss: 1.696928
# Test Error: Avg loss: 53.276659
#
# Epoch 225
# -------------------------------
# train Error: Avg loss: 1.674847
# Test Error: Avg loss: 53.217397
#
# Epoch 226
# -------------------------------
# train Error: Avg loss: 1.653374
# Test Error: Avg loss: 53.155737
#
# Epoch 227
# -------------------------------
# train Error: Avg loss: 1.632570
# Test Error: Avg loss: 53.098856
#
# Epoch 228
# -------------------------------
# train Error: Avg loss: 1.612612
# Test Error: Avg loss: 53.053700
#
# Epoch 229
# -------------------------------
# train Error: Avg loss: 1.593656
# Test Error: Avg loss: 53.026549
#
# Epoch 230
# -------------------------------
# train Error: Avg loss: 1.575677
# Test Error: Avg loss: 53.018242
#
# Epoch 231
# -------------------------------
# train Error: Avg loss: 1.558596
# Test Error: Avg loss: 53.028255
#
# Epoch 232
# -------------------------------
# train Error: Avg loss: 1.542361
# Test Error: Avg loss: 53.048829
#
# Epoch 233
# -------------------------------
# train Error: Avg loss: 1.526989
# Test Error: Avg loss: 53.079095
#
# Epoch 234
# -------------------------------
# train Error: Avg loss: 1.512075
# Test Error: Avg loss: 53.107027
#
# Epoch 235
# -------------------------------
# train Error: Avg loss: 1.497945
# Test Error: Avg loss: 53.132732
#
# Epoch 236
# -------------------------------
# train Error: Avg loss: 1.483790
# Test Error: Avg loss: 53.149579
#
# Epoch 237
# -------------------------------
# train Error: Avg loss: 1.469676
# Test Error: Avg loss: 53.152650
#
# Epoch 238
# -------------------------------
# train Error: Avg loss: 1.454492
# Test Error: Avg loss: 53.138053
#
# Epoch 239
# -------------------------------
# train Error: Avg loss: 1.439915
# Test Error: Avg loss: 53.146173
#
# Epoch 240
# -------------------------------
# train Error: Avg loss: 1.427486
# Test Error: Avg loss: 53.188449
#
# Epoch 241
# -------------------------------
# train Error: Avg loss: 1.415844
# Test Error: Avg loss: 53.223973
#
# Epoch 242
# -------------------------------
# train Error: Avg loss: 1.404485
# Test Error: Avg loss: 53.242300
#
# Epoch 243
# -------------------------------
# train Error: Avg loss: 1.393453
# Test Error: Avg loss: 53.254380
#
# Epoch 244
# -------------------------------
# train Error: Avg loss: 1.381863
# Test Error: Avg loss: 53.256243
#
# Epoch 245
# -------------------------------
# train Error: Avg loss: 1.370477
# Test Error: Avg loss: 53.247843
#
# Epoch 246
# -------------------------------
# train Error: Avg loss: 1.359165
# Test Error: Avg loss: 53.240350
#
# Epoch 247
# -------------------------------
# train Error: Avg loss: 1.347983
# Test Error: Avg loss: 53.235812
#
# Epoch 248
# -------------------------------
# train Error: Avg loss: 1.337018
# Test Error: Avg loss: 53.240479
#
# Epoch 249
# -------------------------------
# train Error: Avg loss: 1.326315
# Test Error: Avg loss: 53.247983
#
# Epoch 250
# -------------------------------
# train Error: Avg loss: 1.316147
# Test Error: Avg loss: 53.265901
#
# Epoch 251
# -------------------------------
# train Error: Avg loss: 1.306128
# Test Error: Avg loss: 53.285550
#
# Epoch 252
# -------------------------------
# train Error: Avg loss: 1.296849
# Test Error: Avg loss: 53.304598
#
# Epoch 253
# -------------------------------
# train Error: Avg loss: 1.288169
# Test Error: Avg loss: 53.324616
#
# Epoch 254
# -------------------------------
# train Error: Avg loss: 1.279924
# Test Error: Avg loss: 53.345091
#
# Epoch 255
# -------------------------------
# train Error: Avg loss: 1.272008
# Test Error: Avg loss: 53.364924
#
# Epoch 256
# -------------------------------
# train Error: Avg loss: 1.264323
# Test Error: Avg loss: 53.387753
#
# Epoch 257
# -------------------------------
# train Error: Avg loss: 1.256788
# Test Error: Avg loss: 53.409347
#
# Epoch 258
# -------------------------------
# train Error: Avg loss: 1.249394
# Test Error: Avg loss: 53.436164
#
# Epoch 259
# -------------------------------
# train Error: Avg loss: 1.241981
# Test Error: Avg loss: 53.460119
#
# Epoch 260
# -------------------------------
# train Error: Avg loss: 1.234664
# Test Error: Avg loss: 53.488659
#
# Epoch 261
# -------------------------------
# train Error: Avg loss: 1.227304
# Test Error: Avg loss: 53.513627
#
# Epoch 262
# -------------------------------
# train Error: Avg loss: 1.220028
# Test Error: Avg loss: 53.539411
#
# Epoch 263
# -------------------------------
# train Error: Avg loss: 1.212856
# Test Error: Avg loss: 53.561345
#
# Epoch 264
# -------------------------------
# train Error: Avg loss: 1.205739
# Test Error: Avg loss: 53.585337
#
# Epoch 265
# -------------------------------
# train Error: Avg loss: 1.198618
# Test Error: Avg loss: 53.604431
#
# Epoch 266
# -------------------------------
# train Error: Avg loss: 1.191375
# Test Error: Avg loss: 53.630181
#
# Epoch 267
# -------------------------------
# train Error: Avg loss: 1.183898
# Test Error: Avg loss: 53.650787
#
# Epoch 268
# -------------------------------
# train Error: Avg loss: 1.176408
# Test Error: Avg loss: 53.678489
#
# Epoch 269
# -------------------------------
# train Error: Avg loss: 1.169179
# Test Error: Avg loss: 53.704431
#
# Epoch 270
# -------------------------------
# train Error: Avg loss: 1.162057
# Test Error: Avg loss: 53.734145
#
# Epoch 271
# -------------------------------
# train Error: Avg loss: 1.155208
# Test Error: Avg loss: 53.763489
#
# Epoch 272
# -------------------------------
# train Error: Avg loss: 1.148521
# Test Error: Avg loss: 53.802317
#
# Epoch 273
# -------------------------------
# train Error: Avg loss: 1.141990
# Test Error: Avg loss: 53.832710
#
# Epoch 274
# -------------------------------
# train Error: Avg loss: 1.135313
# Test Error: Avg loss: 53.879971
#
# Epoch 275
# -------------------------------
# train Error: Avg loss: 1.128547
# Test Error: Avg loss: 53.922031
#
# Epoch 276
# -------------------------------
# train Error: Avg loss: 1.121443
# Test Error: Avg loss: 53.963302
#
# Epoch 277
# -------------------------------
# train Error: Avg loss: 1.114597
# Test Error: Avg loss: 54.012853
#
# Epoch 278
# -------------------------------
# train Error: Avg loss: 1.107414
# Test Error: Avg loss: 54.055986
#
# Epoch 279
# -------------------------------
# train Error: Avg loss: 1.100220
# Test Error: Avg loss: 54.107718
#
# Epoch 280
# -------------------------------
# train Error: Avg loss: 1.093231
# Test Error: Avg loss: 54.148165
#
# Epoch 281
# -------------------------------
# train Error: Avg loss: 1.086838
# Test Error: Avg loss: 54.216841
#
# Epoch 282
# -------------------------------
# train Error: Avg loss: 1.079496
# Test Error: Avg loss: 54.264610
#
# Epoch 283
# -------------------------------
# train Error: Avg loss: 1.071928
# Test Error: Avg loss: 54.331872
#
# Epoch 284
# -------------------------------
# train Error: Avg loss: 1.064831
# Test Error: Avg loss: 54.404133
#
# Epoch 285
# -------------------------------
# train Error: Avg loss: 1.057220
# Test Error: Avg loss: 54.476341
#
# Epoch 286
# -------------------------------
# train Error: Avg loss: 1.050048
# Test Error: Avg loss: 54.555178
#
# Epoch 287
# -------------------------------
# train Error: Avg loss: 1.042737
# Test Error: Avg loss: 54.621895
#
# Epoch 288
# -------------------------------
# train Error: Avg loss: 1.035401
# Test Error: Avg loss: 54.697846
#
# Epoch 289
# -------------------------------
# train Error: Avg loss: 1.028605
# Test Error: Avg loss: 54.734019
#
# Epoch 290
# -------------------------------
# train Error: Avg loss: 1.022954
# Test Error: Avg loss: 54.814603
#
# Epoch 291
# -------------------------------
# train Error: Avg loss: 1.015112
# Test Error: Avg loss: 54.808537
#
# Epoch 292
# -------------------------------
# train Error: Avg loss: 1.006988
# Test Error: Avg loss: 54.883308
#
# Epoch 293
# -------------------------------
# train Error: Avg loss: 0.998663
# Test Error: Avg loss: 54.856562
#
# Epoch 294
# -------------------------------
# train Error: Avg loss: 0.989505
# Test Error: Avg loss: 54.957264
#
# Epoch 295
# -------------------------------
# train Error: Avg loss: 0.982853
# Test Error: Avg loss: 54.883286
#
# Epoch 296
# -------------------------------
# train Error: Avg loss: 0.977315
# Test Error: Avg loss: 54.985229
#
# Epoch 297
# -------------------------------
# train Error: Avg loss: 0.972905
# Test Error: Avg loss: 54.916181
#
# Epoch 298
# -------------------------------
# train Error: Avg loss: 0.971318
# Test Error: Avg loss: 54.917963
#
# Epoch 299
# -------------------------------
# train Error: Avg loss: 0.971276
# Test Error: Avg loss: 54.942210
#
# Epoch 300
# -------------------------------
# train Error: Avg loss: 0.990076
# Test Error: Avg loss: 54.791084
#
# Epoch 301
# -------------------------------
# train Error: Avg loss: 0.978171
# Test Error: Avg loss: 54.982303
#
# Epoch 302
# -------------------------------
# train Error: Avg loss: 0.975622
# Test Error: Avg loss: 54.508564
#
# Epoch 303
# -------------------------------
# train Error: Avg loss: 0.969223
# Test Error: Avg loss: 54.882345
#
# Epoch 304
# -------------------------------
# train Error: Avg loss: 0.965675
# Test Error: Avg loss: 54.434108
#
# Epoch 305
# -------------------------------
# train Error: Avg loss: 0.970467
# Test Error: Avg loss: 54.761971
#
# Epoch 306
# -------------------------------
# train Error: Avg loss: 0.955951
# Test Error: Avg loss: 54.288481
#
# Epoch 307
# -------------------------------
# train Error: Avg loss: 0.954343
# Test Error: Avg loss: 54.536101
#
# Epoch 308
# -------------------------------
# train Error: Avg loss: 0.941688
# Test Error: Avg loss: 54.145615
#
# Epoch 309
# -------------------------------
# train Error: Avg loss: 0.942860
# Test Error: Avg loss: 54.370126
#
# Epoch 310
# -------------------------------
# train Error: Avg loss: 0.929493
# Test Error: Avg loss: 54.080107
#
# Epoch 311
# -------------------------------
# train Error: Avg loss: 0.929550
# Test Error: Avg loss: 54.161038
#
# Epoch 312
# -------------------------------
# train Error: Avg loss: 0.927948
# Test Error: Avg loss: 53.927098
#
# Epoch 313
# -------------------------------
# train Error: Avg loss: 0.943153
# Test Error: Avg loss: 54.071014
#
# Epoch 314
# -------------------------------
# train Error: Avg loss: 0.959516
# Test Error: Avg loss: 53.747838
#
# Epoch 315
# -------------------------------
# train Error: Avg loss: 0.978730
# Test Error: Avg loss: 54.107004
#
# Epoch 316
# -------------------------------
# train Error: Avg loss: 0.991823
# Test Error: Avg loss: 53.521506
#
# Epoch 317
# -------------------------------
# train Error: Avg loss: 0.996248
# Test Error: Avg loss: 54.094015
#
# Epoch 318
# -------------------------------
# train Error: Avg loss: 0.986169
# Test Error: Avg loss: 53.479224
#
# Epoch 319
# -------------------------------
# train Error: Avg loss: 0.954436
# Test Error: Avg loss: 54.112143
#
# Epoch 320
# -------------------------------
# train Error: Avg loss: 0.905663
# Test Error: Avg loss: 53.653860
#
# Epoch 321
# -------------------------------
# train Error: Avg loss: 0.884086
# Test Error: Avg loss: 53.851099
#
# Epoch 322
# -------------------------------
# train Error: Avg loss: 0.844431
# Test Error: Avg loss: 53.832922
#
# Epoch 323
# -------------------------------
# train Error: Avg loss: 0.838329
# Test Error: Avg loss: 53.685836
#
# Epoch 324
# -------------------------------
# train Error: Avg loss: 0.814324
# Test Error: Avg loss: 53.745041
#
# Epoch 325
# -------------------------------
# train Error: Avg loss: 0.812768
# Test Error: Avg loss: 53.518576
#
# Epoch 326
# -------------------------------
# train Error: Avg loss: 0.800703
# Test Error: Avg loss: 53.778356
#
# Epoch 327
# -------------------------------
# train Error: Avg loss: 0.802558
# Test Error: Avg loss: 53.531812
#
# Epoch 328
# -------------------------------
# train Error: Avg loss: 0.791240
# Test Error: Avg loss: 53.587943
#
# Epoch 329
# -------------------------------
# train Error: Avg loss: 0.799455
# Test Error: Avg loss: 53.382065
#
# Epoch 330
# -------------------------------
# train Error: Avg loss: 0.798816
# Test Error: Avg loss: 53.736361
#
# Epoch 331
# -------------------------------
# train Error: Avg loss: 0.816658
# Test Error: Avg loss: 53.508513
#
# Epoch 332
# -------------------------------
# train Error: Avg loss: 0.846062
# Test Error: Avg loss: 53.397372
#
# Epoch 333
# -------------------------------
# train Error: Avg loss: 0.889553
# Test Error: Avg loss: 53.548497
#
# Epoch 334
# -------------------------------
# train Error: Avg loss: 0.972079
# Test Error: Avg loss: 53.515912
#
# Epoch 335
# -------------------------------
# train Error: Avg loss: 1.118900
# Test Error: Avg loss: 53.544314
#
# Epoch 336
# -------------------------------
# train Error: Avg loss: 1.395506
# Test Error: Avg loss: 52.857058
#
# Epoch 337
# -------------------------------
# train Error: Avg loss: 1.504998
# Test Error: Avg loss: 55.031721
#
# Epoch 338
# -------------------------------
# train Error: Avg loss: 1.481424
# Test Error: Avg loss: 52.970707
#
# Epoch 339
# -------------------------------
# train Error: Avg loss: 1.177996
# Test Error: Avg loss: 54.748835
#
# Epoch 340
# -------------------------------
# train Error: Avg loss: 0.889361
# Test Error: Avg loss: 52.777217
#
# Epoch 341
# -------------------------------
# train Error: Avg loss: 0.818957
# Test Error: Avg loss: 52.730656
#
# Epoch 342
# -------------------------------
# train Error: Avg loss: 0.752601
# Test Error: Avg loss: 52.600196
#
# Epoch 343
# -------------------------------
# train Error: Avg loss: 0.735560
# Test Error: Avg loss: 52.627592
#
# Epoch 344
# -------------------------------
# train Error: Avg loss: 0.732375
# Test Error: Avg loss: 52.554156
#
# Epoch 345
# -------------------------------
# train Error: Avg loss: 0.715056
# Test Error: Avg loss: 52.492676
#
# Epoch 346
# -------------------------------
# train Error: Avg loss: 0.709126
# Test Error: Avg loss: 52.446502
#
# Epoch 347
# -------------------------------
# train Error: Avg loss: 0.710515
# Test Error: Avg loss: 52.299549
#
# Epoch 348
# -------------------------------
# train Error: Avg loss: 0.695627
# Test Error: Avg loss: 52.169970
#
# Epoch 349
# -------------------------------
# train Error: Avg loss: 0.693374
# Test Error: Avg loss: 52.114230
#
# Epoch 350
# -------------------------------
# train Error: Avg loss: 0.685724
# Test Error: Avg loss: 52.007592
#
# Epoch 351
# -------------------------------
# train Error: Avg loss: 0.675564
# Test Error: Avg loss: 51.864618
#
# Epoch 352
# -------------------------------
# train Error: Avg loss: 0.673601
# Test Error: Avg loss: 51.839719
#
# Epoch 353
# -------------------------------
# train Error: Avg loss: 0.664632
# Test Error: Avg loss: 51.559570
#
# Epoch 354
# -------------------------------
# train Error: Avg loss: 0.660191
# Test Error: Avg loss: 51.870441
#
# Epoch 355
# -------------------------------
# train Error: Avg loss: 0.657533
# Test Error: Avg loss: 51.413045
#
# Epoch 356
# -------------------------------
# train Error: Avg loss: 0.636701
# Test Error: Avg loss: 51.510911
#
# Epoch 357
# -------------------------------
# train Error: Avg loss: 0.873637
# Test Error: Avg loss: 50.128304
#
# Epoch 358
# -------------------------------
# train Error: Avg loss: 1.010052
# Test Error: Avg loss: 54.001349
#
# Epoch 359
# -------------------------------
# train Error: Avg loss: 0.885479
# Test Error: Avg loss: 52.013153
#
# Epoch 360
# -------------------------------
# train Error: Avg loss: 1.025916
# Test Error: Avg loss: 52.416719
#
# Epoch 361
# -------------------------------
# train Error: Avg loss: 1.092034
# Test Error: Avg loss: 53.489625
#
# Epoch 362
# -------------------------------
# train Error: Avg loss: 1.208398
# Test Error: Avg loss: 52.378570
#
# Epoch 363
# -------------------------------
# train Error: Avg loss: 1.097553
# Test Error: Avg loss: 54.492342
#
# Epoch 364
# -------------------------------
# train Error: Avg loss: 0.913580
# Test Error: Avg loss: 51.077730
#
# Epoch 365
# -------------------------------
# train Error: Avg loss: 0.775535
# Test Error: Avg loss: 52.768652
#
# Epoch 366
# -------------------------------
# train Error: Avg loss: 0.676547
# Test Error: Avg loss: 52.787536
#
# Epoch 367
# -------------------------------
# train Error: Avg loss: 0.627325
# Test Error: Avg loss: 52.419522
#
# Epoch 368
# -------------------------------
# train Error: Avg loss: 0.604668
# Test Error: Avg loss: 52.233664
#
# Epoch 369
# -------------------------------
# train Error: Avg loss: 0.593776
# Test Error: Avg loss: 52.127004
#
# Epoch 370
# -------------------------------
# train Error: Avg loss: 0.601848
# Test Error: Avg loss: 52.432089
#
# Epoch 371
# -------------------------------
# train Error: Avg loss: 0.601400
# Test Error: Avg loss: 51.825526
#
# Epoch 372
# -------------------------------
# train Error: Avg loss: 0.618102
# Test Error: Avg loss: 52.583878
#
# Epoch 373
# -------------------------------
# train Error: Avg loss: 0.607770
# Test Error: Avg loss: 52.001238
#
# Epoch 374
# -------------------------------
# train Error: Avg loss: 0.592740
# Test Error: Avg loss: 51.814617
#
# Epoch 375
# -------------------------------
# train Error: Avg loss: 0.598647
# Test Error: Avg loss: 51.948815
#
# Epoch 376
# -------------------------------
# train Error: Avg loss: 0.620120
# Test Error: Avg loss: 52.490510
#
# Epoch 377
# -------------------------------
# train Error: Avg loss: 0.621716
# Test Error: Avg loss: 51.922828
#
# Epoch 378
# -------------------------------
# train Error: Avg loss: 0.662442
# Test Error: Avg loss: 52.837079
#
# Epoch 379
# -------------------------------
# train Error: Avg loss: 0.681898
# Test Error: Avg loss: 52.247393
#
# Epoch 380
# -------------------------------
# train Error: Avg loss: 0.720960
# Test Error: Avg loss: 52.437095
#
# Epoch 381
# -------------------------------
# train Error: Avg loss: 0.767494
# Test Error: Avg loss: 52.199794
#
# Epoch 382
# -------------------------------
# train Error: Avg loss: 0.874844
# Test Error: Avg loss: 52.351351
#
# Epoch 383
# -------------------------------
# train Error: Avg loss: 0.883117
# Test Error: Avg loss: 53.211357
#
# Epoch 384
# -------------------------------
# train Error: Avg loss: 0.950714
# Test Error: Avg loss: 51.821086
#
# Epoch 385
# -------------------------------
# train Error: Avg loss: 0.964797
# Test Error: Avg loss: 53.515726
#
# Epoch 386
# -------------------------------
# train Error: Avg loss: 0.953309
# Test Error: Avg loss: 52.439137
#
# Epoch 387
# -------------------------------
# train Error: Avg loss: 0.768434
# Test Error: Avg loss: 53.808744
#
# Epoch 388
# -------------------------------
# train Error: Avg loss: 0.656234
# Test Error: Avg loss: 52.479239
#
# Epoch 389
# -------------------------------
# train Error: Avg loss: 0.619126
# Test Error: Avg loss: 52.613955
#
# Epoch 390
# -------------------------------
# train Error: Avg loss: 0.568398
# Test Error: Avg loss: 52.893476
#
# Epoch 391
# -------------------------------
# train Error: Avg loss: 0.545715
# Test Error: Avg loss: 52.229399
#
# Epoch 392
# -------------------------------
# train Error: Avg loss: 0.547723
# Test Error: Avg loss: 52.625240
#
# Epoch 393
# -------------------------------
# train Error: Avg loss: 0.534069
# Test Error: Avg loss: 51.911289
#
# Epoch 394
# -------------------------------
# train Error: Avg loss: 0.545557
# Test Error: Avg loss: 52.696837
#
# Epoch 395
# -------------------------------
# train Error: Avg loss: 0.555485
# Test Error: Avg loss: 51.860344
#
# Epoch 396
# -------------------------------
# train Error: Avg loss: 0.568968
# Test Error: Avg loss: 52.566750
#
# Epoch 397
# -------------------------------
# train Error: Avg loss: 0.567599
# Test Error: Avg loss: 51.779174
#
# Epoch 398
# -------------------------------
# train Error: Avg loss: 0.560052
# Test Error: Avg loss: 52.568605
#
# Epoch 399
# -------------------------------
# train Error: Avg loss: 0.546572
# Test Error: Avg loss: 51.896354
#
# Epoch 400
# -------------------------------
# train Error: Avg loss: 0.552360
# Test Error: Avg loss: 52.404777
#
# Epoch 401
# -------------------------------
# train Error: Avg loss: 0.519566
# Test Error: Avg loss: 52.385238
#
# Epoch 402
# -------------------------------
# train Error: Avg loss: 0.493891
# Test Error: Avg loss: 52.320713
#
# Epoch 403
# -------------------------------
# train Error: Avg loss: 0.488158
# Test Error: Avg loss: 52.270542
#
# Epoch 404
# -------------------------------
# train Error: Avg loss: 0.485355
# Test Error: Avg loss: 52.229787
#
# Epoch 405
# -------------------------------
# train Error: Avg loss: 0.483513
# Test Error: Avg loss: 52.195980
#
# Epoch 406
# -------------------------------
# train Error: Avg loss: 0.482191
# Test Error: Avg loss: 52.167969
#
# Epoch 407
# -------------------------------
# train Error: Avg loss: 0.481159
# Test Error: Avg loss: 52.144880
#
# Epoch 408
# -------------------------------
# train Error: Avg loss: 0.480289
# Test Error: Avg loss: 52.125920
#
# Epoch 409
# -------------------------------
# train Error: Avg loss: 0.479509
# Test Error: Avg loss: 52.110398
#
# Epoch 410
# -------------------------------
# train Error: Avg loss: 0.478782
# Test Error: Avg loss: 52.097663
#
# Epoch 411
# -------------------------------
# train Error: Avg loss: 0.478086
# Test Error: Avg loss: 52.087227
#
# Epoch 412
# -------------------------------
# train Error: Avg loss: 0.477412
# Test Error: Avg loss: 52.078597
#
# Epoch 413
# -------------------------------
# train Error: Avg loss: 0.476757
# Test Error: Avg loss: 52.071413
#
# Epoch 414
# -------------------------------
# train Error: Avg loss: 0.476118
# Test Error: Avg loss: 52.065311
#
# Epoch 415
# -------------------------------
# train Error: Avg loss: 0.475494
# Test Error: Avg loss: 52.060081
#
# Epoch 416
# -------------------------------
# train Error: Avg loss: 0.474884
# Test Error: Avg loss: 52.055432
#
# Epoch 417
# -------------------------------
# train Error: Avg loss: 0.474286
# Test Error: Avg loss: 52.051227
#
# Epoch 418
# -------------------------------
# train Error: Avg loss: 0.473697
# Test Error: Avg loss: 52.047227
#
# Epoch 419
# -------------------------------
# train Error: Avg loss: 0.473113
# Test Error: Avg loss: 52.043393
#
# Epoch 420
# -------------------------------
# train Error: Avg loss: 0.472532
# Test Error: Avg loss: 52.039606
#
# Epoch 421
# -------------------------------
# train Error: Avg loss: 0.471953
# Test Error: Avg loss: 52.035798
#
# Epoch 422
# -------------------------------
# train Error: Avg loss: 0.471374
# Test Error: Avg loss: 52.031940
#
# Epoch 423
# -------------------------------
# train Error: Avg loss: 0.470794
# Test Error: Avg loss: 52.028002
#
# Epoch 424
# -------------------------------
# train Error: Avg loss: 0.470213
# Test Error: Avg loss: 52.023991
#
# Epoch 425
# -------------------------------
# train Error: Avg loss: 0.469631
# Test Error: Avg loss: 52.019917
#
# Epoch 426
# -------------------------------
# train Error: Avg loss: 0.469046
# Test Error: Avg loss: 52.015785
#
# Epoch 427
# -------------------------------
# train Error: Avg loss: 0.468459
# Test Error: Avg loss: 52.011590
#
# Epoch 428
# -------------------------------
# train Error: Avg loss: 0.467868
# Test Error: Avg loss: 52.007349
#
# Epoch 429
# -------------------------------
# train Error: Avg loss: 0.467274
# Test Error: Avg loss: 52.003084
#
# Epoch 430
# -------------------------------
# train Error: Avg loss: 0.466675
# Test Error: Avg loss: 51.998785
#
# Epoch 431
# -------------------------------
# train Error: Avg loss: 0.466074
# Test Error: Avg loss: 51.994522
#
# Epoch 432
# -------------------------------
# train Error: Avg loss: 0.465467
# Test Error: Avg loss: 51.990260
#
# Epoch 433
# -------------------------------
# train Error: Avg loss: 0.464856
# Test Error: Avg loss: 51.986007
#
# Epoch 434
# -------------------------------
# train Error: Avg loss: 0.464240
# Test Error: Avg loss: 51.981797
#
# Epoch 435
# -------------------------------
# train Error: Avg loss: 0.463620
# Test Error: Avg loss: 51.977621
#
# Epoch 436
# -------------------------------
# train Error: Avg loss: 0.462994
# Test Error: Avg loss: 51.973494
#
# Epoch 437
# -------------------------------
# train Error: Avg loss: 0.462364
# Test Error: Avg loss: 51.969420
#
# Epoch 438
# -------------------------------
# train Error: Avg loss: 0.461728
# Test Error: Avg loss: 51.965397
#
# Epoch 439
# -------------------------------
# train Error: Avg loss: 0.461087
# Test Error: Avg loss: 51.961404
#
# Epoch 440
# ...
# Test Error: Avg loss: 52.243566
#
# Epoch 1856
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1857
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1858
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1859
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1860
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1861
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1862
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1863
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1864
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1865
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1866
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1867
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1868
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1869
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1870
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1871
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1872
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1873
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1874
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1875
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1876
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1877
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1878
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1879
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1880
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1881
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1882
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1883
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1884
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1885
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1886
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1887
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1888
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1889
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1890
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1891
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1892
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1893
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1894
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1895
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1896
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1897
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1898
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1899
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1900
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1901
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1902
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1903
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1904
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1905
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1906
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1907
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1908
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1909
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1910
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1911
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1912
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1913
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1914
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1915
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1916
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1917
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1918
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1919
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1920
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1921
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1922
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1923
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1924
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1925
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1926
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1927
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1928
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1929
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1930
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1931
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1932
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1933
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1934
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1935
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1936
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1937
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1938
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1939
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1940
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1941
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1942
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1943
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1944
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1945
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1946
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1947
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1948
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1949
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1950
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1951
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1952
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1953
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1954
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1955
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1956
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1957
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1958
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1959
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1960
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1961
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1962
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1963
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1964
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1965
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1966
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1967
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1968
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1969
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1970
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1971
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1972
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1973
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1974
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1975
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1976
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1977
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1978
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1979
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1980
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1981
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1982
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1983
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1984
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1985
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1986
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1987
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1988
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1989
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1990
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1991
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1992
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1993
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1994
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1995
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1996
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1997
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1998
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 1999
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Epoch 2000
# -------------------------------
# train Error: Avg loss: 0.263337
# Test Error: Avg loss: 52.243566
#
# Done!

# %%
plt.plot(losses[20:], label='train loss')
plt.plot(val[20:], label='test loss')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
count =0
output = torch.tensor([])
model.eval()
with torch.no_grad():
    for X, y in train_loader:
        y_star = model(X)
        output = torch.cat((output, y_star), 0)
        
        #print(X.shape,y.shape )
        #print(X.shape)
#print(count)
plt.plot(y_train, label='Actual Close')
plt.plot(output, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()
output[2000],y_train[2000]
# Out:
# (tensor([92.0723]), array([94.77999878]))

# %%
output = torch.tensor([])
model.eval()
with torch.no_grad():
    for X, y in val_loader:
        y_star = model(X)
        output = torch.cat((output, y_star), 0)
        print(X.shape,y.shape )
plt.plot(y_val, label='Actual Close')
plt.plot(output, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()
# Out:
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([58, 5, 24]) torch.Size([58, 1])

# %%
for batch, (X, y) in enumerate(train_dataset):
    print( (X.shape, y.shape))
    print( batch,(X, y))
    break
# Out:
# (torch.Size([5, 24]), torch.Size([1]))
# 0 (tensor([[-0.7130, -0.7142, -0.7140, -0.7135, -0.5357,  0.7252,  0.6802,  0.1814,
#           1.1504,  0.8146, -0.3438, -0.6620,  1.1862, -1.1676, -0.2644, -0.7198,
#          -0.7174, -0.7146,  1.5675,  1.1005, -0.7179, -0.7160, -0.7142, -0.7162],
#         [-0.7130, -0.7142, -0.7140, -0.7135, -0.5357,  0.7252,  0.6802,  0.1814,
#           1.1504,  0.8146, -0.3438, -0.6620,  1.1862, -1.1676, -0.2644, -0.7198,
#          -0.7174, -0.7146,  1.5675,  1.1005, -0.7179, -0.7160, -0.7142, -0.7162],
#         [-0.7130, -0.7142, -0.7140, -0.7135, -0.5357,  0.7252,  0.6802,  0.1814,
#           1.1504,  0.8146, -0.3438, -0.6620,  1.1862, -1.1676, -0.2644, -0.7198,
#          -0.7174, -0.7146,  1.5675,  1.1005, -0.7179, -0.7160, -0.7142, -0.7162],
#         [-0.7130, -0.7142, -0.7140, -0.7135, -0.5357,  0.7252,  0.6802,  0.1814,
#           1.1504,  0.8146, -0.3438, -0.6620,  1.1862, -1.1676, -0.2644, -0.7198,
#          -0.7174, -0.7146,  1.5675,  1.1005, -0.7179, -0.7160, -0.7142, -0.7162],
#         [-0.7130, -0.7142, -0.7140, -0.7135, -0.5357,  0.7252,  0.6802,  0.1814,
#           1.1504,  0.8146, -0.3438, -0.6620,  1.1862, -1.1676, -0.2644, -0.7198,
#          -0.7174, -0.7146,  1.5675,  1.1005, -0.7179, -0.7160, -0.7142, -0.7162]]), tensor([2.4900]))

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(output,y_val))
# Out:
# 7.238666024538832

# %%
data = pd.read_csv('/Users/hieudao/Desktop/ai/do_an/clean_data/clean_amd.csv')
data['Date'] = pd.to_datetime(data['Date'])
data['Close+1'] = data['Close'].shift(-1)
data = data.dropna()

test = data[data['Date'] >= pd.to_datetime('2023-01-01 00:00:00-04:00')]
test = test.drop(columns=['Date','tema_2','tema_100'])
test
# Out:
#              Open        High         Low       Close    Volume    NATR_3  \
# 10673   66.000000   66.879997   63.590000   64.019997  46851800  4.110550
# 10674   65.000000   65.790001   63.310001   64.660004  47477100  3.952655
# 10675   64.150002   64.349998   62.299999   62.330002  46159500  3.943359
# 10676   63.150002   64.300003   60.049999   63.959999  70161300  5.243824
# 10677   66.220001   69.320000   65.669998   67.239998  69741300  6.479737
# ...           ...         ...         ...         ...       ...       ...
# 10795  112.070000  112.760002  109.839996  111.239998  58347200  3.230614
# 10796  113.029999  114.690002  112.410004  113.910004  53331900  3.091800
# 10797  115.160004  116.730003  114.510002  115.820000  31860000  2.737813
# 10798  116.099998  117.660004  113.860001  113.949997  49501600  3.058771
# 10799  112.070000  113.790001  110.309998  113.480003  42342000  3.139526
#
#            RSI_3      ADX_3  CCI_3_0.015     ROC_3  ...   BBL_3_2.0  \
# 10673  43.227376  40.566151   100.000000  2.317400  ...   63.804846
# 10674  57.191880  42.429407    10.753448 -0.246831  ...   63.821951
# 10675  24.407318  30.501317  -100.000000 -3.767168  ...   61.704227
# 10676  52.799692  39.568982   -59.824010 -0.093717  ...   61.697703
# 10677  77.878709  41.140061   100.000000  3.990093  ...   60.426246
# ...          ...        ...          ...       ...  ...         ...
# 10795  53.049678  36.721870   100.000000  3.469441  ...  109.677250
# 10796  74.737893  41.386671   100.000000  3.188699  ...  108.627862
# 10797  83.109892  51.287612    94.507029  5.128439  ...  109.899988
# 10798  55.902291  60.012046    27.307241  2.436173  ...  112.777792
# 10799  49.760901  47.188927  -100.000000 -0.377491  ...  112.395293
#
#         BBM_3_2.0   BBU_3_2.0  BBB_3_2.0  BBP_3_2.0  min_price_3  max_price_3  \
# 10673   64.536664   65.268483   2.267915   0.146997    63.060001    66.879997
# 10674   64.483332   65.144714   2.051326   0.633562    63.139999    66.879997
# 10675   63.670001   65.635775   6.174882   0.159168    62.299999    66.879997
# 10676   63.650002   65.602300   6.134481   0.579393    60.049999    65.790001
# 10677   64.510000   68.593753  12.660838   0.834251    60.049999    69.320000
# ...           ...         ...        ...        ...          ...          ...
# 10795  110.599998  111.522747   1.668624   0.846790   107.080002   112.760002
# 10796  111.773333  114.918804   5.628303   0.839642   107.629997   114.690002
# 10797  113.656667  117.413346   6.610574   0.787932   109.839996   116.730003
# 10798  114.560000  116.342208   3.111396   0.328863   112.410004   117.660004
# 10799  114.416667  116.438040   3.533355   0.268310   110.309998   117.660004
#
#         mid_price      tema_8     Close+1
# 10673   65.234999   63.968196   64.660004
# 10674   64.550001   64.317467   62.330002
# 10675   63.324999   63.311596   63.959999
# 10676   62.175001   63.587034   67.239998
# 10677   67.494999   65.514038   68.050003
# ...           ...         ...         ...
# 10795  111.299999  108.605059  113.910004
# 10796  113.550003  110.790179  115.820000
# 10797  115.620003  113.230480  113.949997
# 10798  115.760002  113.750856  113.480003
# 10799  112.049999  113.809707  113.169998
#
# [127 rows x 25 columns]

# %%
X_test = test.copy().drop(columns=['Close+1'])
y_test = pd.DataFrame()
y_test['Close+1'] = test[['Close+1']]

#X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

X_test_scaled = scaler.transform(X_test)

test_dataset = TimeSeriesDataset(X_test_scaled,y_test,sequence_length=sequence_length)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)


output = torch.tensor([])
model.eval()
with torch.no_grad():
    for X, y in test_loader:
        y_star = model(X)
        output = torch.cat((output, y_star), 0)
        
        print(X.shape,y.shape )
#print(count)
plt.plot(y_test, label='Actual Close')
plt.plot(output, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()
np.sqrt(mean_squared_error(output,y_test))
# Out:
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([63, 5, 24]) torch.Size([63, 1])
# /usr/local/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# 6.430038422297027

# %%
y_test.shape, X_test_scaled.shape, output.shape
# Out:
# ((127, 1), (127, 24), torch.Size([127, 1]))

# %%
(np.abs(output-y_test)/y_test).mean()*100
# Out:
# tensor(5.0334, dtype=torch.float64)
