# %%
import pandas as pd
import pandas_ta as ta
import mplfinance as mpf
import numpy as np
import mplfinance as mpf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # 1. Read and split dataset

# %% [markdown]
# ## Read

# %%
df = pd.read_csv('../clean_data/clean_amd.csv')
df = df.set_index('Date')
df.index = pd.to_datetime(df.index)
df['Close+1'] = df['Close'].shift(-1)
df[['Close', 'Close+1']].tail(2)
df = df.drop(columns=[ 'tema_100', 'tema_8'])
df.dropna()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-08-06 00:00:00-04:00    0.000000    4.333333    4.218750    4.239583
# 1980-08-07 00:00:00-04:00    0.000000    4.270833    4.208333    4.218750
# 1980-08-08 00:00:00-04:00    0.000000    4.333333    4.260417    4.270833
# 1980-08-11 00:00:00-04:00    0.000000    4.416667    4.270833    4.416667
# 1980-08-12 00:00:00-04:00    0.000000    4.500000    4.333333    4.354167
# ...                               ...         ...         ...         ...
# 2023-06-29 00:00:00-04:00  112.070000  112.760002  109.839996  111.239998
# 2023-06-30 00:00:00-04:00  113.029999  114.690002  112.410004  113.910004
# 2023-07-03 00:00:00-04:00  115.160004  116.730003  114.510002  115.820000
# 2023-07-05 00:00:00-04:00  116.099998  117.660004  113.860001  113.949997
# 2023-07-06 00:00:00-04:00  112.070000  113.790001  110.309998  113.480003
#
#                              Volume    NATR_3      RSI_3      ADX_3  \
# Date
# 1980-08-06 00:00:00-04:00    351600  3.193439  57.558179  67.457227
# 1980-08-07 00:00:00-04:00    218400  2.345345  52.183414  53.444589
# 1980-08-08 00:00:00-04:00    471600  2.499832  64.584952  51.885376
# 1980-08-11 00:00:00-04:00    542400  2.859595  83.049391  57.421407
# 1980-08-12 00:00:00-04:00    445200  3.364200  62.201514  64.956983
# ...                             ...       ...        ...        ...
# 2023-06-29 00:00:00-04:00  58347200  3.230614  53.049678  36.721870
# 2023-06-30 00:00:00-04:00  53331900  3.091800  74.737893  41.386671
# 2023-07-03 00:00:00-04:00  31860000  2.737813  83.109892  51.287612
# 2023-07-05 00:00:00-04:00  49501600  3.058771  55.902291  60.012046
# 2023-07-06 00:00:00-04:00  42342000  3.139526  49.760901  47.188927
#
#                            CCI_3_0.015     ROC_3  ...   BBL_3_2.0   BBM_3_2.0  \
# Date                                              ...
# 1980-08-06 00:00:00-04:00   -70.588288 -0.489012  ...    4.203022    4.305555
# 1980-08-07 00:00:00-04:00   -70.149217 -2.173913  ...    4.145505    4.274305
# 1980-08-08 00:00:00-04:00    92.000132 -2.147972  ...    4.200247    4.243055
# 1980-08-11 00:00:00-04:00   100.000000  4.176919  ...    4.134550    4.302083
# 1980-08-12 00:00:00-04:00    72.222100  3.209884  ...    4.227745    4.347222
# ...                                ...       ...  ...         ...         ...
# 2023-06-29 00:00:00-04:00   100.000000  3.469441  ...  109.677250  110.599998
# 2023-06-30 00:00:00-04:00   100.000000  3.188699  ...  108.627862  111.773333
# 2023-07-03 00:00:00-04:00    94.507029  5.128439  ...  109.899988  113.656667
# 2023-07-05 00:00:00-04:00    27.307241  2.436173  ...  112.777792  114.560000
# 2023-07-06 00:00:00-04:00  -100.000000 -0.377491  ...  112.395293  114.416667
#
#                             BBU_3_2.0  BBB_3_2.0  BBP_3_2.0  min_price_3  \
# Date
# 1980-08-06 00:00:00-04:00    4.408089   4.762848   0.178289     4.218750
# 1980-08-07 00:00:00-04:00    4.403105   6.026714   0.284335     4.208333
# 1980-08-08 00:00:00-04:00    4.285864   2.017800   0.824443     4.208333
# 1980-08-11 00:00:00-04:00    4.469616   7.788452   0.841974     4.208333
# 1980-08-12 00:00:00-04:00    4.466700   5.496718   0.529063     4.260417
# ...                               ...        ...        ...          ...
# 2023-06-29 00:00:00-04:00  111.522747   1.668624   0.846790   107.080002
# 2023-06-30 00:00:00-04:00  114.918804   5.628303   0.839642   107.629997
# 2023-07-03 00:00:00-04:00  117.413346   6.610574   0.787932   109.839996
# 2023-07-05 00:00:00-04:00  116.342208   3.111396   0.328863   112.410004
# 2023-07-06 00:00:00-04:00  116.438040   3.533355   0.268310   110.309998
#
#                            max_price_3   mid_price      tema_2     Close+1
# Date
# 1980-08-06 00:00:00-04:00     4.416667    4.276042    4.244861    4.218750
# 1980-08-07 00:00:00-04:00     4.416667    4.239583    4.213865    4.270833
# 1980-08-08 00:00:00-04:00     4.333333    4.296875    4.265330    4.416667
# 1980-08-11 00:00:00-04:00     4.416667    4.343750    4.412216    4.354167
# 1980-08-12 00:00:00-04:00     4.500000    4.416667    4.362558    4.270833
# ...                                ...         ...         ...         ...
# 2023-06-29 00:00:00-04:00   112.760002  111.299999  111.254857  113.910004
# 2023-06-30 00:00:00-04:00   114.690002  113.550003  113.867390  115.820000
# 2023-07-03 00:00:00-04:00   116.730003  115.620003  115.864276  113.949997
# 2023-07-05 00:00:00-04:00   117.660004  115.760002  114.120879  113.480003
# 2023-07-06 00:00:00-04:00   117.660004  112.049999  113.442697  113.169998
#
# [10800 rows x 25 columns]

# %% [markdown]
# ## SPLIT DATASET

# %%
train = df.loc[(df.index < pd.to_datetime('2020-01-01 00:00:00-04:00'))]
test = df.loc[(df.index >= pd.to_datetime('2020-01-01 00:00:00-04:00')) & (df.index < pd.to_datetime('2023-01-01 00:00:00-04:00'))]
test_last = df.loc[df.index >=  pd.to_datetime('2023-01-01 00:00:00-04:00')]

fig, ax = plt.subplots(figsize=(30, 10))
train['Close'].plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test['Close'].plot(ax=ax, label='test Set', title='Test Split')

test_last['Close'].plot(ax=ax, label='val Set')
ax.axvline('01-01-2023', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
# plt.show()

# %%
temp_df = df.loc[ pd.to_datetime('2013-01-01 00:00:00-04:00'): pd.to_datetime('2022-12-31 00:00:00-04:00')]
# pd.to_datetime('2023-01-01 00:00:00-04:00')
train_size = int(len(temp_df) * 0.80)
test_size = int(len(temp_df) - train_size)

train = temp_df[:train_size]
test= temp_df[train_size:]

fig, ax = plt.subplots(figsize=(30, 10))

train['Close'].plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test['Close'].plot(ax=ax, label='test Set', title='Test Split')

ax.axvline('01-01-2023', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %% [markdown]
# ## cross val

# %%
train = temp_df[:train_size]
test= temp_df[train_size:]

from sklearn.model_selection import TimeSeriesSplit



test_size_ratio = 0.1  # Tỷ lệ phần trăm dùng cho tập kiểm tra
test_size = int(temp_df.shape[0] * test_size_ratio)


tscv = TimeSeriesSplit(n_splits=5, test_size=test_size, gap=0)


fig, axs = plt.subplots(5, 1, figsize=(15, 15), sharex=True)
fold = 0

for train_idx, val_idx in tscv.split(temp_df.copy()):
    train = temp_df.iloc[train_idx]
    test= temp_df.iloc[val_idx]

    train["Close"].plot(ax=axs[fold], label='Training Set', title='Fold {}'.format(fold+1))
    test["Close"].plot(ax=axs[fold], label='Val Set')
    axs[fold].axvline(test.index.min(), color='black', ls='--')
    fold+= 1
plt.show()

# %% [markdown]
# # Model

# %% [markdown]
# ## test raw performance

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
np.random.seed(42)

# %%
X_train = train.copy().drop(columns=['Close+1'])
Y_train = train[['Close+1']]
X_test = test.copy().drop(columns=['Close+1'])
Y_test = test[['Close+1']]

# %%
svr = SVR()
svr.fit(X_train,Y_train)
Y_pred =  svr.predict(X_test)
mse = (mean_squared_error(Y_test, Y_pred))
rmse = np.sqrt(mse)
print(f"Mean Squared Error: {mse,rmse}")
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Mean Squared Error: (345.6983904581913, 18.592966155462964)

# %% [markdown]
# ## scale

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
#X_scaled = scaler.fit_transform(X)

X = temp_df.copy().drop(columns=['Close+1'])
X_scaled = scaler.fit_transform(X)

y = temp_df[['Close+1']]

# %% [markdown]
# # fine tune

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning,DataConversionWarning

# Filter out DataConversionWarning
warnings.filterwarnings("ignore", category=DataConversionWarning)

# Filter out ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %% [markdown]
# ## grid search overview

# %%
from sklearn.model_selection import  GridSearchCV

# param_grid = {
#     'C': [0.1],
#     'epsilon': [0.1],
#     'kernel': ['linear']
# }
param_grid={
    'C':[0.0001,0.001,0.01,0.1,1,10, 100], 
    'kernel': ['linear','rbf','poly'],
    'max_iter': [1000],
    'gamma':[0.0001,0.001,0.01,0.1,1,10, 100], 
    'degree':[1,2,3,4,5],
     'max_iter': [1000]
}



# Define the number of splits for time series cross-validation
n_splits = 10
tscv = TimeSeriesSplit(n_splits=n_splits)

# Create the SVR model
svr = SVR()

# Perform grid search with cross-validation
grid_search = GridSearchCV(estimator=svr, param_grid=param_grid, scoring='neg_mean_squared_error', cv=tscv)
grid_search.fit(X_scaled, y)

# Print the best parameter combination and the corresponding mean squared error
print("Best Parameters: ", grid_search.best_params_)
print("Best Mean Squared Error: ", (-grid_search.best_score_))
# Out:
# Best Parameters:  {'C': 10, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly', 'max_iter': 1000}
# Best Mean Squared Error:  4.254233893448941

# %%
scores = grid_search.cv_results_
mean_scores = scores['mean_test_score']
params = scores['params']

# Sort the scores and parameters based on the mean scores in descending order
sorted_indices = np.argsort(mean_scores)[::-1]
sorted_mean_scores = mean_scores[sorted_indices]
sorted_params = [params[i] for i in sorted_indices]

lim = 0
# Print the sorted mean scores and corresponding parameters
for mean_score, param in zip(sorted_mean_scores, sorted_params):
    print(mean_score, '----', param)
    lim +=1 
    if lim ==30:
        break
    # if param['kernel'] == 'linear' and param['C'] == 1.0 and param['gamma'] == 0.001:
      
    #     print(mean_score, '----', param)
# Out:
# -4.254233893448941 ---- {'C': 10, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 3, 'gamma': 0.0001, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 2, 'gamma': 0.01, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 3, 'gamma': 1, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 3, 'gamma': 0.01, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 3, 'gamma': 0.001, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 2, 'gamma': 100, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 2, 'gamma': 10, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 2, 'gamma': 1, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 2, 'gamma': 0.1, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 1, 'gamma': 1, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 2, 'gamma': 0.0001, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 1, 'gamma': 100, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 1, 'gamma': 10, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 1, 'gamma': 0.0001, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 1, 'gamma': 0.001, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 1, 'gamma': 0.01, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 1, 'gamma': 0.1, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 3, 'gamma': 10, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 3, 'gamma': 100, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 4, 'gamma': 0.0001, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 5, 'gamma': 0.0001, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 5, 'gamma': 100, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 5, 'gamma': 10, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 5, 'gamma': 1, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 5, 'gamma': 0.1, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 4, 'gamma': 0.001, 'kernel': 'linear', 'max_iter': 1000}
# -4.26136259827779 ---- {'C': 1, 'degree': 5, 'gamma': 0.001, 'kernel': 'linear', 'max_iter': 1000}

# %%
print(zip(sorted_mean_scores, sorted_params))
# Out:
# <zip object at 0x1269263c0>

# %% [markdown]
# ## grid search smaller

# %%
from sklearn.model_selection import  GridSearchCV

# param_grid = {
#     'C': [0.1],
#     'epsilon': [0.1],
#     'kernel': ['linear']
# }
param_grid={
    'C':[0.1,1,10], 
    'kernel': ['linear'],
    
     'max_iter': [5000]
}



# Define the number of splits for time series cross-validation
n_splits = 10
tscv = TimeSeriesSplit(n_splits=n_splits)

# Create the SVR model
svr = SVR()

# Perform grid search with cross-validation
grid_search = GridSearchCV(estimator=svr, param_grid=param_grid, scoring='neg_mean_squared_error', cv=tscv)
grid_search.fit(X_scaled, y)

# Print the best parameter combination and the corresponding mean squared error
print("Best Parameters: ", grid_search.best_params_)
print("Best Mean Squared Error: ", (-grid_search.best_score_))

scores = grid_search.cv_results_
mean_scores = scores['mean_test_score']
params = scores['params']

# Sort the scores and parameters based on the mean scores in descending order
sorted_indices = np.argsort(mean_scores)[::-1]
sorted_mean_scores = mean_scores[sorted_indices]
sorted_params = [params[i] for i in sorted_indices]

lim = 0
# Print the sorted mean scores and corresponding parameters
for mean_score, param in zip(sorted_mean_scores, sorted_params):
    print(mean_score, '----', param)
    lim +=1 
    if lim ==30:
        break
    # if param['kernel'] == 'linear' and param['C'] == 1.0 and param['gamma'] == 0.001:
      
    #     print(mean_score, '----', param)
# Out:
# Best Parameters:  {'C': 1, 'kernel': 'linear', 'max_iter': 5000}
# Best Mean Squared Error:  3.7247341102096256
# -3.7247341102096256 ---- {'C': 1, 'kernel': 'linear', 'max_iter': 5000}
# -4.084167063851142 ---- {'C': 10, 'kernel': 'linear', 'max_iter': 5000}
# -6.247398544069396 ---- {'C': 0.1, 'kernel': 'linear', 'max_iter': 5000}

# %%
train = temp_df[:train_size]
test= temp_df[train_size:]

from sklearn.model_selection import TimeSeriesSplit



test_size_ratio = 0.1  # Tỷ lệ phần trăm dùng cho tập kiểm tra
test_size = int(temp_df.shape[0] * test_size_ratio)


tscv = TimeSeriesSplit(n_splits=10, test_size=test_size, gap=0)


fig, axs = plt.subplots(10, 1, figsize=(15, 15), sharex=True)
fold = 0

mean_val = 0
for train_idx, val_idx in tscv.split(temp_df.copy()):

    svr =SVR(C=1, kernel='linear',  max_iter= 5000)
    #'C': 0.1, 'degree': 1, 'gamma': 10, 'kernel': 'poly', 'max_iter': 1000

    train = temp_df.iloc[train_idx]
    test= temp_df.iloc[val_idx]
    X_train = train.copy().drop(columns=['Close+1'])

    scaler_cv = StandardScaler()
    scaler_cv.fit(X_train)
    x_train_scaled = scaler.transform(X_train)
    y_train = train[['Close+1']]
    X_test = test.copy().drop(columns=['Close+1'])
    X_test_scaled = scaler.transform(X_test)

    y_test = test[['Close+1']]
    
    svr.fit(x_train_scaled, y_train)

    y_pred = svr.predict(X_test_scaled)

    result = test.copy()
    result['pred'] = y_pred
    
    result["Close+1"].plot(ax=axs[fold], label='Training Set', title='Fold {}'.format(fold+1))
    result["pred"].plot(ax=axs[fold], label='Val Set')
    print(mean_squared_error(y_pred, y_test))
    mean_val+= mean_squared_error(y_pred, y_test)
    axs[fold].axvline(test.index.min(), color='black', ls='--')
    fold+= 1
plt.show()
print(mean_val)
# Out:
# 1.0691979671428966
# 0.13627318603610708
# 0.19397175098507255
# 0.1906557301411748
# 0.28157473505411346
# 0.7723448798956272
# 1.227764094907
# 5.993357862370777
# 10.239886252701623
# 15.108573701654047
# 35.21360016088844

# %%
test_last = test_last.dropna()

svr =SVR(C=1, kernel= 'linear', max_iter= 5000)
X_train = temp_df.copy().drop(columns=['Close+1'])
y_train = temp_df[['Close+1']]
#scale train
final_scaler = StandardScaler()
final_scaler.fit(X_train)
X_train_scaled = final_scaler.transform(X_train)
#scale test
X_test_last = test_last.copy().drop(columns=['Close+1'])
y_test_last = test_last[['Close+1']]

X_test_last_scale = final_scaler.transform(X_test_last)

svr.fit(X_train_scaled,y_train)
y_pred = svr.predict(X_test_last_scale)


df_plot = y_test_last.copy()
df_plot['pred'] = y_pred

# %%
rmse = np.sqrt(mean_squared_error(y_pred,y_test_last))
mape = np.abs((df_plot['pred']-df_plot['Close+1'])/df_plot['Close+1'])
mape = (mape.mean())
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}')
# Out:
# RMSE: 3.270645635563715
# MAPE: 0.02484953695766292

# %%
fig, ax = plt.subplots(figsize=(30, 10))
df_plot['Close+1'].plot(ax=ax, label='actual')
df_plot['pred'].plot(ax=ax, label='predict')
# Out:
# <Axes: xlabel='Date'>

# %%
print((df_plot['pred']-df['Close+1'])/df_plot['Close+1'])
# Out:
# Date
# 1980-08-06 00:00:00-04:00         NaN
# 1980-08-07 00:00:00-04:00         NaN
# 1980-08-08 00:00:00-04:00         NaN
# 1980-08-11 00:00:00-04:00         NaN
# 1980-08-12 00:00:00-04:00         NaN
#                                ...
# 2023-06-30 00:00:00-04:00   -0.024440
# 2023-07-03 00:00:00-04:00    0.008864
# 2023-07-05 00:00:00-04:00    0.004618
# 2023-07-06 00:00:00-04:00   -0.005354
# 2023-07-07 00:00:00-04:00         NaN
# Length: 10801, dtype: float64

# %%
(np.abs(df_plot['pred']-df_plot['Close+1'])/df_plot['Close+1']).sum()/df_plot.shape[0]
# Out:
# 0.02484953695766292
