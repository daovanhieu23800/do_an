# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import random
random.seed(0)
import torch
torch.manual_seed(0)
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
data = pd.read_csv('/Users/hieudao/Desktop/ai/do_an/clean_data/clean_apple.csv')

# %%
data['Date'] = pd.to_datetime(data['Date'])
data = data[ data['Date'] < pd.to_datetime('2023-01-01 00:00:00-04:00')]
data = data[ data['Date'] >= pd.to_datetime('2013-01-01 00:00:00-04:00')]
data['Close+1'] = data['Close'].shift(-1)
data = data.dropna()
data.tail(3)
# Out:
#                             Date        Open        High         Low  \
# 10494  2022-12-27 00:00:00-05:00  130.998521  131.028433  128.346242
# 10495  2022-12-28 00:00:00-05:00  129.293484  130.649535  125.504522
# 10496  2022-12-29 00:00:00-05:00  127.618359  130.101127  127.359119
#
#             Close    Volume    NATR_3      RSI_3      ADX_3  CCI_3_0.015  ...  \
# 10494  129.652435  69007800  2.641618  18.464509  41.547614  -100.000000  ...
# 10495  125.674026  85438400  3.409589   8.852589  52.109435  -100.000000  ...
# 10496  129.233658  75703700  3.370665  46.341243  59.150649    20.991684  ...
#
#         BBU_3_2.0  BBB_3_2.0  BBP_3_2.0  min_price_3  max_price_3   mid_price  \
# 10494  132.909909   2.928490   0.150834   128.346242   134.169275  129.687337
# 10495  133.780294   7.516627   0.163572   125.504522   132.035499  128.077029
# 10496  131.756586   5.569812   0.646637   125.504522   131.028433  128.730123
#
#            tema_2    tema_100      tema_8     Close+1
# 10494  129.680351  137.984687  129.586572  125.674026
# 10495  125.750223  137.058611  126.913788  129.233658
# 10496  128.940210  136.379374  127.354561  129.552719
#
# [3 rows x 28 columns]

# %%
data = data.drop(columns=['tema_8', 'tema_100'])
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'NATR_3', 'RSI_3',
#        'ADX_3', 'CCI_3_0.015', 'ROC_3', 'STOCHk_14_3_3', 'STOCHd_14_3_3',
#        'WILLR_3', 'OBV', 'MACD_12_26_9', 'BBL_3_2.0', 'BBM_3_2.0', 'BBU_3_2.0',
#        'BBB_3_2.0', 'BBP_3_2.0', 'min_price_3', 'max_price_3', 'mid_price',
#        'tema_2', 'Close+1'],
#       dtype='object')

# %%
train = data[data['Date'] < pd.to_datetime('2022-01-01 00:00:00-04:00')]

val = data[data['Date'] < pd.to_datetime('2023-01-01 00:00:00-04:00')]
val = data[data['Date'] >= pd.to_datetime('2022-01-01 00:00:00-04:00')]

train = train.drop(columns=['Date'])
val = val.drop(columns=['Date'])


X_train = train.copy().drop(columns=['Close+1'])
y_train = pd.DataFrame()
y_train['Close+1'] = train[['Close+1']]

X_val = val.copy().drop(columns=['Close+1'])
y_val = pd.DataFrame()
y_val['Close+1'] = val[['Close+1']]
X_train.shape,X_val.shape,y_train.shape,y_val.shape
# Out:
# ((2267, 24), (250, 24), (2267, 1), (250, 1))

# %%
X_train = X_train.to_numpy()
y_train = y_train.to_numpy()
X_val = X_val.to_numpy()
y_val = y_val.to_numpy()
X_train.shape, X_val.shape
# Out:
# ((2267, 24), (250, 24))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_train_scaled.shape, X_val_scaled.shape
# Out:
# ((2267, 24), (250, 24))

# %%
from torch.utils.data import DataLoader,Dataset
sequence_length= 5
class TimeSeriesDataset(Dataset):
    def __init__(self, X, y,sequence_length=5):
        self.X =  torch.tensor(X).float()
        self.y = torch.tensor(y).float()
        self.sequence_length = sequence_length
    def __len__(self):
        return len(self.X)

    def __getitem__(self, i): 
       
        if i >= self.sequence_length - 1:
            i_start = i - self.sequence_length + 1
            x = self.X[i_start:(i + 1), :]
        elif self.sequence_length==1:
            return self.X[i],self.y[i]
        else:
            padding = self.X[0].repeat(self.sequence_length - i - 1, 1)
            x = self.X[0:(i + 1), :]
            #print(padding.shape, x.shape)
            x = torch.cat((padding, x), 0)
            # x = self.X[0:i, :]
            #print(x.shape,padding.shape)

        return x, self.y[i]
       
train_dataset = TimeSeriesDataset(X_train_scaled, y_train, sequence_length=sequence_length)
val_dataset = TimeSeriesDataset(X_val_scaled, y_val, sequence_length=sequence_length)

# %%
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers,batch_first=True)

        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

model = LSTM(24, 64, 2)
model.to(device)
model
# Out:
# LSTM(
#   (lstm): LSTM(24, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
losses = []
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    # Set the model to training mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.train()
    train_loss = 0
    num_batches = len(dataloader)

    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)
        train_loss += loss.item()
        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            #print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    print(f"train Error: Avg loss: {train_loss/num_batches:>8f}")
    losses.append((train_loss/num_batches))

# %%
val = []
def test_loop(dataloader, model, loss_fn):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    
    val.append(test_loss)
    
    scheduler.step()
    #curr_lr = optimizer.param_groups[0]['lr']

    print(f"Test Error: Avg loss: {test_loss:>8f}  \n")

# %%
from torch.optim.lr_scheduler import StepLR

learning_rate = 0.01
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
scheduler = StepLR(optimizer, step_size=200, gamma=0.1)

epochs = 2000
for t in range(epochs):
    if epochs %100==0:
        
        print(f"Epoch {t+1}\n-------------------------------")
    
    train_loop(train_loader, model, loss_fn, optimizer)
    test_loop(val_loader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# train Error: Avg loss: 2826.708710
# Test Error: Avg loss: 16118.225342
#
# Epoch 2
# -------------------------------
# train Error: Avg loss: 2009.786701
# Test Error: Avg loss: 13422.669922
#
# Epoch 3
# -------------------------------
# train Error: Avg loss: 1854.480302
# Test Error: Avg loss: 12034.959717
#
# Epoch 4
# -------------------------------
# train Error: Avg loss: 1827.429826
# Test Error: Avg loss: 11256.715820
#
# Epoch 5
# -------------------------------
# train Error: Avg loss: 1442.573734
# Test Error: Avg loss: 9646.592896
#
# Epoch 6
# -------------------------------
# train Error: Avg loss: 1175.382853
# Test Error: Avg loss: 8587.714111
#
# Epoch 7
# -------------------------------
# train Error: Avg loss: 976.124470
# Test Error: Avg loss: 7446.365723
#
# Epoch 8
# -------------------------------
# train Error: Avg loss: 899.852937
# Test Error: Avg loss: 6904.221069
#
# Epoch 9
# -------------------------------
# train Error: Avg loss: 806.815165
# Test Error: Avg loss: 6074.469727
#
# Epoch 10
# -------------------------------
# train Error: Avg loss: 666.711790
# Test Error: Avg loss: 5267.560181
#
# Epoch 11
# -------------------------------
# train Error: Avg loss: 522.008838
# Test Error: Avg loss: 4315.194702
#
# Epoch 12
# -------------------------------
# train Error: Avg loss: 503.989804
# Test Error: Avg loss: 4076.574097
#
# Epoch 13
# -------------------------------
# train Error: Avg loss: 388.269369
# Test Error: Avg loss: 3472.269287
#
# Epoch 14
# -------------------------------
# train Error: Avg loss: 399.053289
# Test Error: Avg loss: 3377.364624
#
# Epoch 15
# -------------------------------
# train Error: Avg loss: 349.763979
# Test Error: Avg loss: 2770.202545
#
# Epoch 16
# -------------------------------
# train Error: Avg loss: 418.017808
# Test Error: Avg loss: 3167.932587
#
# Epoch 17
# -------------------------------
# train Error: Avg loss: 294.050162
# Test Error: Avg loss: 2670.526611
#
# Epoch 18
# -------------------------------
# train Error: Avg loss: 239.379460
# Test Error: Avg loss: 2268.867798
#
# Epoch 19
# -------------------------------
# train Error: Avg loss: 190.140085
# Test Error: Avg loss: 1926.580902
#
# Epoch 20
# -------------------------------
# train Error: Avg loss: 158.363076
# Test Error: Avg loss: 1629.277542
#
# Epoch 21
# -------------------------------
# train Error: Avg loss: 135.741005
# Test Error: Avg loss: 1392.541992
#
# Epoch 22
# -------------------------------
# train Error: Avg loss: 143.074411
# Test Error: Avg loss: 1478.989670
#
# Epoch 23
# -------------------------------
# train Error: Avg loss: 101.583731
# Test Error: Avg loss: 1018.415695
#
# Epoch 24
# -------------------------------
# train Error: Avg loss: 110.820355
# Test Error: Avg loss: 1041.469673
#
# Epoch 25
# -------------------------------
# train Error: Avg loss: 135.652032
# Test Error: Avg loss: 865.011131
#
# Epoch 26
# -------------------------------
# train Error: Avg loss: 242.922875
# Test Error: Avg loss: 880.035027
#
# Epoch 27
# -------------------------------
# train Error: Avg loss: 172.657155
# Test Error: Avg loss: 751.610477
#
# Epoch 28
# -------------------------------
# train Error: Avg loss: 173.929103
# Test Error: Avg loss: 768.382172
#
# Epoch 29
# -------------------------------
# train Error: Avg loss: 127.375856
# Test Error: Avg loss: 738.764103
#
# Epoch 30
# -------------------------------
# train Error: Avg loss: 102.708111
# Test Error: Avg loss: 709.477310
#
# Epoch 31
# -------------------------------
# train Error: Avg loss: 63.407662
# Test Error: Avg loss: 529.155279
#
# Epoch 32
# -------------------------------
# train Error: Avg loss: 77.562157
# Test Error: Avg loss: 519.725571
#
# Epoch 33
# -------------------------------
# train Error: Avg loss: 54.572014
# Test Error: Avg loss: 584.738678
#
# Epoch 34
# -------------------------------
# train Error: Avg loss: 49.341994
# Test Error: Avg loss: 537.087715
#
# Epoch 35
# -------------------------------
# train Error: Avg loss: 64.367412
# Test Error: Avg loss: 395.640532
#
# Epoch 36
# -------------------------------
# train Error: Avg loss: 131.608217
# Test Error: Avg loss: 399.761299
#
# Epoch 37
# -------------------------------
# train Error: Avg loss: 75.037842
# Test Error: Avg loss: 410.599453
#
# Epoch 38
# -------------------------------
# train Error: Avg loss: 55.756381
# Test Error: Avg loss: 401.249220
#
# Epoch 39
# -------------------------------
# train Error: Avg loss: 44.783172
# Test Error: Avg loss: 401.856922
#
# Epoch 40
# -------------------------------
# train Error: Avg loss: 41.926424
# Test Error: Avg loss: 376.026339
#
# Epoch 41
# -------------------------------
# train Error: Avg loss: 57.710316
# Test Error: Avg loss: 303.352591
#
# Epoch 42
# -------------------------------
# train Error: Avg loss: 112.509901
# Test Error: Avg loss: 293.222575
#
# Epoch 43
# -------------------------------
# train Error: Avg loss: 58.878781
# Test Error: Avg loss: 359.415304
#
# Epoch 44
# -------------------------------
# train Error: Avg loss: 55.577835
# Test Error: Avg loss: 341.857246
#
# Epoch 45
# -------------------------------
# train Error: Avg loss: 49.511705
# Test Error: Avg loss: 373.336178
#
# Epoch 46
# -------------------------------
# train Error: Avg loss: 72.568675
# Test Error: Avg loss: 352.952454
#
# Epoch 47
# -------------------------------
# train Error: Avg loss: 81.480619
# Test Error: Avg loss: 675.455688
#
# Epoch 48
# -------------------------------
# train Error: Avg loss: 98.125436
# Test Error: Avg loss: 535.799133
#
# Epoch 49
# -------------------------------
# train Error: Avg loss: 43.381639
# Test Error: Avg loss: 363.373020
#
# Epoch 50
# -------------------------------
# train Error: Avg loss: 29.155664
# Test Error: Avg loss: 204.156401
#
# Epoch 51
# -------------------------------
# train Error: Avg loss: 49.175743
# Test Error: Avg loss: 255.178263
#
# Epoch 52
# -------------------------------
# train Error: Avg loss: 81.431649
# Test Error: Avg loss: 526.908615
#
# Epoch 53
# -------------------------------
# train Error: Avg loss: 117.172062
# Test Error: Avg loss: 244.695488
#
# Epoch 54
# -------------------------------
# train Error: Avg loss: 53.630854
# Test Error: Avg loss: 330.468973
#
# Epoch 55
# -------------------------------
# train Error: Avg loss: 115.565707
# Test Error: Avg loss: 177.961172
#
# Epoch 56
# -------------------------------
# train Error: Avg loss: 55.954507
# Test Error: Avg loss: 422.794682
#
# Epoch 57
# -------------------------------
# train Error: Avg loss: 45.486165
# Test Error: Avg loss: 267.889986
#
# Epoch 58
# -------------------------------
# train Error: Avg loss: 33.664769
# Test Error: Avg loss: 212.374252
#
# Epoch 59
# -------------------------------
# train Error: Avg loss: 34.568594
# Test Error: Avg loss: 214.695883
#
# Epoch 60
# -------------------------------
# train Error: Avg loss: 51.098480
# Test Error: Avg loss: 284.689198
#
# Epoch 61
# -------------------------------
# train Error: Avg loss: 68.428300
# Test Error: Avg loss: 148.674490
#
# Epoch 62
# -------------------------------
# train Error: Avg loss: 39.205334
# Test Error: Avg loss: 362.065304
#
# Epoch 63
# -------------------------------
# train Error: Avg loss: 31.620767
# Test Error: Avg loss: 236.332518
#
# Epoch 64
# -------------------------------
# train Error: Avg loss: 25.340304
# Test Error: Avg loss: 269.257107
#
# Epoch 65
# -------------------------------
# train Error: Avg loss: 24.138728
# Test Error: Avg loss: 184.633476
#
# Epoch 66
# -------------------------------
# train Error: Avg loss: 18.476626
# Test Error: Avg loss: 203.432749
#
# Epoch 67
# -------------------------------
# train Error: Avg loss: 19.457150
# Test Error: Avg loss: 162.865835
#
# Epoch 68
# -------------------------------
# train Error: Avg loss: 16.108246
# Test Error: Avg loss: 161.649359
#
# Epoch 69
# -------------------------------
# train Error: Avg loss: 19.264700
# Test Error: Avg loss: 121.561701
#
# Epoch 70
# -------------------------------
# train Error: Avg loss: 18.180140
# Test Error: Avg loss: 159.234425
#
# Epoch 71
# -------------------------------
# train Error: Avg loss: 26.285990
# Test Error: Avg loss: 110.522370
#
# Epoch 72
# -------------------------------
# train Error: Avg loss: 29.677154
# Test Error: Avg loss: 176.955193
#
# Epoch 73
# -------------------------------
# train Error: Avg loss: 47.926273
# Test Error: Avg loss: 154.401321
#
# Epoch 74
# -------------------------------
# train Error: Avg loss: 70.142430
# Test Error: Avg loss: 499.872223
#
# Epoch 75
# -------------------------------
# train Error: Avg loss: 78.514217
# Test Error: Avg loss: 127.207127
#
# Epoch 76
# -------------------------------
# train Error: Avg loss: 67.459202
# Test Error: Avg loss: 540.055611
#
# Epoch 77
# -------------------------------
# train Error: Avg loss: 35.815639
# Test Error: Avg loss: 128.024683
#
# Epoch 78
# -------------------------------
# train Error: Avg loss: 23.527822
# Test Error: Avg loss: 241.421509
#
# Epoch 79
# -------------------------------
# train Error: Avg loss: 19.851564
# Test Error: Avg loss: 114.119877
#
# Epoch 80
# -------------------------------
# train Error: Avg loss: 20.140322
# Test Error: Avg loss: 159.433224
#
# Epoch 81
# -------------------------------
# train Error: Avg loss: 26.427303
# Test Error: Avg loss: 92.867778
#
# Epoch 82
# -------------------------------
# train Error: Avg loss: 25.822736
# Test Error: Avg loss: 208.990845
#
# Epoch 83
# -------------------------------
# train Error: Avg loss: 37.376798
# Test Error: Avg loss: 107.044069
#
# Epoch 84
# -------------------------------
# train Error: Avg loss: 45.834760
# Test Error: Avg loss: 444.424301
#
# Epoch 85
# -------------------------------
# train Error: Avg loss: 32.932556
# Test Error: Avg loss: 106.455121
#
# Epoch 86
# -------------------------------
# train Error: Avg loss: 22.763764
# Test Error: Avg loss: 287.305737
#
# Epoch 87
# -------------------------------
# train Error: Avg loss: 15.312549
# Test Error: Avg loss: 140.502260
#
# Epoch 88
# -------------------------------
# train Error: Avg loss: 16.805186
# Test Error: Avg loss: 197.388796
#
# Epoch 89
# -------------------------------
# train Error: Avg loss: 18.934946
# Test Error: Avg loss: 101.099915
#
# Epoch 90
# -------------------------------
# train Error: Avg loss: 11.624283
# Test Error: Avg loss: 168.923223
#
# Epoch 91
# -------------------------------
# train Error: Avg loss: 11.568646
# Test Error: Avg loss: 91.127635
#
# Epoch 92
# -------------------------------
# train Error: Avg loss: 9.006773
# Test Error: Avg loss: 137.982449
#
# Epoch 93
# -------------------------------
# train Error: Avg loss: 9.233509
# Test Error: Avg loss: 88.127543
#
# Epoch 94
# -------------------------------
# train Error: Avg loss: 7.765702
# Test Error: Avg loss: 111.058107
#
# Epoch 95
# -------------------------------
# train Error: Avg loss: 7.988022
# Test Error: Avg loss: 76.222840
#
# Epoch 96
# -------------------------------
# train Error: Avg loss: 6.828188
# Test Error: Avg loss: 92.257426
#
# Epoch 97
# -------------------------------
# train Error: Avg loss: 6.991047
# Test Error: Avg loss: 71.635005
#
# Epoch 98
# -------------------------------
# train Error: Avg loss: 6.583150
# Test Error: Avg loss: 75.983583
#
# Epoch 99
# -------------------------------
# train Error: Avg loss: 8.546256
# Test Error: Avg loss: 69.018069
#
# Epoch 100
# -------------------------------
# train Error: Avg loss: 8.672451
# Test Error: Avg loss: 97.668019
#
# Epoch 101
# -------------------------------
# train Error: Avg loss: 15.081590
# Test Error: Avg loss: 73.663190
#
# Epoch 102
# -------------------------------
# train Error: Avg loss: 34.500790
# Test Error: Avg loss: 214.686691
#
# Epoch 103
# -------------------------------
# train Error: Avg loss: 77.590934
# Test Error: Avg loss: 126.959396
#
# Epoch 104
# -------------------------------
# train Error: Avg loss: 125.607525
# Test Error: Avg loss: 589.642719
#
# Epoch 105
# -------------------------------
# train Error: Avg loss: 121.188231
# Test Error: Avg loss: 181.564539
#
# Epoch 106
# -------------------------------
# train Error: Avg loss: 74.775389
# Test Error: Avg loss: 96.415131
#
# Epoch 107
# -------------------------------
# train Error: Avg loss: 78.469397
# Test Error: Avg loss: 400.923389
#
# Epoch 108
# -------------------------------
# train Error: Avg loss: 67.827144
# Test Error: Avg loss: 73.144551
#
# Epoch 109
# -------------------------------
# train Error: Avg loss: 54.019559
# Test Error: Avg loss: 401.654369
#
# Epoch 110
# -------------------------------
# train Error: Avg loss: 28.664049
# Test Error: Avg loss: 120.699581
#
# Epoch 111
# -------------------------------
# train Error: Avg loss: 18.553220
# Test Error: Avg loss: 116.836811
#
# Epoch 112
# -------------------------------
# train Error: Avg loss: 21.029687
# Test Error: Avg loss: 86.600701
#
# Epoch 113
# -------------------------------
# train Error: Avg loss: 14.231571
# Test Error: Avg loss: 110.751104
#
# Epoch 114
# -------------------------------
# train Error: Avg loss: 14.378225
# Test Error: Avg loss: 73.819556
#
# Epoch 115
# -------------------------------
# train Error: Avg loss: 9.655254
# Test Error: Avg loss: 101.052629
#
# Epoch 116
# -------------------------------
# train Error: Avg loss: 13.945492
# Test Error: Avg loss: 66.156361
#
# Epoch 117
# -------------------------------
# train Error: Avg loss: 8.630683
# Test Error: Avg loss: 90.596107
#
# Epoch 118
# -------------------------------
# train Error: Avg loss: 7.225259
# Test Error: Avg loss: 62.477225
#
# Epoch 119
# -------------------------------
# train Error: Avg loss: 7.145739
# Test Error: Avg loss: 73.097264
#
# Epoch 120
# -------------------------------
# train Error: Avg loss: 7.103888
# Test Error: Avg loss: 63.596336
#
# Epoch 121
# -------------------------------
# train Error: Avg loss: 6.950312
# Test Error: Avg loss: 77.914079
#
# Epoch 122
# -------------------------------
# train Error: Avg loss: 6.669003
# Test Error: Avg loss: 57.544766
#
# Epoch 123
# -------------------------------
# train Error: Avg loss: 5.586206
# Test Error: Avg loss: 79.244747
#
# Epoch 124
# -------------------------------
# train Error: Avg loss: 6.068139
# Test Error: Avg loss: 55.417365
#
# Epoch 125
# -------------------------------
# train Error: Avg loss: 5.317211
# Test Error: Avg loss: 79.220648
#
# Epoch 126
# -------------------------------
# train Error: Avg loss: 6.093773
# Test Error: Avg loss: 53.716671
#
# Epoch 127
# -------------------------------
# train Error: Avg loss: 5.352580
# Test Error: Avg loss: 80.039962
#
# Epoch 128
# -------------------------------
# train Error: Avg loss: 6.472028
# Test Error: Avg loss: 58.852386
#
# Epoch 129
# -------------------------------
# train Error: Avg loss: 7.704286
# Test Error: Avg loss: 75.381289
#
# Epoch 130
# -------------------------------
# train Error: Avg loss: 15.491648
# Test Error: Avg loss: 58.656630
#
# Epoch 131
# -------------------------------
# train Error: Avg loss: 30.606953
# Test Error: Avg loss: 152.960260
#
# Epoch 132
# -------------------------------
# train Error: Avg loss: 56.951477
# Test Error: Avg loss: 86.184803
#
# Epoch 133
# -------------------------------
# train Error: Avg loss: 79.354773
# Test Error: Avg loss: 520.864822
#
# Epoch 134
# -------------------------------
# train Error: Avg loss: 66.509793
# Test Error: Avg loss: 118.736329
#
# Epoch 135
# -------------------------------
# train Error: Avg loss: 33.258640
# Test Error: Avg loss: 227.899300
#
# Epoch 136
# -------------------------------
# train Error: Avg loss: 29.501658
# Test Error: Avg loss: 112.033222
#
# Epoch 137
# -------------------------------
# train Error: Avg loss: 25.426406
# Test Error: Avg loss: 196.996338
#
# Epoch 138
# -------------------------------
# train Error: Avg loss: 23.766028
# Test Error: Avg loss: 68.379474
#
# Epoch 139
# -------------------------------
# train Error: Avg loss: 26.147997
# Test Error: Avg loss: 234.728333
#
# Epoch 140
# -------------------------------
# train Error: Avg loss: 28.723896
# Test Error: Avg loss: 57.712288
#
# Epoch 141
# -------------------------------
# train Error: Avg loss: 31.893275
# Test Error: Avg loss: 265.621731
#
# Epoch 142
# -------------------------------
# train Error: Avg loss: 40.730067
# Test Error: Avg loss: 55.665815
#
# Epoch 143
# -------------------------------
# train Error: Avg loss: 28.710489
# Test Error: Avg loss: 309.459724
#
# Epoch 144
# -------------------------------
# train Error: Avg loss: 14.448606
# Test Error: Avg loss: 93.923025
#
# Epoch 145
# -------------------------------
# train Error: Avg loss: 10.010066
# Test Error: Avg loss: 119.360743
#
# Epoch 146
# -------------------------------
# train Error: Avg loss: 7.668781
# Test Error: Avg loss: 72.528896
#
# Epoch 147
# -------------------------------
# train Error: Avg loss: 5.797556
# Test Error: Avg loss: 78.219779
#
# Epoch 148
# -------------------------------
# train Error: Avg loss: 5.014617
# Test Error: Avg loss: 68.417121
#
# Epoch 149
# -------------------------------
# train Error: Avg loss: 6.021813
# Test Error: Avg loss: 70.203852
#
# Epoch 150
# -------------------------------
# train Error: Avg loss: 5.555387
# Test Error: Avg loss: 63.148363
#
# Epoch 151
# -------------------------------
# train Error: Avg loss: 5.247807
# Test Error: Avg loss: 65.353935
#
# Epoch 152
# -------------------------------
# train Error: Avg loss: 4.570170
# Test Error: Avg loss: 56.178737
#
# Epoch 153
# -------------------------------
# train Error: Avg loss: 4.722420
# Test Error: Avg loss: 66.145379
#
# Epoch 154
# -------------------------------
# train Error: Avg loss: 4.524002
# Test Error: Avg loss: 55.152210
#
# Epoch 155
# -------------------------------
# train Error: Avg loss: 4.895663
# Test Error: Avg loss: 66.664645
#
# Epoch 156
# -------------------------------
# train Error: Avg loss: 6.029652
# Test Error: Avg loss: 57.313782
#
# Epoch 157
# -------------------------------
# train Error: Avg loss: 7.502142
# Test Error: Avg loss: 88.003430
#
# Epoch 158
# -------------------------------
# train Error: Avg loss: 12.278816
# Test Error: Avg loss: 65.334651
#
# Epoch 159
# -------------------------------
# train Error: Avg loss: 26.015786
# Test Error: Avg loss: 220.333721
#
# Epoch 160
# -------------------------------
# train Error: Avg loss: 39.867391
# Test Error: Avg loss: 70.622871
#
# Epoch 161
# -------------------------------
# train Error: Avg loss: 53.264678
# Test Error: Avg loss: 459.490067
#
# Epoch 162
# -------------------------------
# train Error: Avg loss: 33.822368
# Test Error: Avg loss: 62.069788
#
# Epoch 163
# -------------------------------
# train Error: Avg loss: 22.598455
# Test Error: Avg loss: 175.042580
#
# Epoch 164
# -------------------------------
# train Error: Avg loss: 18.519478
# Test Error: Avg loss: 83.289562
#
# Epoch 165
# -------------------------------
# train Error: Avg loss: 16.419788
# Test Error: Avg loss: 89.806752
#
# Epoch 166
# -------------------------------
# train Error: Avg loss: 15.198156
# Test Error: Avg loss: 43.579017
#
# Epoch 167
# -------------------------------
# train Error: Avg loss: 10.043179
# Test Error: Avg loss: 97.276302
#
# Epoch 168
# -------------------------------
# train Error: Avg loss: 8.283807
# Test Error: Avg loss: 48.888946
#
# Epoch 169
# -------------------------------
# train Error: Avg loss: 7.863152
# Test Error: Avg loss: 90.263082
#
# Epoch 170
# -------------------------------
# train Error: Avg loss: 7.646504
# Test Error: Avg loss: 47.565396
#
# Epoch 171
# -------------------------------
# train Error: Avg loss: 6.211903
# Test Error: Avg loss: 87.001887
#
# Epoch 172
# -------------------------------
# train Error: Avg loss: 5.121053
# Test Error: Avg loss: 47.987807
#
# Epoch 173
# -------------------------------
# train Error: Avg loss: 4.464809
# Test Error: Avg loss: 71.234156
#
# Epoch 174
# -------------------------------
# train Error: Avg loss: 4.071442
# Test Error: Avg loss: 58.341063
#
# Epoch 175
# -------------------------------
# train Error: Avg loss: 3.853099
# Test Error: Avg loss: 67.090226
#
# Epoch 176
# -------------------------------
# train Error: Avg loss: 4.256515
# Test Error: Avg loss: 49.938256
#
# Epoch 177
# -------------------------------
# train Error: Avg loss: 4.095694
# Test Error: Avg loss: 75.931397
#
# Epoch 178
# -------------------------------
# train Error: Avg loss: 4.367713
# Test Error: Avg loss: 50.155514
#
# Epoch 179
# -------------------------------
# train Error: Avg loss: 4.775148
# Test Error: Avg loss: 71.524698
#
# Epoch 180
# -------------------------------
# train Error: Avg loss: 6.300154
# Test Error: Avg loss: 48.331307
#
# Epoch 181
# -------------------------------
# train Error: Avg loss: 8.092077
# Test Error: Avg loss: 82.566254
#
# Epoch 182
# -------------------------------
# train Error: Avg loss: 14.675739
# Test Error: Avg loss: 72.591431
#
# Epoch 183
# -------------------------------
# train Error: Avg loss: 49.482681
# Test Error: Avg loss: 251.409344
#
# Epoch 184
# -------------------------------
# train Error: Avg loss: 102.406914
# Test Error: Avg loss: 143.527351
#
# Epoch 185
# -------------------------------
# train Error: Avg loss: 205.038916
# Test Error: Avg loss: 692.813377
#
# Epoch 186
# -------------------------------
# train Error: Avg loss: 120.329376
# Test Error: Avg loss: 148.508806
#
# Epoch 187
# -------------------------------
# train Error: Avg loss: 57.845001
# Test Error: Avg loss: 128.722382
#
# Epoch 188
# -------------------------------
# train Error: Avg loss: 41.625959
# Test Error: Avg loss: 53.712209
#
# Epoch 189
# -------------------------------
# train Error: Avg loss: 18.544832
# Test Error: Avg loss: 98.673435
#
# Epoch 190
# -------------------------------
# train Error: Avg loss: 19.229064
# Test Error: Avg loss: 51.569407
#
# Epoch 191
# -------------------------------
# train Error: Avg loss: 28.899984
# Test Error: Avg loss: 180.378830
#
# Epoch 192
# -------------------------------
# train Error: Avg loss: 29.194593
# Test Error: Avg loss: 53.313399
#
# Epoch 193
# -------------------------------
# train Error: Avg loss: 52.555591
# Test Error: Avg loss: 347.303192
#
# Epoch 194
# -------------------------------
# train Error: Avg loss: 34.695113
# Test Error: Avg loss: 53.468248
#
# Epoch 195
# -------------------------------
# train Error: Avg loss: 16.889190
# Test Error: Avg loss: 168.093168
#
# Epoch 196
# -------------------------------
# train Error: Avg loss: 9.467741
# Test Error: Avg loss: 75.050396
#
# Epoch 197
# -------------------------------
# train Error: Avg loss: 7.838396
# Test Error: Avg loss: 80.588847
#
# Epoch 198
# -------------------------------
# train Error: Avg loss: 5.949810
# Test Error: Avg loss: 67.894132
#
# Epoch 199
# -------------------------------
# train Error: Avg loss: 5.100450
# Test Error: Avg loss: 82.276746
#
# Epoch 200
# -------------------------------
# train Error: Avg loss: 4.799875
# Test Error: Avg loss: 70.015412
#
# Epoch 201
# -------------------------------
# train Error: Avg loss: 4.098235
# Test Error: Avg loss: 72.987514
#
# Epoch 202
# -------------------------------
# train Error: Avg loss: 3.994206
# Test Error: Avg loss: 74.084912
#
# Epoch 203
# -------------------------------
# train Error: Avg loss: 3.908643
# Test Error: Avg loss: 75.009913
#
# Epoch 204
# -------------------------------
# train Error: Avg loss: 3.838186
# Test Error: Avg loss: 75.699157
#
# Epoch 205
# -------------------------------
# train Error: Avg loss: 3.778744
# Test Error: Avg loss: 76.198821
#
# Epoch 206
# -------------------------------
# train Error: Avg loss: 3.721943
# Test Error: Avg loss: 76.442019
#
# Epoch 207
# -------------------------------
# train Error: Avg loss: 3.680637
# Test Error: Avg loss: 76.510271
#
# Epoch 208
# -------------------------------
# train Error: Avg loss: 3.637568
# Test Error: Avg loss: 76.591580
#
# Epoch 209
# -------------------------------
# train Error: Avg loss: 3.591520
# Test Error: Avg loss: 76.581231
#
# Epoch 210
# -------------------------------
# train Error: Avg loss: 3.546880
# Test Error: Avg loss: 76.499969
#
# Epoch 211
# -------------------------------
# train Error: Avg loss: 3.502745
# Test Error: Avg loss: 76.387632
#
# Epoch 212
# -------------------------------
# train Error: Avg loss: 3.460574
# Test Error: Avg loss: 76.261373
#
# Epoch 213
# -------------------------------
# train Error: Avg loss: 3.422151
# Test Error: Avg loss: 76.123985
#
# Epoch 214
# -------------------------------
# train Error: Avg loss: 3.387245
# Test Error: Avg loss: 75.975164
#
# Epoch 215
# -------------------------------
# train Error: Avg loss: 3.354628
# Test Error: Avg loss: 75.814340
#
# Epoch 216
# -------------------------------
# train Error: Avg loss: 3.323365
# Test Error: Avg loss: 75.642307
#
# Epoch 217
# -------------------------------
# train Error: Avg loss: 3.293008
# Test Error: Avg loss: 75.458344
#
# Epoch 218
# -------------------------------
# train Error: Avg loss: 3.263642
# Test Error: Avg loss: 75.264306
#
# Epoch 219
# -------------------------------
# train Error: Avg loss: 3.234909
# Test Error: Avg loss: 75.070019
#
# Epoch 220
# -------------------------------
# train Error: Avg loss: 3.206021
# Test Error: Avg loss: 74.886017
#
# Epoch 221
# -------------------------------
# train Error: Avg loss: 3.176432
# Test Error: Avg loss: 74.715453
#
# Epoch 222
# -------------------------------
# train Error: Avg loss: 3.147857
# Test Error: Avg loss: 74.557168
#
# Epoch 223
# -------------------------------
# train Error: Avg loss: 3.121503
# Test Error: Avg loss: 74.391699
#
# Epoch 224
# -------------------------------
# train Error: Avg loss: 3.095766
# Test Error: Avg loss: 74.204876
#
# Epoch 225
# -------------------------------
# train Error: Avg loss: 3.069460
# Test Error: Avg loss: 74.011117
#
# Epoch 226
# -------------------------------
# train Error: Avg loss: 3.042808
# Test Error: Avg loss: 73.831732
#
# Epoch 227
# -------------------------------
# train Error: Avg loss: 3.018743
# Test Error: Avg loss: 73.667012
#
# Epoch 228
# -------------------------------
# train Error: Avg loss: 2.996638
# Test Error: Avg loss: 73.495409
#
# Epoch 229
# -------------------------------
# train Error: Avg loss: 2.974845
# Test Error: Avg loss: 73.316374
#
# Epoch 230
# -------------------------------
# train Error: Avg loss: 2.952906
# Test Error: Avg loss: 73.136096
#
# Epoch 231
# -------------------------------
# train Error: Avg loss: 2.931007
# Test Error: Avg loss: 72.939929
#
# Epoch 232
# -------------------------------
# train Error: Avg loss: 2.909915
# Test Error: Avg loss: 72.722277
#
# Epoch 233
# -------------------------------
# train Error: Avg loss: 2.889696
# Test Error: Avg loss: 72.503275
#
# Epoch 234
# -------------------------------
# train Error: Avg loss: 2.869921
# Test Error: Avg loss: 72.288745
#
# Epoch 235
# -------------------------------
# train Error: Avg loss: 2.850239
# Test Error: Avg loss: 72.064851
#
# Epoch 236
# -------------------------------
# train Error: Avg loss: 2.830299
# Test Error: Avg loss: 71.828511
#
# Epoch 237
# -------------------------------
# train Error: Avg loss: 2.809870
# Test Error: Avg loss: 71.574357
#
# Epoch 238
# -------------------------------
# train Error: Avg loss: 2.789111
# Test Error: Avg loss: 71.293947
#
# Epoch 239
# -------------------------------
# train Error: Avg loss: 2.768254
# Test Error: Avg loss: 70.971931
#
# Epoch 240
# -------------------------------
# train Error: Avg loss: 2.746844
# Test Error: Avg loss: 70.597972
#
# Epoch 241
# -------------------------------
# train Error: Avg loss: 2.724193
# Test Error: Avg loss: 70.169389
#
# Epoch 242
# -------------------------------
# train Error: Avg loss: 2.699619
# Test Error: Avg loss: 69.672973
#
# Epoch 243
# -------------------------------
# train Error: Avg loss: 2.672455
# Test Error: Avg loss: 69.093138
#
# Epoch 244
# -------------------------------
# train Error: Avg loss: 2.642300
# Test Error: Avg loss: 68.416410
#
# Epoch 245
# -------------------------------
# train Error: Avg loss: 2.610018
# Test Error: Avg loss: 67.655107
#
# Epoch 246
# -------------------------------
# train Error: Avg loss: 2.578654
# Test Error: Avg loss: 66.881782
#
# Epoch 247
# -------------------------------
# train Error: Avg loss: 2.550976
# Test Error: Avg loss: 66.205039
#
# Epoch 248
# -------------------------------
# train Error: Avg loss: 2.526674
# Test Error: Avg loss: 65.669799
#
# Epoch 249
# -------------------------------
# train Error: Avg loss: 2.504011
# Test Error: Avg loss: 65.256836
#
# Epoch 250
# -------------------------------
# train Error: Avg loss: 2.481749
# Test Error: Avg loss: 64.931268
#
# Epoch 251
# -------------------------------
# train Error: Avg loss: 2.459506
# Test Error: Avg loss: 64.667919
#
# Epoch 252
# -------------------------------
# train Error: Avg loss: 2.438623
# Test Error: Avg loss: 64.446279
#
# Epoch 253
# -------------------------------
# train Error: Avg loss: 2.419896
# Test Error: Avg loss: 64.250715
#
# Epoch 254
# -------------------------------
# train Error: Avg loss: 2.402694
# Test Error: Avg loss: 64.067372
#
# Epoch 255
# -------------------------------
# train Error: Avg loss: 2.386537
# Test Error: Avg loss: 63.891399
#
# Epoch 256
# -------------------------------
# train Error: Avg loss: 2.371212
# Test Error: Avg loss: 63.713964
#
# Epoch 257
# -------------------------------
# train Error: Avg loss: 2.356586
# Test Error: Avg loss: 63.536460
#
# Epoch 258
# -------------------------------
# train Error: Avg loss: 2.342523
# Test Error: Avg loss: 63.359850
#
# Epoch 259
# -------------------------------
# train Error: Avg loss: 2.328988
# Test Error: Avg loss: 63.204066
#
# Epoch 260
# -------------------------------
# train Error: Avg loss: 2.315831
# Test Error: Avg loss: 63.072180
#
# Epoch 261
# -------------------------------
# train Error: Avg loss: 2.303017
# Test Error: Avg loss: 62.958780
#
# Epoch 262
# -------------------------------
# train Error: Avg loss: 2.290256
# Test Error: Avg loss: 62.853881
#
# Epoch 263
# -------------------------------
# train Error: Avg loss: 2.277921
# Test Error: Avg loss: 62.750603
#
# Epoch 264
# -------------------------------
# train Error: Avg loss: 2.265871
# Test Error: Avg loss: 62.716111
#
# Epoch 265
# -------------------------------
# train Error: Avg loss: 2.255664
# Test Error: Avg loss: 62.554162
#
# Epoch 266
# -------------------------------
# train Error: Avg loss: 2.248258
# Test Error: Avg loss: 62.511889
#
# Epoch 267
# -------------------------------
# train Error: Avg loss: 2.247584
# Test Error: Avg loss: 62.354787
#
# Epoch 268
# -------------------------------
# train Error: Avg loss: 2.261597
# Test Error: Avg loss: 61.274531
#
# Epoch 269
# -------------------------------
# train Error: Avg loss: 2.241099
# Test Error: Avg loss: 63.320063
#
# Epoch 270
# -------------------------------
# train Error: Avg loss: 2.231313
# Test Error: Avg loss: 60.647593
#
# Epoch 271
# -------------------------------
# train Error: Avg loss: 2.197772
# Test Error: Avg loss: 63.083695
#
# Epoch 272
# -------------------------------
# train Error: Avg loss: 2.180210
# Test Error: Avg loss: 61.395291
#
# Epoch 273
# -------------------------------
# train Error: Avg loss: 2.161593
# Test Error: Avg loss: 62.667725
#
# Epoch 274
# -------------------------------
# train Error: Avg loss: 2.145935
# Test Error: Avg loss: 61.423367
#
# Epoch 275
# -------------------------------
# train Error: Avg loss: 2.130395
# Test Error: Avg loss: 62.312877
#
# Epoch 276
# -------------------------------
# train Error: Avg loss: 2.117995
# Test Error: Avg loss: 61.035989
#
# Epoch 277
# -------------------------------
# train Error: Avg loss: 2.104036
# Test Error: Avg loss: 62.041743
#
# Epoch 278
# -------------------------------
# train Error: Avg loss: 2.096105
# Test Error: Avg loss: 60.445764
#
# Epoch 279
# -------------------------------
# train Error: Avg loss: 2.081730
# Test Error: Avg loss: 61.983065
#
# Epoch 280
# -------------------------------
# train Error: Avg loss: 2.073700
# Test Error: Avg loss: 59.749716
#
# Epoch 281
# -------------------------------
# train Error: Avg loss: 2.050870
# Test Error: Avg loss: 62.169542
#
# Epoch 282
# -------------------------------
# train Error: Avg loss: 2.031761
# Test Error: Avg loss: 59.232815
#
# Epoch 283
# -------------------------------
# train Error: Avg loss: 1.995475
# Test Error: Avg loss: 61.645478
#
# Epoch 284
# -------------------------------
# train Error: Avg loss: 1.976623
# Test Error: Avg loss: 59.478746
#
# Epoch 285
# -------------------------------
# train Error: Avg loss: 1.950803
# Test Error: Avg loss: 60.912958
#
# Epoch 286
# -------------------------------
# train Error: Avg loss: 1.940637
# Test Error: Avg loss: 59.061827
#
# Epoch 287
# -------------------------------
# train Error: Avg loss: 1.919649
# Test Error: Avg loss: 60.604026
#
# Epoch 288
# -------------------------------
# train Error: Avg loss: 1.918915
# Test Error: Avg loss: 58.445101
#
# Epoch 289
# -------------------------------
# train Error: Avg loss: 1.899158
# Test Error: Avg loss: 59.889960
#
# Epoch 290
# -------------------------------
# train Error: Avg loss: 1.914363
# Test Error: Avg loss: 57.812681
#
# Epoch 291
# -------------------------------
# train Error: Avg loss: 1.898950
# Test Error: Avg loss: 60.166172
#
# Epoch 292
# -------------------------------
# train Error: Avg loss: 1.935652
# Test Error: Avg loss: 57.025939
#
# Epoch 293
# -------------------------------
# train Error: Avg loss: 1.922366
# Test Error: Avg loss: 59.897425
#
# Epoch 294
# -------------------------------
# train Error: Avg loss: 1.951284
# Test Error: Avg loss: 55.802505
#
# Epoch 295
# -------------------------------
# train Error: Avg loss: 1.901815
# Test Error: Avg loss: 61.100702
#
# Epoch 296
# -------------------------------
# train Error: Avg loss: 1.903221
# Test Error: Avg loss: 55.051736
#
# Epoch 297
# -------------------------------
# train Error: Avg loss: 1.837176
# Test Error: Avg loss: 60.626446
#
# Epoch 298
# -------------------------------
# train Error: Avg loss: 1.823045
# Test Error: Avg loss: 56.761719
#
# Epoch 299
# -------------------------------
# train Error: Avg loss: 1.775301
# Test Error: Avg loss: 58.811025
#
# Epoch 300
# -------------------------------
# train Error: Avg loss: 1.784538
# Test Error: Avg loss: 56.895454
#
# Epoch 301
# -------------------------------
# train Error: Avg loss: 1.747982
# Test Error: Avg loss: 58.726139
#
# Epoch 302
# -------------------------------
# train Error: Avg loss: 1.760442
# Test Error: Avg loss: 56.247090
#
# Epoch 303
# -------------------------------
# train Error: Avg loss: 1.724569
# Test Error: Avg loss: 58.171229
#
# Epoch 304
# -------------------------------
# train Error: Avg loss: 1.741148
# Test Error: Avg loss: 56.339417
#
# Epoch 305
# -------------------------------
# train Error: Avg loss: 1.716078
# Test Error: Avg loss: 58.596483
#
# Epoch 306
# -------------------------------
# train Error: Avg loss: 1.759547
# Test Error: Avg loss: 55.272130
#
# Epoch 307
# -------------------------------
# train Error: Avg loss: 1.764520
# Test Error: Avg loss: 58.002517
#
# Epoch 308
# -------------------------------
# train Error: Avg loss: 1.872778
# Test Error: Avg loss: 54.086676
#
# Epoch 309
# -------------------------------
# train Error: Avg loss: 1.815753
# Test Error: Avg loss: 61.966676
#
# Epoch 310
# -------------------------------
# train Error: Avg loss: 1.836968
# Test Error: Avg loss: 52.427326
#
# Epoch 311
# -------------------------------
# train Error: Avg loss: 1.725515
# Test Error: Avg loss: 60.585163
#
# Epoch 312
# -------------------------------
# train Error: Avg loss: 1.714093
# Test Error: Avg loss: 53.922953
#
# Epoch 313
# -------------------------------
# train Error: Avg loss: 1.637766
# Test Error: Avg loss: 57.432822
#
# Epoch 314
# -------------------------------
# train Error: Avg loss: 1.644958
# Test Error: Avg loss: 54.843942
#
# Epoch 315
# -------------------------------
# train Error: Avg loss: 1.581473
# Test Error: Avg loss: 56.214729
#
# Epoch 316
# -------------------------------
# train Error: Avg loss: 1.594336
# Test Error: Avg loss: 54.853636
#
# Epoch 317
# -------------------------------
# train Error: Avg loss: 1.548840
# Test Error: Avg loss: 56.361140
#
# Epoch 318
# -------------------------------
# train Error: Avg loss: 1.567669
# Test Error: Avg loss: 54.287115
#
# Epoch 319
# -------------------------------
# train Error: Avg loss: 1.539861
# Test Error: Avg loss: 56.589666
#
# Epoch 320
# -------------------------------
# train Error: Avg loss: 1.576338
# Test Error: Avg loss: 53.517961
#
# Epoch 321
# -------------------------------
# train Error: Avg loss: 1.581492
# Test Error: Avg loss: 56.766725
#
# Epoch 322
# -------------------------------
# train Error: Avg loss: 1.690302
# Test Error: Avg loss: 51.990999
#
# Epoch 323
# -------------------------------
# train Error: Avg loss: 1.752398
# Test Error: Avg loss: 59.772803
#
# Epoch 324
# -------------------------------
# train Error: Avg loss: 1.851539
# Test Error: Avg loss: 50.256364
#
# Epoch 325
# -------------------------------
# train Error: Avg loss: 1.903443
# Test Error: Avg loss: 61.528625
#
# Epoch 326
# -------------------------------
# train Error: Avg loss: 1.891787
# Test Error: Avg loss: 49.918948
#
# Epoch 327
# -------------------------------
# train Error: Avg loss: 1.773355
# Test Error: Avg loss: 62.815377
#
# Epoch 328
# -------------------------------
# train Error: Avg loss: 1.681872
# Test Error: Avg loss: 48.289470
#
# Epoch 329
# -------------------------------
# train Error: Avg loss: 1.519857
# Test Error: Avg loss: 55.687085
#
# Epoch 330
# -------------------------------
# train Error: Avg loss: 1.475582
# Test Error: Avg loss: 51.155129
#
# Epoch 331
# -------------------------------
# train Error: Avg loss: 1.392135
# Test Error: Avg loss: 52.784269
#
# Epoch 332
# -------------------------------
# train Error: Avg loss: 1.381003
# Test Error: Avg loss: 52.037386
#
# Epoch 333
# -------------------------------
# train Error: Avg loss: 1.336048
# Test Error: Avg loss: 52.803990
#
# Epoch 334
# -------------------------------
# train Error: Avg loss: 1.331274
# Test Error: Avg loss: 52.211150
#
# Epoch 335
# -------------------------------
# train Error: Avg loss: 1.303973
# Test Error: Avg loss: 52.813038
#
# Epoch 336
# -------------------------------
# train Error: Avg loss: 1.298876
# Test Error: Avg loss: 52.584581
#
# Epoch 337
# -------------------------------
# train Error: Avg loss: 1.290056
# Test Error: Avg loss: 53.789018
#
# Epoch 338
# -------------------------------
# train Error: Avg loss: 1.284230
# Test Error: Avg loss: 52.358515
#
# Epoch 339
# -------------------------------
# train Error: Avg loss: 1.306975
# Test Error: Avg loss: 54.775785
#
# Epoch 340
# -------------------------------
# train Error: Avg loss: 1.291454
# Test Error: Avg loss: 51.859529
#
# Epoch 341
# -------------------------------
# train Error: Avg loss: 1.341037
# Test Error: Avg loss: 55.504566
#
# Epoch 342
# -------------------------------
# train Error: Avg loss: 1.453098
# Test Error: Avg loss: 51.198563
#
# Epoch 343
# -------------------------------
# train Error: Avg loss: 1.651012
# Test Error: Avg loss: 57.757214
#
# Epoch 344
# -------------------------------
# train Error: Avg loss: 2.180751
# Test Error: Avg loss: 47.748120
#
# Epoch 345
# -------------------------------
# train Error: Avg loss: 2.370908
# Test Error: Avg loss: 62.520904
#
# Epoch 346
# -------------------------------
# train Error: Avg loss: 2.646967
# Test Error: Avg loss: 42.839272
#
# Epoch 347
# -------------------------------
# train Error: Avg loss: 2.636288
# Test Error: Avg loss: 69.811224
#
# Epoch 348
# -------------------------------
# train Error: Avg loss: 1.803973
# Test Error: Avg loss: 42.220063
#
# Epoch 349
# -------------------------------
# train Error: Avg loss: 1.445868
# Test Error: Avg loss: 53.829913
#
# Epoch 350
# -------------------------------
# train Error: Avg loss: 1.328257
# Test Error: Avg loss: 49.493729
#
# Epoch 351
# -------------------------------
# train Error: Avg loss: 1.216871
# Test Error: Avg loss: 49.935062
#
# Epoch 352
# -------------------------------
# train Error: Avg loss: 1.186204
# Test Error: Avg loss: 49.645961
#
# Epoch 353
# -------------------------------
# train Error: Avg loss: 1.144958
# Test Error: Avg loss: 49.579571
#
# Epoch 354
# -------------------------------
# train Error: Avg loss: 1.132332
# Test Error: Avg loss: 49.147790
#
# Epoch 355
# -------------------------------
# train Error: Avg loss: 1.116052
# Test Error: Avg loss: 49.037908
#
# Epoch 356
# -------------------------------
# train Error: Avg loss: 1.098579
# Test Error: Avg loss: 48.730900
#
# Epoch 357
# -------------------------------
# train Error: Avg loss: 1.098012
# Test Error: Avg loss: 48.667629
#
# Epoch 358
# -------------------------------
# train Error: Avg loss: 1.075070
# Test Error: Avg loss: 48.462767
#
# Epoch 359
# -------------------------------
# train Error: Avg loss: 1.078226
# Test Error: Avg loss: 48.392549
#
# Epoch 360
# -------------------------------
# train Error: Avg loss: 1.054060
# Test Error: Avg loss: 48.158057
#
# Epoch 361
# -------------------------------
# train Error: Avg loss: 1.052715
# Test Error: Avg loss: 47.900415
#
# Epoch 362
# -------------------------------
# train Error: Avg loss: 1.053774
# Test Error: Avg loss: 47.710303
#
# Epoch 363
# -------------------------------
# train Error: Avg loss: 1.058687
# Test Error: Avg loss: 47.964467
#
# Epoch 364
# -------------------------------
# train Error: Avg loss: 1.122946
# Test Error: Avg loss: 47.218957
#
# Epoch 365
# -------------------------------
# train Error: Avg loss: 1.142403
# Test Error: Avg loss: 49.703853
#
# Epoch 366
# -------------------------------
# train Error: Avg loss: 1.192549
# Test Error: Avg loss: 45.539608
#
# Epoch 367
# -------------------------------
# train Error: Avg loss: 1.192479
# Test Error: Avg loss: 51.459606
#
# Epoch 368
# -------------------------------
# train Error: Avg loss: 1.181574
# Test Error: Avg loss: 44.677967
#
# Epoch 369
# -------------------------------
# train Error: Avg loss: 1.146464
# Test Error: Avg loss: 52.059283
#
# Epoch 370
# -------------------------------
# train Error: Avg loss: 1.104636
# Test Error: Avg loss: 44.472689
#
# Epoch 371
# -------------------------------
# train Error: Avg loss: 1.073033
# Test Error: Avg loss: 50.892291
#
# Epoch 372
# -------------------------------
# train Error: Avg loss: 1.047764
# Test Error: Avg loss: 44.490125
#
# Epoch 373
# -------------------------------
# train Error: Avg loss: 1.021799
# Test Error: Avg loss: 48.832676
#
# Epoch 374
# -------------------------------
# train Error: Avg loss: 1.043806
# Test Error: Avg loss: 45.239154
#
# Epoch 375
# -------------------------------
# train Error: Avg loss: 1.014764
# Test Error: Avg loss: 48.456901
#
# Epoch 376
# -------------------------------
# train Error: Avg loss: 1.051385
# Test Error: Avg loss: 45.299586
#
# Epoch 377
# -------------------------------
# train Error: Avg loss: 1.030317
# Test Error: Avg loss: 48.844824
#
# Epoch 378
# -------------------------------
# train Error: Avg loss: 1.071705
# Test Error: Avg loss: 46.539147
#
# Epoch 379
# -------------------------------
# train Error: Avg loss: 1.173529
# Test Error: Avg loss: 52.112651
#
# Epoch 380
# -------------------------------
# train Error: Avg loss: 1.401220
# Test Error: Avg loss: 46.235151
#
# Epoch 381
# -------------------------------
# train Error: Avg loss: 1.924539
# Test Error: Avg loss: 57.295615
#
# Epoch 382
# -------------------------------
# train Error: Avg loss: 2.071492
# Test Error: Avg loss: 42.546350
#
# Epoch 383
# -------------------------------
# train Error: Avg loss: 2.336598
# Test Error: Avg loss: 60.417503
#
# Epoch 384
# -------------------------------
# train Error: Avg loss: 2.045159
# Test Error: Avg loss: 38.709264
#
# Epoch 385
# -------------------------------
# train Error: Avg loss: 1.589032
# Test Error: Avg loss: 55.444909
#
# Epoch 386
# -------------------------------
# train Error: Avg loss: 1.267105
# Test Error: Avg loss: 44.531123
#
# Epoch 387
# -------------------------------
# train Error: Avg loss: 1.046924
# Test Error: Avg loss: 47.314067
#
# Epoch 388
# -------------------------------
# train Error: Avg loss: 0.946179
# Test Error: Avg loss: 45.502320
#
# Epoch 389
# -------------------------------
# train Error: Avg loss: 0.897854
# Test Error: Avg loss: 45.581911
#
# Epoch 390
# -------------------------------
# train Error: Avg loss: 0.878972
# Test Error: Avg loss: 44.990180
#
# Epoch 391
# -------------------------------
# train Error: Avg loss: 0.875987
# Test Error: Avg loss: 45.158667
#
# Epoch 392
# -------------------------------
# train Error: Avg loss: 0.854199
# Test Error: Avg loss: 45.105430
#
# Epoch 393
# -------------------------------
# train Error: Avg loss: 0.855612
# Test Error: Avg loss: 45.213645
#
# Epoch 394
# -------------------------------
# train Error: Avg loss: 0.835474
# Test Error: Avg loss: 45.132401
#
# Epoch 395
# -------------------------------
# train Error: Avg loss: 0.835886
# Test Error: Avg loss: 45.952564
#
# Epoch 396
# -------------------------------
# train Error: Avg loss: 0.840836
# Test Error: Avg loss: 45.045089
#
# Epoch 397
# -------------------------------
# train Error: Avg loss: 0.846492
# Test Error: Avg loss: 46.627238
#
# Epoch 398
# -------------------------------
# train Error: Avg loss: 0.890428
# Test Error: Avg loss: 44.415710
#
# Epoch 399
# -------------------------------
# train Error: Avg loss: 0.899702
# Test Error: Avg loss: 47.683658
#
# Epoch 400
# -------------------------------
# train Error: Avg loss: 0.986217
# Test Error: Avg loss: 43.744724
#
# Epoch 401
# -------------------------------
# train Error: Avg loss: 0.834606
# Test Error: Avg loss: 45.006763
#
# Epoch 402
# -------------------------------
# train Error: Avg loss: 0.810233
# Test Error: Avg loss: 45.227453
#
# Epoch 403
# -------------------------------
# train Error: Avg loss: 0.797821
# Test Error: Avg loss: 45.370383
#
# Epoch 404
# -------------------------------
# train Error: Avg loss: 0.790993
# Test Error: Avg loss: 45.469830
#
# Epoch 405
# -------------------------------
# train Error: Avg loss: 0.786745
# Test Error: Avg loss: 45.533638
#
# Epoch 406
# -------------------------------
# train Error: Avg loss: 0.783840
# Test Error: Avg loss: 45.569715
#
# Epoch 407
# -------------------------------
# train Error: Avg loss: 0.781692
# Test Error: Avg loss: 45.585955
#
# Epoch 408
# -------------------------------
# train Error: Avg loss: 0.779993
# Test Error: Avg loss: 45.588820
#
# Epoch 409
# -------------------------------
# train Error: Avg loss: 0.778570
# Test Error: Avg loss: 45.583526
#
# Epoch 410
# -------------------------------
# train Error: Avg loss: 0.777322
# Test Error: Avg loss: 45.573749
#
# Epoch 411
# -------------------------------
# train Error: Avg loss: 0.776188
# Test Error: Avg loss: 45.562151
#
# Epoch 412
# -------------------------------
# train Error: Avg loss: 0.775127
# Test Error: Avg loss: 45.550368
#
# Epoch 413
# -------------------------------
# train Error: Avg loss: 0.774113
# Test Error: Avg loss: 45.539699
#
# Epoch 414
# -------------------------------
# train Error: Avg loss: 0.773127
# Test Error: Avg loss: 45.530793
#
# Epoch 415
# -------------------------------
# train Error: Avg loss: 0.772158
# Test Error: Avg loss: 45.523829
#
# Epoch 416
# -------------------------------
# train Error: Avg loss: 0.771198
# Test Error: Avg loss: 45.518518
#
# Epoch 417
# -------------------------------
# train Error: Avg loss: 0.770243
# Test Error: Avg loss: 45.514355
#
# Epoch 418
# -------------------------------
# train Error: Avg loss: 0.769295
# Test Error: Avg loss: 45.510129
#
# Epoch 419
# -------------------------------
# train Error: Avg loss: 0.768358
# Test Error: Avg loss: 45.504822
#
# Epoch 420
# -------------------------------
# train Error: Avg loss: 0.767436
# Test Error: Avg loss: 45.497742
#
# Epoch 421
# -------------------------------
# train Error: Avg loss: 0.766531
# Test Error: Avg loss: 45.488667
#
# Epoch 422
# -------------------------------
# train Error: Avg loss: 0.765641
# Test Error: Avg loss: 45.478029
#
# Epoch 423
# -------------------------------
# train Error: Avg loss: 0.764767
# Test Error: Avg loss: 45.466280
#
# Epoch 424
# -------------------------------
# train Error: Avg loss: 0.763904
# Test Error: Avg loss: 45.454409
#
# Epoch 425
# -------------------------------
# train Error: Avg loss: 0.763051
# Test Error: Avg loss: 45.442679
#
# Epoch 426
# -------------------------------
# train Error: Avg loss: 0.762205
# Test Error: Avg loss: 45.431520
#
# Epoch 427
# -------------------------------
# train Error: Avg loss: 0.761364
# Test Error: Avg loss: 45.420863
#
# Epoch 428
# -------------------------------
# train Error: Avg loss: 0.760528
# Test Error: Avg loss: 45.410820
#
# Epoch 429
# -------------------------------
# train Error: Avg loss: 0.759694
# Test Error: Avg loss: 45.401421
#
# Epoch 430
# -------------------------------
# train Error: Avg loss: 0.758862
# Test Error: Avg loss: 45.392357
#
# Epoch 431
# -------------------------------
# train Error: Avg loss: 0.758029
# Test Error: Avg loss: 45.383646
#
# Epoch 432
# -------------------------------
# train Error: Avg loss: 0.757196
# Test Error: Avg loss: 45.375059
#
# Epoch 433
# -------------------------------
# train Error: Avg loss: 0.756362
# Test Error: Avg loss: 45.366354
#
# Epoch 434
# -------------------------------
# train Error: Avg loss: 0.755525
# Test Error: Avg loss: 45.357561
#
# Epoch 435
# -------------------------------
# train Error: Avg loss: 0.754685
# Test Error: Avg loss: 45.348517
#
# Epoch 436
# -------------------------------
# train Error: Avg loss: 0.753842
# Test Error: Avg loss: 45.339303
#
# Epoch 437
# -------------------------------
# train Error: Avg loss: 0.752993
# Test Error: Avg loss: 45.329347
#
# Epoch 438
# -------------------------------
# train Error: Avg loss: 0.752140
# Test Error: Avg loss: 45.318880
#
# Epoch 439
# ...
# Test Error: Avg loss: 44.221097
#
# Epoch 1856
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1857
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1858
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1859
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1860
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1861
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1862
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1863
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1864
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1865
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1866
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1867
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1868
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1869
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1870
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1871
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1872
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1873
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1874
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1875
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1876
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1877
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1878
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1879
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1880
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1881
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1882
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1883
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1884
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1885
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1886
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1887
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1888
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1889
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1890
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1891
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1892
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1893
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1894
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1895
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1896
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1897
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1898
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1899
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1900
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1901
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1902
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1903
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1904
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1905
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1906
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1907
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1908
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1909
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1910
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1911
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1912
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1913
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1914
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1915
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1916
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1917
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1918
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1919
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1920
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1921
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1922
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1923
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1924
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1925
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1926
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1927
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1928
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1929
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1930
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1931
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1932
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1933
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1934
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1935
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1936
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1937
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1938
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1939
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1940
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1941
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1942
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1943
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1944
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1945
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1946
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1947
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1948
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1949
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1950
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1951
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1952
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1953
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1954
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1955
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1956
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1957
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1958
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1959
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1960
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1961
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1962
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1963
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1964
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1965
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1966
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1967
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1968
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1969
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1970
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1971
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1972
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1973
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1974
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1975
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1976
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1977
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1978
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1979
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1980
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1981
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1982
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1983
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1984
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1985
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1986
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1987
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1988
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1989
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1990
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1991
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1992
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1993
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1994
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1995
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1996
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1997
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1998
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 1999
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Epoch 2000
# -------------------------------
# train Error: Avg loss: 0.520557
# Test Error: Avg loss: 44.221097
#
# Done!

# %%
plt.plot(losses[20:], label='train loss')
plt.plot(val[20:], label='test loss')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()

# %%
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
count =0
output = torch.tensor([])
model.eval()
with torch.no_grad():
    for X, y in train_loader:
        y_star = model(X)
        output = torch.cat((output, y_star), 0)
        
        #print(X.shape,y.shape )
        #print(X.shape)
#print(count)
plt.plot(y_train, label='Actual Close')
plt.plot(output, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()
output[2000],y_train[2000]
# Out:
# (tensor([120.5625]), array([120.60674286]))

# %%
output = torch.tensor([])
model.eval()
with torch.no_grad():
    for X, y in val_loader:
        y_star = model(X)
        output = torch.cat((output, y_star), 0)
        print(X.shape,y.shape )
plt.plot(y_val, label='Actual Close')
plt.plot(output, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()
# Out:
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([58, 5, 24]) torch.Size([58, 1])

# %%
for batch, (X, y) in enumerate(train_dataset):
    print( (X.shape, y.shape))
    print( batch,(X, y))
    break
# Out:
# (torch.Size([5, 24]), torch.Size([1]))
# 0 (tensor([[-0.8327, -0.8351, -0.8389, -0.8365,  2.9628,  1.3271,  1.1751,  0.3802,
#           1.1056,  2.1106, -0.1353, -0.8181,  1.0276, -0.4912, -0.5962, -0.8696,
#          -0.8510, -0.8328,  2.8687,  0.9830, -0.8611, -0.8382, -0.8370, -0.8363],
#         [-0.8327, -0.8351, -0.8389, -0.8365,  2.9628,  1.3271,  1.1751,  0.3802,
#           1.1056,  2.1106, -0.1353, -0.8181,  1.0276, -0.4912, -0.5962, -0.8696,
#          -0.8510, -0.8328,  2.8687,  0.9830, -0.8611, -0.8382, -0.8370, -0.8363],
#         [-0.8327, -0.8351, -0.8389, -0.8365,  2.9628,  1.3271,  1.1751,  0.3802,
#           1.1056,  2.1106, -0.1353, -0.8181,  1.0276, -0.4912, -0.5962, -0.8696,
#          -0.8510, -0.8328,  2.8687,  0.9830, -0.8611, -0.8382, -0.8370, -0.8363],
#         [-0.8327, -0.8351, -0.8389, -0.8365,  2.9628,  1.3271,  1.1751,  0.3802,
#           1.1056,  2.1106, -0.1353, -0.8181,  1.0276, -0.4912, -0.5962, -0.8696,
#          -0.8510, -0.8328,  2.8687,  0.9830, -0.8611, -0.8382, -0.8370, -0.8363],
#         [-0.8327, -0.8351, -0.8389, -0.8365,  2.9628,  1.3271,  1.1751,  0.3802,
#           1.1056,  2.1106, -0.1353, -0.8181,  1.0276, -0.4912, -0.5962, -0.8696,
#          -0.8510, -0.8328,  2.8687,  0.9830, -0.8611, -0.8382, -0.8370, -0.8363]]), tensor([16.6016]))

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(output,y_val))
# Out:
# 6.664405502773537

# %%
data = pd.read_csv('/Users/hieudao/Desktop/ai/do_an/clean_data/clean_apple.csv')
data['Date'] = pd.to_datetime(data['Date'])
data['Close+1'] = data['Close'].shift(-1)
data = data.dropna()

test = data[data['Date'] >= pd.to_datetime('2023-01-01 00:00:00-04:00')]
test = test.drop(columns=['Date','tema_8','tema_100'])
test
# Out:
#              Open        High         Low       Close     Volume    NATR_3  \
# 10498  129.901704  130.519898  123.809445  124.706833  112117500  4.067464
# 10499  126.521555  128.286420  124.716813  125.993095   89113600  3.433518
# 10500  126.760849  127.398990  124.397735  124.656975   80962700  2.938965
# 10501  125.644111  129.911675  124.527360  129.243622   87754700  3.500343
# 10502  130.091158  133.022623  129.512840  129.772079   70790800  3.199059
# ...           ...         ...         ...         ...        ...       ...
# 10620  189.080002  190.070007  188.940002  189.589996   46347300  0.990360
# 10621  191.630005  194.479996  191.259995  193.970001   85069600  1.744503
# 10622  193.779999  193.880005  191.759995  192.460007   31458200  1.453242
# 10623  191.570007  192.979996  190.619995  191.330002   46920300  1.347648
# 10624  189.839996  192.020004  189.199997  191.809998   45094300  1.407242
#
#            RSI_3      ADX_3  CCI_3_0.015     ROC_3  ...   BBL_3_2.0  \
# 10498  22.405448  73.412177  -100.000000 -0.769605  ...  123.405058
# 10499  36.223387  79.201037   -50.416864 -2.507522  ...  122.651668
# 10500  28.355520  83.429230  -100.000000 -3.778959  ...  123.882094
# 10501  66.180390  62.498965   100.000000  3.637963  ...  122.779047
# 10502  69.008185  62.336225   100.000000  2.999358  ...  123.297133
# ...          ...        ...          ...       ...  ...         ...
# 10620  82.130415  70.421457    74.977544  2.331728  ...  187.654737
# 10621  93.782080  78.988970   100.000000  3.142616  ...  186.637909
# 10622  70.134070  84.700645    38.282485  1.696173  ...  188.373397
# 10623  54.661777  68.426905  -100.000000  0.917773  ...  190.423689
# 10624  60.249293  50.174234   -84.587180 -1.113576  ...  190.940549
#
#         BBM_3_2.0   BBU_3_2.0  BBB_3_2.0  BBP_3_2.0  min_price_3  max_price_3  \
# 10498  127.831070  132.257082   6.924783   0.147060   123.809445   130.519898
# 10499  126.750882  130.850097   6.468143   0.407569   123.809445   130.519898
# 10500  125.118968  126.355841   1.977116   0.313242   123.809445   130.519898
# 10501  126.631231  130.483415   6.084098   0.839079   124.397735   129.911675
# 10502  127.890892  132.484651   7.183872   0.704755   124.397735   133.022623
# ...           ...         ...        ...        ...          ...          ...
# 10620  188.966665  190.278593   1.388529   0.737563   185.669998   190.070007
# 10621  190.936666  195.235423   4.502809   0.852815   187.600006   194.479996
# 10622  192.006668  195.639939   3.784526   0.562387   188.940002   194.479996
# 10623  192.586670  194.749651   2.246241   0.209505   190.619995   194.479996
# 10624  191.866669  192.792788   0.965378   0.469404   189.199997   193.880005
#
#         mid_price      tema_2     Close+1
# 10498  127.164672  124.960140  125.993095
# 10499  126.501617  125.789991  124.656975
# 10500  125.898362  124.696691  129.243622
# 10501  127.219517  129.043934  129.772079
# 10502  131.267732  129.921296  130.350403
# ...           ...         ...         ...
# 10620  189.505005  189.651317  193.970001
# 10621  192.869995  193.833325  192.460007
# 10622  192.820000  192.671886  191.330002
# 10623  191.799995  191.357489  191.809998
# 10624  190.610001  191.716240  190.679993
#
# [127 rows x 25 columns]

# %%
X_test = test.copy().drop(columns=['Close+1'])
y_test = pd.DataFrame()
y_test['Close+1'] = test[['Close+1']]

#X_test = X_test.to_numpy()
y_test = y_test.to_numpy()

X_test_scaled = scaler.transform(X_test)

test_dataset = TimeSeriesDataset(X_test_scaled,y_test,sequence_length=sequence_length)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)


output = torch.tensor([])
model.eval()
with torch.no_grad():
    for X, y in test_loader:
        y_star = model(X)
        output = torch.cat((output, y_star), 0)
        
        print(X.shape,y.shape )
#print(count)
plt.plot(y_test, label='Actual Close')
plt.plot(output, label='Predicted Close')
plt.xlabel('Day')
plt.ylabel('Close')
plt.legend()
plt.show()
np.sqrt(mean_squared_error(output,y_test))
# Out:
# /usr/local/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# torch.Size([64, 5, 24]) torch.Size([64, 1])
# torch.Size([63, 5, 24]) torch.Size([63, 1])
# 5.994191670258519

# %%
y_test.shape, X_test_scaled.shape, output.shape
# Out:
# ((127, 1), (127, 24), torch.Size([127, 1]))
